# %% [markdown]
# # XML example and exercise
# ****
# + study examples of accessing nodes in XML tree structure
# + work on exercise to be completed and submitted
# ****
# + reference: https://docs.python.org/2.7/library/xml.etree.elementtree.html
# + data source: http://www.dbis.informatik.uni-goettingen.de/Mondial
# ****

# %%
from xml.etree import ElementTree as ET
import pandas as pd

# %% [markdown]
# ## XML example
#
# + for details about tree traversal and iterators, see https://docs.python.org/2.7/library/xml.etree.elementtree.html

# %%
document_tree = ET.parse( './data/mondial_database_less.xml' )
root = document_tree.getroot()
root.tag, root.attrib
# Out:
# ('mondial', {})

# %%
for child in root:
    print(child.attrib)
# Out:
# {'car_code': 'AL', 'area': '28750', 'capital': 'cty-Albania-Tirane', 'memberships': 'org-BSEC org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EITI org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IFAD org-ILO org-IMO org-IMF org-IOC org-IOM org-ISO org-OIF org-ITU org-ITUC org-IDB org-MIGA org-NATO org-OSCE org-OPCW org-OAS org-OIC org-PCA org-UN org-UNCTAD org-UNESCO org-UNIDO org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO'}
# {'car_code': 'GR', 'area': '131940', 'capital': 'cty-Greece-Athens', 'memberships': 'org-AG org-BIS org-BSEC org-CD org-SELEC org-CE org-EMU org-EAPC org-EBRD org-ECB org-EIB org-CERN org-ESA org-EU org-FATF org-FAO org-IGAD org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICJ org-ICCt org-Interpol org-IDA org-IEA org-IFRCS org-IFC org-IFAD org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NATO org-NEA org-NSG org-OECD org-OSCE org-OPCW org-OAS org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO org-ZC'}
# {'car_code': 'MK', 'area': '25333', 'capital': 'cty-Macedonia-Skopje', 'memberships': 'org-BIS org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EU org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IFAD org-ILO org-IMO org-IMF org-IOC org-IOM org-OIF org-ITU org-ITUC org-MIGA org-OSCE org-OPCW org-OAS org-PFP org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UPU org-WCO org-WHO org-WIPO org-WMO org-UNWTO org-WTO'}
# {'car_code': 'SRB', 'area': '77474', 'capital': 'city-Belgrade-SRB-SRB', 'memberships': 'org-BIS org-BSEC org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EU org-FAO org-G-9 org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NAM org-NSG org-OSCE org-OPCW org-OAS org-PFP org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UNMIL org-UNOCI org-MONUSCO org-UNFICYP org-UNTSO org-UPU org-WCO org-WHO org-WIPO org-WMO org-UNWTO org-WTO'}
# {'car_code': 'MNE', 'area': '14026', 'capital': 'city-Podgorica-MNE-MNE', 'memberships': 'org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EU org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-ISO org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NAM org-OSCE org-OPCW org-PFP org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNMIL org-UPU org-WCO org-WHO org-WIPO org-WMO org-UNWTO org-WTO'}
# {'car_code': 'KOS', 'area': '10887', 'capital': 'city-Pristina-KOS-KOS', 'memberships': 'org-CD org-EBRD org-IBRD org-IDA org-IFC org-IMF org-ITUC'}
# {'car_code': 'AND', 'area': '450', 'capital': 'cty-Andorra-Andorra-la-Vella', 'memberships': 'org-CE org-FAO org-IPU org-ICC org-ICAO org-ICCt org-Interpol org-IFRCS org-IOC org-OIF org-ITU org-OSCE org-OPCW org-UN org-UNCTAD org-UNESCO org-WCO org-WHO org-WIPO org-UNWTO org-WTO'}

# %%
out = len(root)
count = 0
while count < out:
    print(root[count].tag)
    
    inner = len(root[count])
    in_count = 0
    
    while in_count < inner:
        if root[count][in_count].text is None:
            print('   ' + root[count][in_count].tag + ' ' + str(root[count][in_count].attrib) + ': ')
        else:
            print('   ' + root[count][in_count].tag + ' ' + str(root[count][in_count].attrib) + ': ' + 
                  root[count][in_count].text)
        in_count += 1
        
    count += 1
# Out:
# country
#    name {}: Albania
#    population {'measured': 'est.', 'year': '1950'}: 1214489
#    population {'measured': 'est.', 'year': '1960'}: 1618829
#    population {'measured': 'est.', 'year': '1970'}: 2138966
#    population {'measured': 'est.', 'year': '1980'}: 2734776
#    population {'measured': 'est.', 'year': '1990'}: 3446882
#    population {'year': '1997'}: 3249136
#    population {'measured': 'est.', 'year': '2000'}: 3304948
#    population {'year': '2001', 'measured': 'census'}: 3069275
#    population {'year': '2011', 'measured': 'census'}: 2800138
#    population_growth {}: 0.3
#    infant_mortality {}: 13.19
#    gdp_total {}: 12800
#    gdp_agri {}: 19.5
#    gdp_ind {}: 12
#    gdp_serv {}: 68.5
#    inflation {}: 1.7
#    unemployment {}: 16.9
#    indep_date {'from': 'Ottoman Empire'}: 1912-11-28
#    government {}: parliamentary democracy
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '95'}: Albanian
#    ethnicgroup {'percentage': '3'}: Greek
#    religion {'percentage': '70'}: Muslim
#    religion {'percentage': '10'}: Roman Catholic
#    religion {'percentage': '20'}: Christian Orthodox
#    language {'percentage': '98.8'}: Albanian
#    language {'percentage': '0.5'}: Greek
#    border {'country': 'GR', 'length': '282'}:
#    border {'country': 'MK', 'length': '151'}:
#    border {'country': 'MNE', 'length': '172'}:
#    border {'country': 'KOS', 'length': '112'}:
#    city {'id': 'cty-Albania-Tirane', 'country': 'AL'}:
#
#    city {'id': 'stadt-Shkoder-AL-AL', 'country': 'AL'}:
#
#    city {'id': 'stadt-Durres-AL-AL', 'country': 'AL'}:
#
#    city {'id': 'stadt-Vlore-AL-AL', 'country': 'AL'}:
#
#    city {'id': 'stadt-Elbasan-AL-AL', 'country': 'AL'}:
#
#    city {'id': 'stadt-Korce-AL-AL', 'country': 'AL'}:
#
# country
#    name {}: Greece
#    localname {}: Ελληνική Δημοκρατία
#    population {'measured': 'census', 'year': '1861'}: 1096810
#    population {'measured': 'census', 'year': '1870'}: 1457894
#    population {'measured': 'census', 'year': '1879'}: 1679470
#    population {'measured': 'census', 'year': '1896'}: 2433806
#    population {'measured': 'census', 'year': '1907'}: 2631592
#    population {'measured': 'census', 'year': '1920'}: 5016889
#    population {'measured': 'census', 'year': '1928'}: 6204684
#    population {'measured': 'census', 'year': '1940'}: 7344860
#    population {'measured': 'census', 'year': '1951'}: 7632801
#    population {'measured': 'census', 'year': '1961'}: 8388553
#    population {'measured': 'census', 'year': '1971'}: 8768372
#    population {'measured': 'census', 'year': '1981'}: 9739589
#    population {'year': '1991', 'measured': 'census'}: 10217335
#    population {'measured': 'census', 'year': '2001'}: 10934097
#    population {'measured': 'census', 'year': '2011'}: 10816286
#    population_growth {}: 0.01
#    infant_mortality {}: 4.78
#    gdp_total {}: 243300
#    gdp_agri {}: 3.5
#    gdp_ind {}: 16
#    gdp_serv {}: 80.5
#    inflation {}: -0.8
#    unemployment {}: 27.9
#    indep_date {'from': 'Ottoman Empire'}: 1829-01-01
#    government {}: parliamentary republic
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '93'}: Greek
#    religion {'percentage': '98'}: Christian Orthodox
#    religion {'percentage': '1.3'}: Muslim
#    language {'percentage': '99'}: Greek
#    border {'country': 'AL', 'length': '282'}:
#    border {'country': 'MK', 'length': '228'}:
#    border {'country': 'BG', 'length': '494'}:
#    border {'country': 'TR', 'length': '206'}:
#    province {'id': 'prov-Greece-2', 'country': 'GR', 'capital': 'cty-Greece-Komotini'}:
#
#    province {'id': 'prov-Greece-3', 'country': 'GR', 'capital': 'cty-Greece-Athens'}:
#
#    province {'id': 'prov-Greece-4', 'country': 'GR', 'capital': 'cty-Greece-5'}:
#
#    province {'id': 'prov-Greece-5', 'country': 'GR', 'capital': 'cty-Greece-Kozani'}:
#
#    province {'id': 'prov-Greece-6', 'country': 'GR', 'capital': 'cty-Greece-Korfu'}:
#
#    province {'id': 'prov-Greece-7', 'country': 'GR', 'capital': 'cty-Greece-Ioannina'}:
#
#    province {'id': 'prov-Greece-8', 'country': 'GR', 'capital': 'cty-Greece-Thessaloniki'}:
#
#    province {'id': 'prov-Greece-9', 'country': 'GR', 'capital': 'cty-Greece-7'}:
#
#    province {'id': 'prov-Greece-10', 'country': 'GR', 'capital': 'cty-Greece-Ermoupoli'}:
#
#    province {'id': 'prov-Greece-11', 'country': 'GR', 'capital': 'cty-Greece-Tripoli'}:
#
#    province {'id': 'prov-Greece-12', 'country': 'GR', 'capital': 'cty-Greece-Lamia'}:
#
#    province {'id': 'prov-Greece-13', 'country': 'GR', 'capital': 'cty-Greece-6'}:
#
#    province {'id': 'prov-Greece-14', 'country': 'GR', 'capital': 'cty-Greece-Mytilini'}:
#
#    province {'id': 'prov-Greece-15', 'country': 'GR', 'capital': 'cty-Greece-Mytilini'}:
#
# country
#    name {}: Macedonia
#    localname {}: Република Македониjа
#    population {'measured': 'census', 'year': '1921'}: 808724
#    population {'measured': 'census', 'year': '1931'}: 949958
#    population {'measured': 'census', 'year': '1948'}: 1152986
#    population {'measured': 'census', 'year': '1953'}: 1304514
#    population {'measured': 'census', 'year': '1961'}: 1406003
#    population {'measured': 'census', 'year': '1971'}: 1647308
#    population {'measured': 'census', 'year': '1981'}: 1909136
#    population {'measured': 'census', 'year': '1991'}: 2033964
#    population {'measured': 'census', 'year': '1994'}: 1935034
#    population {'measured': 'census', 'year': '2002'}: 2022547
#    population {'year': '2011', 'measured': 'estimate'}: 2059794
#    population_growth {}: 0.21
#    infant_mortality {}: 7.9
#    gdp_total {}: 10650
#    gdp_agri {}: 10.2
#    gdp_ind {}: 27.5
#    gdp_serv {}: 62.3
#    inflation {}: 2.8
#    unemployment {}: 28.6
#    indep_date {'from': 'Yugoslavia'}: 1991-09-17
#    government {}: parliamentary democracy
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '64.2'}: Macedonian
#    ethnicgroup {'percentage': '25.2'}: Albanian
#    ethnicgroup {'percentage': '3.9'}: Turkish
#    ethnicgroup {'percentage': '2.7'}: Gypsy
#    ethnicgroup {'percentage': '1.8'}: Serb
#    religion {'percentage': '64.7'}: Christian Orthodox
#    religion {'percentage': '33.3'}: Muslim
#    religion {'percentage': '0.2'}: Roman Catholic
#    language {'percentage': '66.5'}: Macedonian
#    language {'percentage': '25.1'}: Albanian
#    language {'percentage': '3.5'}: Turkish
#    language {'percentage': '1.9'}: Roma
#    language {'percentage': '1.2'}: Serbian
#    border {'country': 'AL', 'length': '151'}:
#    border {'country': 'GR', 'length': '228'}:
#    border {'country': 'SRB', 'length': '62'}:
#    border {'country': 'KOS', 'length': '159'}:
#    border {'country': 'BG', 'length': '148'}:
#    city {'id': 'cty-Macedonia-Skopje', 'country': 'MK'}:
#
#    city {'id': 'cty-Macedonia-Kumanovo', 'country': 'MK'}:
#
# country
#    name {}: Serbia
#    localname {}: Република Србија
#    population {'measured': 'est.', 'year': '1950'}: 6732256
#    population {'measured': 'est.', 'year': '1960'}: 7657958
#    population {'measured': 'est.', 'year': '1970'}: 8236185
#    population {'measured': 'est.', 'year': '1980'}: 9057483
#    population {'measured': 'est.', 'year': '1990'}: 9735429
#    population {'year': '1991', 'measured': 'census'}: 7620531
#    population {'measured': 'census', 'year': '2002'}: 7498001
#    population {'measured': 'census', 'year': '2011'}: 7120666
#    population_growth {}: -0.46
#    infant_mortality {}: 6.16
#    gdp_total {}: 43680
#    gdp_agri {}: 7.9
#    gdp_ind {}: 31.8
#    gdp_serv {}: 60.3
#    inflation {}: 2.2
#    unemployment {}: 20.1
#    indep_date {'from': 'Yugoslavia'}: 1992-04-11
#    government {}: republic
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '82.9'}: Serb
#    ethnicgroup {'percentage': '0.9'}: Montenegrin
#    ethnicgroup {'percentage': '3.9'}: Hungarian
#    ethnicgroup {'percentage': '1.4'}: Roma
#    ethnicgroup {'percentage': '1.8'}: Bosniak
#    ethnicgroup {'percentage': '1.1'}: Croat
#    religion {'percentage': '85'}: Christian Orthodox
#    religion {'percentage': '3.2'}: Muslim
#    religion {'percentage': '5.5'}: Roman Catholic
#    religion {'percentage': '1.1'}: Protestant
#    language {'percentage': '88.3'}: Serbian
#    language {'percentage': '3.8'}: Hungarian
#    language {'percentage': '1.8'}: Bosnian
#    language {'percentage': '1.1'}: Roma
#    border {'country': 'H', 'length': '151'}:
#    border {'country': 'RO', 'length': '476'}:
#    border {'country': 'BG', 'length': '318'}:
#    border {'country': 'MK', 'length': '62'}:
#    border {'country': 'HR', 'length': '241'}:
#    border {'country': 'BIH', 'length': '357'}:
#    border {'country': 'MNE', 'length': '124'}:
#    border {'country': 'KOS', 'length': '352'}:
#    city {'id': 'city-Belgrade-SRB-SRB', 'country': 'SRB'}:
#
#    city {'id': 'city-NoviSad-SRB-SRB', 'country': 'SRB'}:
#
#    city {'id': 'city-Nis-SRB-SRB', 'country': 'SRB'}:
#
# country
#    name {}: Montenegro
#    localname {}: Црна Гора
#    population {'measured': 'census', 'year': '1921'}: 311341
#    population {'measured': 'census', 'year': '1931'}: 360044
#    population {'measured': 'census', 'year': '1948'}: 377189
#    population {'measured': 'census', 'year': '1953'}: 419873
#    population {'measured': 'census', 'year': '1961'}: 471894
#    population {'measured': 'census', 'year': '1971'}: 529604
#    population {'measured': 'census', 'year': '1981'}: 584310
#    population {'measured': 'census', 'year': '1991'}: 615035
#    population {'measured': 'census', 'year': '2003'}: 620145
#    population {'year': '2011', 'measured': 'census'}: 620029
#    population_growth {}: -0.49
#    gdp_total {}: 4518
#    gdp_agri {}: 0.8
#    gdp_ind {}: 11.3
#    gdp_serv {}: 87.9
#    inflation {}: 4
#    unemployment {}: 19.1
#    indep_date {'from': 'SRB'}: 2006-06-03
#    government {}: republic
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '43'}: Montenegrin
#    ethnicgroup {'percentage': '32'}: Serb
#    ethnicgroup {'percentage': '8'}: Bosniak
#    ethnicgroup {'percentage': '5'}: Albanian
#    religion {'percentage': '74.2'}: Christian Orthodox
#    religion {'percentage': '17.7'}: Muslim
#    religion {'percentage': '3.5'}: Roman Catholic
#    language {'percentage': '63.6'}: Serbian
#    language {'percentage': '22'}: Montenegrin
#    language {'percentage': '5.5'}: Bosnian
#    language {'percentage': '5.3'}: Albanian
#    border {'country': 'HR', 'length': '25'}:
#    border {'country': 'SRB', 'length': '124'}:
#    border {'country': 'BIH', 'length': '249'}:
#    border {'country': 'AL', 'length': '172'}:
#    border {'country': 'KOS', 'length': '79'}:
#    city {'id': 'city-Podgorica-MNE-MNE', 'country': 'MNE'}:
#
# country
#    name {}: Kosovo
#    localname {}: Republika e Kosovës
#    population {'measured': 'census', 'year': '1981'}: 1584440
#    population {'measured': 'census', 'year': '1991'}: 1956196
#    population {'measured': 'census', 'year': '2011'}: 1733872
#    gdp_total {}: 7150
#    gdp_agri {}: 12.9
#    gdp_ind {}: 22.6
#    gdp_serv {}: 64.5
#    inflation {}: 1.8
#    unemployment {}: 30.9
#    indep_date {'from': 'SRB'}: 2008-02-17
#    government {}: republic
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '92'}: Albanian
#    ethnicgroup {'percentage': '5'}: Serbian
#    religion {'percentage': '90'}: Muslim
#    language {'percentage': '92'}: Albanian
#    language {'percentage': '5'}: Serbian
#    border {'country': 'MNE', 'length': '79'}:
#    border {'country': 'SRB', 'length': '352'}:
#    border {'country': 'MK', 'length': '159'}:
#    border {'country': 'AL', 'length': '112'}:
#    city {'id': 'city-Pristina-KOS-KOS', 'country': 'KOS'}:
#
# country
#    name {}: Andorra
#    localname {}: Principat d’Andorra
#    population {'measured': 'est.', 'year': '1950'}: 6197
#    population {'measured': 'est.', 'year': '1960'}: 13414
#    population {'measured': 'est.', 'year': '1970'}: 24279
#    population {'measured': 'est.', 'year': '1980'}: 36063
#    population {'measured': 'census', 'year': '1989'}: 46166
#    population {'year': '2001', 'measured': 'admin.'}: 66334
#    population {'year': '2006', 'measured': 'admin.'}: 81222
#    population {'year': '2011', 'measured': 'admin.'}: 78115
#    population_growth {}: 0.17
#    infant_mortality {}: 3.69
#    gdp_total {}: 4800
#    gdp_agri {}: 14
#    gdp_ind {}: 79
#    gdp_serv {}: 6
#    inflation {}: 1.1
#    unemployment {}: 4
#    indep_date {}: 1278-09-08
#    government {}: parliamentary democracy that retains as its chiefs of state a co-principality
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '43'}: Spanish
#    ethnicgroup {'percentage': '33'}: Andorran
#    ethnicgroup {'percentage': '11'}: Portuguese
#    ethnicgroup {'percentage': '2'}: French
#    ethnicgroup {'percentage': '5'}: African
#    religion {'percentage': '95'}: Roman Catholic
#    language {'percentage': '44'}: Catalan
#    language {'percentage': '33'}: Spanish
#    language {'percentage': '2'}: Galician
#    language {'percentage': '11'}: Portuguese
#    language {'percentage': '7'}: French
#    border {'country': 'F', 'length': '60'}:
#    border {'country': 'E', 'length': '65'}:
#    city {'id': 'cty-Andorra-Andorra-la-Vella', 'country': 'AND'}:

# %%
# print names of all countries
for child in root:
    print(child.find('name').text)
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra

# %%
# print names of all countries and their cities
for element in root.iter('country'):
    print('* ' + element.find('name').text + ':')
    capitals_string = ''
    for subelement in element.iter('city'):
        capitals_string += subelement.find('name').text + ', '
    print(capitals_string[:-2])
# Out:
# * Albania:
# Tirana, Shkodër, Durrës, Vlorë, Elbasan, Korçë
# * Greece:
# Komotini, Kavala, Athina, Peiraias, Peristeri, Acharnes, Patra, Kozani, Kerkyra, Ioannina, Thessaloniki, Iraklio, Chania, Ermoupoli, Rhodes, Tripoli, Lamia, Chalkida, Larissa, Volos, Mytilini, Karyes
# * Macedonia:
# Skopje, Kumanovo
# * Serbia:
# Beograd, Novi Sad, Niš
# * Montenegro:
# Podgorica
# * Kosovo:
# Prishtine
# * Andorra:
# Andorra la Vella

# %% [markdown]
# ****
# ## XML exercise
#
# Using data in 'data/mondial_database.xml', the examples above, and refering to https://docs.python.org/2.7/library/xml.etree.elementtree.html, find
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
# 4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
document = ET.parse( './data/mondial_database.xml' )

# %%
# some code to undestand the dataset
root = document.getroot()
root.tag, root.attrib
# Out:
# ('mondial', {})

# %%
out = len(root)
count = 0
while count < out:
    print(root[count].tag + ' ' + str(root[count].attrib))
    
    inner = len(root[count])
    in_count = 0
    
    while in_count < inner:
        if root[count][in_count].text is None:
            print('   ' + root[count][in_count].tag + ' ' + str(root[count][in_count].attrib) + ': ')
        else:
            print('   ' + root[count][in_count].tag + ' ' + str(root[count][in_count].attrib) + ': ' + 
                  root[count][in_count].text)
        in_count += 1
        
    count += 1
# Out:
# country {'car_code': 'AL', 'area': '28750', 'capital': 'cty-Albania-Tirane', 'memberships': 'org-BSEC org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EITI org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IFAD org-ILO org-IMO org-IMF org-IOC org-IOM org-ISO org-OIF org-ITU org-ITUC org-IDB org-MIGA org-NATO org-OSCE org-OPCW org-OAS org-OIC org-PCA org-UN org-UNCTAD org-UNESCO org-UNIDO org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO'}
#    name {}: Albania
#    population {'measured': 'est.', 'year': '1950'}: 1214489
#    population {'measured': 'est.', 'year': '1960'}: 1618829
#    population {'measured': 'est.', 'year': '1970'}: 2138966
#    population {'measured': 'est.', 'year': '1980'}: 2734776
#    population {'measured': 'est.', 'year': '1990'}: 3446882
#    population {'year': '1997'}: 3249136
#    population {'measured': 'est.', 'year': '2000'}: 3304948
#    population {'year': '2001', 'measured': 'census'}: 3069275
#    population {'year': '2011', 'measured': 'census'}: 2800138
#    population_growth {}: 0.3
#    infant_mortality {}: 13.19
#    gdp_total {}: 12800
#    gdp_agri {}: 19.5
#    gdp_ind {}: 12
#    gdp_serv {}: 68.5
#    inflation {}: 1.7
#    unemployment {}: 16.9
#    indep_date {'from': 'Ottoman Empire'}: 1912-11-28
#    government {}: parliamentary democracy
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '95'}: Albanian
#    ethnicgroup {'percentage': '3'}: Greek
#    religion {'percentage': '70'}: Muslim
#    religion {'percentage': '10'}: Roman Catholic
#    religion {'percentage': '20'}: Christian Orthodox
#    language {'percentage': '98.8'}: Albanian
#    language {'percentage': '0.5'}: Greek
#    border {'country': 'GR', 'length': '282'}:
#    border {'country': 'MK', 'length': '151'}:
#    border {'country': 'MNE', 'length': '172'}:
#    border {'country': 'KOS', 'length': '112'}:
#    city {'id': 'cty-Albania-Tirane', 'country': 'AL'}:
#
#    city {'id': 'stadt-Shkoder-AL-AL', 'country': 'AL'}:
#
#    city {'id': 'stadt-Durres-AL-AL', 'country': 'AL'}:
#
#    city {'id': 'stadt-Vlore-AL-AL', 'country': 'AL'}:
#
#    city {'id': 'stadt-Elbasan-AL-AL', 'country': 'AL'}:
#
#    city {'id': 'stadt-Korce-AL-AL', 'country': 'AL'}:
#
# country {'car_code': 'GR', 'area': '131940', 'capital': 'cty-Greece-Athens', 'memberships': 'org-AG org-BIS org-BSEC org-CD org-SELEC org-CE org-EMU org-EAPC org-EBRD org-ECB org-EIB org-CERN org-ESA org-EU org-FATF org-FAO org-IGAD org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICJ org-ICCt org-Interpol org-IDA org-IEA org-IFRCS org-IFC org-IFAD org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NATO org-NEA org-NSG org-OECD org-OSCE org-OPCW org-OAS org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO org-ZC'}
#    name {}: Greece
#    localname {}: Ελληνική Δημοκρατία
#    population {'measured': 'census', 'year': '1861'}: 1096810
#    population {'measured': 'census', 'year': '1870'}: 1457894
#    population {'measured': 'census', 'year': '1879'}: 1679470
#    population {'measured': 'census', 'year': '1896'}: 2433806
#    population {'measured': 'census', 'year': '1907'}: 2631592
#    population {'measured': 'census', 'year': '1920'}: 5016889
#    population {'measured': 'census', 'year': '1928'}: 6204684
#    population {'measured': 'census', 'year': '1940'}: 7344860
#    population {'measured': 'census', 'year': '1951'}: 7632801
#    population {'measured': 'census', 'year': '1961'}: 8388553
#    population {'measured': 'census', 'year': '1971'}: 8768372
#    population {'measured': 'census', 'year': '1981'}: 9739589
#    population {'year': '1991', 'measured': 'census'}: 10217335
#    population {'measured': 'census', 'year': '2001'}: 10934097
#    population {'measured': 'census', 'year': '2011'}: 10816286
#    population_growth {}: 0.01
#    infant_mortality {}: 4.78
#    gdp_total {}: 243300
#    gdp_agri {}: 3.5
#    gdp_ind {}: 16
#    gdp_serv {}: 80.5
#    inflation {}: -0.8
#    unemployment {}: 27.9
#    indep_date {'from': 'Ottoman Empire'}: 1829-01-01
#    government {}: parliamentary republic
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '93'}: Greek
#    religion {'percentage': '98'}: Christian Orthodox
#    religion {'percentage': '1.3'}: Muslim
#    language {'percentage': '99'}: Greek
#    border {'country': 'AL', 'length': '282'}:
#    border {'country': 'MK', 'length': '228'}:
#    border {'country': 'BG', 'length': '494'}:
#    border {'country': 'TR', 'length': '206'}:
#    province {'id': 'prov-Greece-2', 'country': 'GR', 'capital': 'cty-Greece-Komotini'}:
#
#    province {'id': 'prov-Greece-3', 'country': 'GR', 'capital': 'cty-Greece-Athens'}:
#
#    province {'id': 'prov-Greece-4', 'country': 'GR', 'capital': 'cty-Greece-5'}:
#
#    province {'id': 'prov-Greece-5', 'country': 'GR', 'capital': 'cty-Greece-Kozani'}:
#
#    province {'id': 'prov-Greece-6', 'country': 'GR', 'capital': 'cty-Greece-Korfu'}:
#
#    province {'id': 'prov-Greece-7', 'country': 'GR', 'capital': 'cty-Greece-Ioannina'}:
#
#    province {'id': 'prov-Greece-8', 'country': 'GR', 'capital': 'cty-Greece-Thessaloniki'}:
#
#    province {'id': 'prov-Greece-9', 'country': 'GR', 'capital': 'cty-Greece-7'}:
#
#    province {'id': 'prov-Greece-10', 'country': 'GR', 'capital': 'cty-Greece-Ermoupoli'}:
#
#    province {'id': 'prov-Greece-11', 'country': 'GR', 'capital': 'cty-Greece-Tripoli'}:
#
#    province {'id': 'prov-Greece-12', 'country': 'GR', 'capital': 'cty-Greece-Lamia'}:
#
#    province {'id': 'prov-Greece-13', 'country': 'GR', 'capital': 'cty-Greece-6'}:
#
#    province {'id': 'prov-Greece-14', 'country': 'GR', 'capital': 'cty-Greece-Mytilini'}:
#
#    province {'id': 'prov-Greece-15', 'country': 'GR', 'capital': 'cty-Greece-Mytilini'}:
#
# country {'car_code': 'MK', 'area': '25333', 'capital': 'cty-Macedonia-Skopje', 'memberships': 'org-BIS org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EU org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IFAD org-ILO org-IMO org-IMF org-IOC org-IOM org-OIF org-ITU org-ITUC org-MIGA org-OSCE org-OPCW org-OAS org-PFP org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UPU org-WCO org-WHO org-WIPO org-WMO org-UNWTO org-WTO'}
#    name {}: Macedonia
#    localname {}: Република Македониjа
#    population {'measured': 'census', 'year': '1921'}: 808724
#    population {'measured': 'census', 'year': '1931'}: 949958
#    population {'measured': 'census', 'year': '1948'}: 1152986
#    population {'measured': 'census', 'year': '1953'}: 1304514
#    population {'measured': 'census', 'year': '1961'}: 1406003
#    population {'measured': 'census', 'year': '1971'}: 1647308
#    population {'measured': 'census', 'year': '1981'}: 1909136
#    population {'measured': 'census', 'year': '1991'}: 2033964
#    population {'measured': 'census', 'year': '1994'}: 1935034
#    population {'measured': 'census', 'year': '2002'}: 2022547
#    population {'year': '2011', 'measured': 'estimate'}: 2059794
#    population_growth {}: 0.21
#    infant_mortality {}: 7.9
#    gdp_total {}: 10650
#    gdp_agri {}: 10.2
#    gdp_ind {}: 27.5
#    gdp_serv {}: 62.3
#    inflation {}: 2.8
#    unemployment {}: 28.6
#    indep_date {'from': 'Yugoslavia'}: 1991-09-17
#    government {}: parliamentary democracy
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '64.2'}: Macedonian
#    ethnicgroup {'percentage': '25.2'}: Albanian
#    ethnicgroup {'percentage': '3.9'}: Turkish
#    ethnicgroup {'percentage': '2.7'}: Gypsy
#    ethnicgroup {'percentage': '1.8'}: Serb
#    religion {'percentage': '64.7'}: Christian Orthodox
#    religion {'percentage': '33.3'}: Muslim
#    religion {'percentage': '0.2'}: Roman Catholic
#    language {'percentage': '66.5'}: Macedonian
#    language {'percentage': '25.1'}: Albanian
#    language {'percentage': '3.5'}: Turkish
#    language {'percentage': '1.9'}: Roma
#    language {'percentage': '1.2'}: Serbian
#    border {'country': 'AL', 'length': '151'}:
#    border {'country': 'GR', 'length': '228'}:
#    border {'country': 'SRB', 'length': '62'}:
#    border {'country': 'KOS', 'length': '159'}:
#    border {'country': 'BG', 'length': '148'}:
#    city {'id': 'cty-Macedonia-Skopje', 'country': 'MK'}:
#
#    city {'id': 'cty-Macedonia-Kumanovo', 'country': 'MK'}:
#
# country {'car_code': 'SRB', 'area': '77474', 'capital': 'city-Belgrade-SRB-SRB', 'memberships': 'org-BIS org-BSEC org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EU org-FAO org-G-9 org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NAM org-NSG org-OSCE org-OPCW org-OAS org-PFP org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UNMIL org-UNOCI org-MONUSCO org-UNFICYP org-UNTSO org-UPU org-WCO org-WHO org-WIPO org-WMO org-UNWTO org-WTO'}
#    name {}: Serbia
#    localname {}: Република Србија
#    population {'measured': 'est.', 'year': '1950'}: 6732256
#    population {'measured': 'est.', 'year': '1960'}: 7657958
#    population {'measured': 'est.', 'year': '1970'}: 8236185
#    population {'measured': 'est.', 'year': '1980'}: 9057483
#    population {'measured': 'est.', 'year': '1990'}: 9735429
#    population {'year': '1991', 'measured': 'census'}: 7620531
#    population {'measured': 'census', 'year': '2002'}: 7498001
#    population {'measured': 'census', 'year': '2011'}: 7120666
#    population_growth {}: -0.46
#    infant_mortality {}: 6.16
#    gdp_total {}: 43680
#    gdp_agri {}: 7.9
#    gdp_ind {}: 31.8
#    gdp_serv {}: 60.3
#    inflation {}: 2.2
#    unemployment {}: 20.1
#    indep_date {'from': 'Yugoslavia'}: 1992-04-11
#    government {}: republic
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '82.9'}: Serb
#    ethnicgroup {'percentage': '0.9'}: Montenegrin
#    ethnicgroup {'percentage': '3.9'}: Hungarian
#    ethnicgroup {'percentage': '1.4'}: Roma
#    ethnicgroup {'percentage': '1.8'}: Bosniak
#    ethnicgroup {'percentage': '1.1'}: Croat
#    religion {'percentage': '85'}: Christian Orthodox
#    religion {'percentage': '3.2'}: Muslim
#    religion {'percentage': '5.5'}: Roman Catholic
#    religion {'percentage': '1.1'}: Protestant
#    language {'percentage': '88.3'}: Serbian
#    language {'percentage': '3.8'}: Hungarian
#    language {'percentage': '1.8'}: Bosnian
#    language {'percentage': '1.1'}: Roma
#    border {'country': 'H', 'length': '151'}:
#    border {'country': 'RO', 'length': '476'}:
#    border {'country': 'BG', 'length': '318'}:
#    border {'country': 'MK', 'length': '62'}:
#    border {'country': 'HR', 'length': '241'}:
#    border {'country': 'BIH', 'length': '357'}:
#    border {'country': 'MNE', 'length': '124'}:
#    border {'country': 'KOS', 'length': '352'}:
#    city {'id': 'city-Belgrade-SRB-SRB', 'country': 'SRB'}:
#
#    city {'id': 'city-NoviSad-SRB-SRB', 'country': 'SRB'}:
#
#    city {'id': 'city-Nis-SRB-SRB', 'country': 'SRB'}:
#
# country {'car_code': 'MNE', 'area': '14026', 'capital': 'city-Podgorica-MNE-MNE', 'memberships': 'org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EU org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-ISO org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NAM org-OSCE org-OPCW org-PFP org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNMIL org-UPU org-WCO org-WHO org-WIPO org-WMO org-UNWTO org-WTO'}
#    name {}: Montenegro
#    localname {}: Црна Гора
#    population {'measured': 'census', 'year': '1921'}: 311341
#    population {'measured': 'census', 'year': '1931'}: 360044
#    population {'measured': 'census', 'year': '1948'}: 377189
#    population {'measured': 'census', 'year': '1953'}: 419873
#    population {'measured': 'census', 'year': '1961'}: 471894
#    population {'measured': 'census', 'year': '1971'}: 529604
#    population {'measured': 'census', 'year': '1981'}: 584310
#    population {'measured': 'census', 'year': '1991'}: 615035
#    population {'measured': 'census', 'year': '2003'}: 620145
#    population {'year': '2011', 'measured': 'census'}: 620029
#    population_growth {}: -0.49
#    gdp_total {}: 4518
#    gdp_agri {}: 0.8
#    gdp_ind {}: 11.3
#    gdp_serv {}: 87.9
#    inflation {}: 4
#    unemployment {}: 19.1
#    indep_date {'from': 'SRB'}: 2006-06-03
#    government {}: republic
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '43'}: Montenegrin
#    ethnicgroup {'percentage': '32'}: Serb
#    ethnicgroup {'percentage': '8'}: Bosniak
#    ethnicgroup {'percentage': '5'}: Albanian
#    religion {'percentage': '74.2'}: Christian Orthodox
#    religion {'percentage': '17.7'}: Muslim
#    religion {'percentage': '3.5'}: Roman Catholic
#    language {'percentage': '63.6'}: Serbian
#    language {'percentage': '22'}: Montenegrin
#    language {'percentage': '5.5'}: Bosnian
#    language {'percentage': '5.3'}: Albanian
#    border {'country': 'HR', 'length': '25'}:
#    border {'country': 'SRB', 'length': '124'}:
#    border {'country': 'BIH', 'length': '249'}:
#    border {'country': 'AL', 'length': '172'}:
#    border {'country': 'KOS', 'length': '79'}:
#    city {'id': 'city-Podgorica-MNE-MNE', 'country': 'MNE'}:
#
# country {'car_code': 'KOS', 'area': '10887', 'capital': 'city-Pristina-KOS-KOS', 'memberships': 'org-CD org-EBRD org-IBRD org-IDA org-IFC org-IMF org-ITUC'}
#    name {}: Kosovo
#    localname {}: Republika e Kosovës
#    population {'measured': 'census', 'year': '1981'}: 1584440
#    population {'measured': 'census', 'year': '1991'}: 1956196
#    population {'measured': 'census', 'year': '2011'}: 1733872
#    gdp_total {}: 7150
#    gdp_agri {}: 12.9
#    gdp_ind {}: 22.6
#    gdp_serv {}: 64.5
#    inflation {}: 1.8
#    unemployment {}: 30.9
#    indep_date {'from': 'SRB'}: 2008-02-17
#    government {}: republic
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '92'}: Albanian
#    ethnicgroup {'percentage': '5'}: Serbian
#    religion {'percentage': '90'}: Muslim
#    language {'percentage': '92'}: Albanian
#    language {'percentage': '5'}: Serbian
#    border {'country': 'MNE', 'length': '79'}:
#    border {'country': 'SRB', 'length': '352'}:
#    border {'country': 'MK', 'length': '159'}:
#    border {'country': 'AL', 'length': '112'}:
#    city {'id': 'city-Pristina-KOS-KOS', 'country': 'KOS'}:
#
# country {'car_code': 'AND', 'area': '450', 'capital': 'cty-Andorra-Andorra-la-Vella', 'memberships': 'org-CE org-FAO org-IPU org-ICC org-ICAO org-ICCt org-Interpol org-IFRCS org-IOC org-OIF org-ITU org-OSCE org-OPCW org-UN org-UNCTAD org-UNESCO org-WCO org-WHO org-WIPO org-UNWTO org-WTO'}
#    name {}: Andorra
#    localname {}: Principat d’Andorra
#    population {'measured': 'est.', 'year': '1950'}: 6197
#    population {'measured': 'est.', 'year': '1960'}: 13414
#    population {'measured': 'est.', 'year': '1970'}: 24279
#    population {'measured': 'est.', 'year': '1980'}: 36063
#    population {'measured': 'census', 'year': '1989'}: 46166
#    population {'year': '2001', 'measured': 'admin.'}: 66334
#    population {'year': '2006', 'measured': 'admin.'}: 81222
#    population {'year': '2011', 'measured': 'admin.'}: 78115
#    population_growth {}: 0.17
#    infant_mortality {}: 3.69
#    gdp_total {}: 4800
#    gdp_agri {}: 14
#    gdp_ind {}: 79
#    gdp_serv {}: 6
#    inflation {}: 1.1
#    unemployment {}: 4
#    indep_date {}: 1278-09-08
#    government {}: parliamentary democracy that retains as its chiefs of state a co-principality
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '43'}: Spanish
#    ethnicgroup {'percentage': '33'}: Andorran
#    ethnicgroup {'percentage': '11'}: Portuguese
#    ethnicgroup {'percentage': '2'}: French
#    ethnicgroup {'percentage': '5'}: African
#    religion {'percentage': '95'}: Roman Catholic
#    language {'percentage': '44'}: Catalan
#    language {'percentage': '33'}: Spanish
#    language {'percentage': '2'}: Galician
#    language {'percentage': '11'}: Portuguese
#    language {'percentage': '7'}: French
#    border {'country': 'F', 'length': '60'}:
#    border {'country': 'E', 'length': '65'}:
#    city {'id': 'cty-Andorra-Andorra-la-Vella', 'country': 'AND'}:
#
# country {'car_code': 'F', 'area': '547030', 'capital': 'cty-France-Paris', 'memberships': 'org-AfDB org-ADB org-AG org-BIS org-BSEC org-BDEAC org-SICA org-SELEC org-CE org-CBSS org-EMU org-EAPC org-EBRD org-ECB org-EIB org-CERN org-ESA org-EU org-EITI org-FATF org-FAO org-FZ org-G-10 org-G-20 org-G-5 org-G-7 org-G-8 org-InOC org-IADB org-IGAD org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IEA org-IFRCS org-IFC org-IFAD org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NATO org-NEA org-NSG org-OECD org-OSCE org-OPCW org-OAS org-PIF org-PCA org-SPC org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-MINURSO org-UNMIL org-UNOCI org-MONUSCO org-UNRWA org-UNSC org-UNTSO org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO org-ZC'}
#    name {}: France
#    localname {}: la République française
#    population {'measured': 'census', 'year': '1946'}: 40502513
#    population {'measured': 'census', 'year': '1954'}: 42777162
#    population {'measured': 'census', 'year': '1962'}: 46520271
#    population {'measured': 'census', 'year': '1968'}: 49778540
#    population {'measured': 'census', 'year': '1975'}: 52591584
#    population {'measured': 'census', 'year': '1982'}: 54334871
#    population {'measured': 'census', 'year': '1990'}: 56615155
#    population {'year': '1999', 'measured': 'census'}: 60185831
#    population {'year': '2006', 'measured': 'admin.'}: 60825000
#    population {'year': '2011', 'measured': 'admin.'}: 64933400
#    population_growth {}: 0.45
#    infant_mortality {}: 3.31
#    gdp_total {}: 2739000
#    gdp_agri {}: 1.9
#    gdp_ind {}: 18.7
#    gdp_serv {}: 79.4
#    inflation {}: 0.9
#    unemployment {}: 10.2
#    government {}: republic
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    religion {'percentage': '85'}: Roman Catholic
#    religion {'percentage': '8'}: Muslim
#    religion {'percentage': '2'}: Protestant
#    religion {'percentage': '1'}: Jewish
#    language {'percentage': '100'}: French
#    border {'country': 'AND', 'length': '60'}:
#    border {'country': 'E', 'length': '623'}:
#    border {'country': 'D', 'length': '451'}:
#    border {'country': 'I', 'length': '488'}:
#    border {'country': 'CH', 'length': '573'}:
#    border {'country': 'B', 'length': '620'}:
#    border {'country': 'L', 'length': '73'}:
#    border {'country': 'MC', 'length': '4.4'}:
#    province {'id': 'prov-France-2', 'country': 'F', 'capital': 'cty-France-Strasbourg'}:
#
#    province {'id': 'prov-France-5', 'country': 'F', 'capital': 'cty-France-9'}:
#
#    province {'id': 'prov-France-11', 'country': 'F', 'capital': 'cty-France-22'}:
#
#    province {'id': 'prov-France-16', 'country': 'F', 'capital': 'cty-France-31'}:
#
#    province {'id': 'prov-France-20', 'country': 'F', 'capital': 'cty-France-12'}:
#
#    province {'id': 'prov-France-25', 'country': 'F', 'capital': 'cty-France-19'}:
#
#    province {'id': 'prov-France-30', 'country': 'F', 'capital': 'cty-France-34'}:
#
#    province {'id': 'prov-France-37', 'country': 'F', 'capital': 'cty-France-Chalons'}:
#
#    province {'id': 'prov-France-42', 'country': 'F', 'capital': 'cty-France-Ajaccio'}:
#
#    province {'id': 'prov-France-45', 'country': 'F', 'capital': 'cty-France-30'}:
#
#    province {'id': 'prov-France-50', 'country': 'F', 'capital': 'cty-France-35'}:
#
#    province {'id': 'prov-France-53', 'country': 'F', 'capital': 'cty-France-Paris'}:
#
#    province {'id': 'prov-France-62', 'country': 'F', 'capital': 'cty-France-10'}:
#
#    province {'id': 'prov-France-68', 'country': 'F', 'capital': 'cty-France-23'}:
#
#    province {'id': 'prov-France-72', 'country': 'F', 'capital': 'cty-France-28'}:
#
#    province {'id': 'prov-France-77', 'country': 'F', 'capital': 'cty-France-5'}:
#
#    province {'id': 'prov-France-86', 'country': 'F', 'capital': 'cty-France-15'}:
#
#    province {'id': 'prov-France-89', 'country': 'F', 'capital': 'cty-France-Nantes'}:
#
#    province {'id': 'prov-France-95', 'country': 'F', 'capital': 'cty-France-24'}:
#
#    province {'id': 'prov-France-99', 'country': 'F', 'capital': 'cty-France-Poitiers'}:
#
#    province {'id': 'prov-France-104', 'country': 'F', 'capital': 'cty-France-3'}:
#
#    province {'id': 'prov-France-111', 'country': 'F', 'capital': 'cty-France-Lyon'}:
#
# country {'car_code': 'E', 'area': '504750', 'capital': 'cty-Spain-Madrid', 'memberships': 'org-AfDB org-CAN org-ADB org-AG org-BIS org-BCIE org-SICA org-CD org-SELEC org-CE org-CBSS org-EMU org-EAPC org-EBRD org-ECB org-EIB org-CERN org-ESA org-EU org-EITI org-FATF org-FAO org-IADB org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICJ org-ICCt org-Interpol org-IDA org-IEA org-IFRCS org-IFC org-IFAD org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-ITSO org-ITU org-ITUC org-LAIA org-MIGA org-NATO org-NEA org-NSG org-OECD org-OSCE org-OPCW org-OAS org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UNRWA org-UPU org-WCO org-WHO org-WIPO org-WMO org-UNWTO org-WTO org-ZC'}
#    name {}: Spain
#    localname {}: el Reino de España
#    population {'measured': 'census', 'year': '1900'}: 18618086
#    population {'measured': 'census', 'year': '1910'}: 19995686
#    population {'measured': 'census', 'year': '1920'}: 21389842
#    population {'measured': 'census', 'year': '1930'}: 23677794
#    population {'measured': 'census', 'year': '1940'}: 25877971
#    population {'measured': 'census', 'year': '1950'}: 27976755
#    population {'measured': 'census', 'year': '1960'}: 30528539
#    population {'measured': 'census', 'year': '1970'}: 34040657
#    population {'measured': 'census', 'year': '1981'}: 37683363
#    population {'year': '1991', 'measured': 'census'}: 38871331
#    population {'measured': 'census', 'year': '2001'}: 40847371
#    population {'measured': 'census', 'year': '2011'}: 46815916
#    population_growth {}: 0.81
#    infant_mortality {}: 3.33
#    gdp_total {}: 1356000
#    gdp_agri {}: 3.1
#    gdp_ind {}: 26
#    gdp_serv {}: 70.8
#    inflation {}: 1.8
#    unemployment {}: 26.3
#    indep_date {}: 1492-01-01
#    government {}: parliamentary monarchy
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '100'}: Mediterranean Nordic
#    religion {'percentage': '94'}: Roman Catholic
#    language {'percentage': '74'}: Spanish
#    language {'percentage': '17'}: Catalan
#    language {'percentage': '7'}: Galician
#    language {'percentage': '2'}: Basque
#    border {'country': 'AND', 'length': '65'}:
#    border {'country': 'F', 'length': '623'}:
#    border {'country': 'GBZ', 'length': '1.2'}:
#    border {'country': 'P', 'length': '1214'}:
#    province {'id': 'prov-Spain-2', 'country': 'E', 'capital': 'cty-Spain-5'}:
#
#    province {'id': 'prov-Spain-3', 'country': 'E', 'capital': 'cty-Spain-6'}:
#
#    province {'id': 'prov-Spain-4', 'country': 'E', 'capital': 'cty-Spain-23'}:
#
#    province {'id': 'prov-Spain-5', 'country': 'E', 'capital': 'cty-Spain-12'}:
#
#    province {'id': 'prov-Spain-6', 'country': 'E', 'capital': 'cty-Spain-21'}:
#
#    province {'id': 'prov-Spain-7', 'country': 'E', 'capital': 'cty-Spain-22'}:
#
#    province {'id': 'prov-Spain-8', 'country': 'E', 'capital': 'cty-Spain-25'}:
#
#    province {'id': 'prov-Spain-9', 'country': 'E', 'capital': 'cty-Spain-11'}:
#
#    province {'id': 'prov-Spain-10', 'country': 'E', 'capital': 'cty-Spain-Toledo'}:
#
#    province {'id': 'prov-Spain-11', 'country': 'E', 'capital': 'cty-Spain-Barcelona'}:
#
#    province {'id': 'prov-Spain-12', 'country': 'E', 'capital': 'cty-Spain-Merida'}:
#
#    province {'id': 'prov-Spain-13', 'country': 'E', 'capital': 'cty-Spain-Santiago-de-Compostela'}:
#
#    province {'id': 'prov-Spain-14', 'country': 'E', 'capital': 'cty-Spain-Madrid'}:
#
#    province {'id': 'prov-Spain-15', 'country': 'E', 'capital': 'cty-Spain-10'}:
#
#    province {'id': 'prov-Spain-16', 'country': 'E', 'capital': 'cty-Spain-29'}:
#
#    province {'id': 'prov-Spain-17', 'country': 'E', 'capital': 'cty-Spain-49'}:
#
#    province {'id': 'prov-Spain-18', 'country': 'E', 'capital': 'cty-Spain-Valencia'}:
#
# country {'car_code': 'A', 'area': '83850', 'capital': 'cty-Austria-Vienna', 'memberships': 'org-AfDB org-ADB org-AG org-BIS org-BSEC org-CEI org-CD org-SELEC org-CE org-EMU org-EAPC org-EBRD org-ECB org-EIB org-CERN org-ESA org-EU org-FATF org-FAO org-G-9 org-IADB org-IGAD org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICJ org-ICCt org-Interpol org-IDA org-IEA org-IFRCS org-IFC org-ILO org-IMO org-IMF org-IOC org-IOM org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NEA org-NSG org-OECD org-OSCE org-OPCW org-OAS org-PFP org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-MINURSO org-UNFICYP org-UNTSO org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO org-ZC'}
#    name {}: Austria
#    localname {}: Republik Österreich (die)
#    population {'measured': 'census', 'year': '1869'}: 4497873
#    population {'measured': 'census', 'year': '1910'}: 6648310
#    population {'measured': 'census', 'year': '1934'}: 6760233
#    population {'measured': 'census', 'year': '1951'}: 6933905
#    population {'measured': 'census', 'year': '1961'}: 7073807
#    population {'measured': 'census', 'year': '1971'}: 7491526
#    population {'measured': 'census', 'year': '1981'}: 7555338
#    population {'measured': 'census', 'year': '1991'}: 7795786
#    population {'measured': 'census', 'year': '2001'}: 8032926
#    population {'year': '2010', 'measured': 'admin.'}: 8375290
#    population {'year': '2013', 'measured': 'admin.'}: 8499759
#    population_growth {}: 0.01
#    infant_mortality {}: 4.16
#    gdp_total {}: 417900
#    gdp_agri {}: 1.6
#    gdp_ind {}: 28.6
#    gdp_serv {}: 69.8
#    inflation {}: 2.1
#    unemployment {}: 4.9
#    indep_date {'from': 'Austria-Hungary'}: 1918-11-12
#    government {}: federal republic
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '91.1'}: Austrian
#    ethnicgroup {'percentage': '1.6'}: Turkish
#    ethnicgroup {'percentage': '1'}: Slovene
#    ethnicgroup {'percentage': '2'}: Croat
#    ethnicgroup {'percentage': '2'}: Serbs
#    ethnicgroup {'percentage': '0.9'}: German
#    religion {'percentage': '85'}: Roman Catholic
#    religion {'percentage': '6'}: Protestant
#    language {'percentage': '88.6'}: German
#    language {'percentage': '2.3'}: Turkish
#    language {'percentage': '2.2'}: Serbian
#    language {'percentage': '2.5'}: Croatian
#    language {'percentage': '0.3'}: Slovene
#    language {'percentage': '0.1'}: Hungarian
#    border {'country': 'CZ', 'length': '362'}:
#    border {'country': 'D', 'length': '784'}:
#    border {'country': 'H', 'length': '366'}:
#    border {'country': 'I', 'length': '430'}:
#    border {'country': 'FL', 'length': '37'}:
#    border {'country': 'SK', 'length': '91'}:
#    border {'country': 'SLO', 'length': '324'}:
#    border {'country': 'CH', 'length': '164'}:
#    province {'id': 'prov-Austria-2', 'country': 'A', 'capital': 'cty-Austria-Eisenstadt'}:
#
#    province {'id': 'prov-Austria-3', 'country': 'A', 'capital': 'cty-Austria-Klagenfurt'}:
#
#    province {'id': 'prov-Austria-4', 'country': 'A', 'capital': 'cty-Austria-Bregenz'}:
#
#    province {'id': 'prov-Austria-5', 'country': 'A', 'capital': 'cty-Austria-Vienna'}:
#
#    province {'id': 'prov-Austria-6', 'country': 'A', 'capital': 'cty-Austria-4'}:
#
#    province {'id': 'prov-Austria-7', 'country': 'A', 'capital': 'cty-Austria-6'}:
#
#    province {'id': 'prov-Austria-8', 'country': 'A', 'capital': 'cty-Austria-3'}:
#
#    province {'id': 'prov-Austria-9', 'country': 'A', 'capital': 'cty-Austria-5'}:
#
#    province {'id': 'prov-Austria-10', 'country': 'A', 'capital': 'cty-Austria-St-Polten'}:
#
# country {'car_code': 'CZ', 'area': '78703', 'capital': 'cty-Czech-2', 'memberships': 'org-AG org-BIS org-BSEC org-CEI org-CD org-CE org-EAPC org-EBRD org-EIB org-CERN org-ESA org-EU org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IEA org-IFRCS org-IFC org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NATO org-NEA org-NSG org-OECD org-OSCE org-OPCW org-OAS org-PCA org-UN org-UNCTAD org-UNESCO org-UNIDO org-MONUSCO org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO org-ZC'}
#    name {}: Czech Republic
#    population {'measured': 'est.', 'year': '1950'}: 8876260
#    population {'measured': 'est.', 'year': '1960'}: 9577974
#    population {'measured': 'est.', 'year': '1970'}: 9827923
#    population {'measured': 'est.', 'year': '1980'}: 10313309
#    population {'measured': 'est.', 'year': '1990'}: 10325976
#    population {'year': '1997'}: 10321120
#    population {'measured': 'est.', 'year': '2000'}: 10250398
#    population {'year': '2001', 'measured': 'census'}: 10230060
#    population {'year': '2011', 'measured': 'census'}: 10562214
#    population_growth {}: 0.17
#    infant_mortality {}: 2.63
#    gdp_total {}: 194800
#    gdp_agri {}: 2.4
#    gdp_ind {}: 37.3
#    gdp_serv {}: 60.3
#    inflation {}: 1.4
#    unemployment {}: 7.1
#    indep_date {'from': 'Czechoslovakia'}: 1993-01-01
#    government {}: parliamentary democracy
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '90.4'}: Czech
#    ethnicgroup {'percentage': '3.7'}: Moravian
#    ethnicgroup {'percentage': '1.9'}: Slovak
#    ethnicgroup {'percentage': '0.5'}: German
#    ethnicgroup {'percentage': '0.6'}: Polish
#    ethnicgroup {'percentage': '0.3'}: Roma
#    ethnicgroup {'percentage': '0.2'}: Hungarian
#    religion {'percentage': '26.8'}: Roman Catholic
#    religion {'percentage': '2.1'}: Protestant
#    language {'percentage': '94.9'}: Czech
#    language {'percentage': '2'}: Slovak
#    border {'country': 'A', 'length': '362'}:
#    border {'country': 'D', 'length': '646'}:
#    border {'country': 'SK', 'length': '215'}:
#    border {'country': 'PL', 'length': '658'}:
#    province {'id': 'prov-Czech-1', 'country': 'CZ', 'capital': 'cty-Czech-2'}:
#
#    province {'id': 'prov-Czech-2', 'country': 'CZ', 'capital': 'cty-Czech-8'}:
#
#    province {'id': 'prov-Czech-3', 'country': 'CZ', 'capital': 'cty-Czech-3'}:
#
#    province {'id': 'prov-Czech-4', 'country': 'CZ', 'capital': 'cty-Czech-Karlovy'}:
#
#    province {'id': 'prov-Czech-5', 'country': 'CZ', 'capital': 'cty-Czech-Jihlava'}:
#
#    province {'id': 'prov-Czech-6', 'country': 'CZ', 'capital': 'cty-Czech-9'}:
#
#    province {'id': 'prov-Czech-7', 'country': 'CZ', 'capital': 'cty-Czech-11'}:
#
#    province {'id': 'prov-Czech-8', 'country': 'CZ', 'capital': 'cty-Czech-4'}:
#
#    province {'id': 'prov-Czech-9', 'country': 'CZ', 'capital': 'cty-Czech-5'}:
#
#    province {'id': 'prov-Czech-10', 'country': 'CZ', 'capital': 'cty-Czech-10'}:
#
#    province {'id': 'prov-Czech-11', 'country': 'CZ', 'capital': 'cty-Czech-7'}:
#
#    province {'id': 'prov-Czech-12', 'country': 'CZ', 'capital': 'cty-Czech-2'}:
#
#    province {'id': 'prov-Czech-13', 'country': 'CZ', 'capital': 'cty-Czech-Usti-nad-Labem'}:
#
#    province {'id': 'prov-Czech-14', 'country': 'CZ', 'capital': 'cty-Czech-6'}:
#
# country {'car_code': 'D', 'area': '356910', 'capital': 'cty-Germany-Berlin', 'memberships': 'org-AfDB org-UNAMID org-ADB org-AG org-BIS org-BSEC org-CDB org-SICA org-CD org-SELEC org-CE org-CBSS org-EMU org-EAPC org-EBRD org-ECB org-EIB org-CERN org-ESA org-EU org-EITI org-FATF org-FAO org-G-10 org-G-20 org-G-5 org-G-7 org-G-8 org-IADB org-IGAD org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICJ org-ICCt org-Interpol org-IDA org-IEA org-IFRCS org-IFC org-IFAD org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-ITSO org-ITU org-ITUC org-MIGA org-NATO org-NEA org-NSG org-OECD org-OSCE org-OPCW org-OAS org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UNMISS org-UNRWA org-UPU org-WCO org-WHO org-WIPO org-WMO org-UNWTO org-WTO org-ZC'}
#    name {}: Germany
#    localname {}: Bundesrepublik Deutschland (die)
#    population {'measured': 'census', 'year': '1950'}: 68230796
#    population {'year': '1997', 'measured': 'admin.'}: 82501000
#    population {'year': '2007', 'measured': 'admin.'}: 82217837
#    population {'year': '2011', 'measured': 'census'}: 80219695
#    population_growth {}: -0.18
#    infant_mortality {}: 3.46
#    gdp_total {}: 3593000
#    gdp_agri {}: 0.8
#    gdp_ind {}: 30.1
#    gdp_serv {}: 69
#    inflation {}: 1.6
#    unemployment {}: 5.3
#    indep_date {}: 1871-01-18
#    government {}: federal republic
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '91.5'}: German
#    ethnicgroup {'percentage': '2.4'}: Turkish
#    religion {'percentage': '34'}: Roman Catholic
#    religion {'percentage': '34'}: Protestant
#    religion {'percentage': '3.7'}: Muslim
#    language {'percentage': '100'}: German
#    border {'country': 'F', 'length': '451'}:
#    border {'country': 'A', 'length': '784'}:
#    border {'country': 'CZ', 'length': '646'}:
#    border {'country': 'CH', 'length': '334'}:
#    border {'country': 'PL', 'length': '456'}:
#    border {'country': 'B', 'length': '167'}:
#    border {'country': 'L', 'length': '138'}:
#    border {'country': 'NL', 'length': '577'}:
#    border {'country': 'DK', 'length': '68'}:
#    province {'id': 'prov-Germany-2', 'country': 'D', 'capital': 'cty-Germany-9'}:
#
#    province {'id': 'prov-Germany-3', 'country': 'D', 'capital': 'cty-Germany-Munich'}:
#
#    province {'id': 'prov-Germany-4', 'country': 'D', 'capital': 'cty-Germany-Berlin'}:
#
#    province {'id': 'prov-Germany-5', 'country': 'D', 'capital': 'cty-Germany-55'}:
#
#    province {'id': 'prov-Germany-6', 'country': 'D', 'capital': 'cty-Germany-11'}:
#
#    province {'id': 'prov-Germany-7', 'country': 'D', 'capital': 'cty-Germany-Hamburg'}:
#
#    province {'id': 'prov-Germany-8', 'country': 'D', 'capital': 'cty-Germany-26'}:
#
#    province {'id': 'prov-Germany-9', 'country': 'D', 'capital': 'cty-Germany-68'}:
#
#    province {'id': 'prov-Germany-10', 'country': 'D', 'capital': 'cty-Germany-Hannover'}:
#
#    province {'id': 'prov-Germany-11', 'country': 'D', 'capital': 'cty-Germany-10'}:
#
#    province {'id': 'prov-Germany-12', 'country': 'D', 'capital': 'cty-Germany-43'}:
#
#    province {'id': 'prov-Germany-13', 'country': 'D', 'capital': 'cty-Germany-42'}:
#
#    province {'id': 'prov-Germany-14', 'country': 'D', 'capital': 'cty-Germany-16'}:
#
#    province {'id': 'prov-Germany-15', 'country': 'D', 'capital': 'cty-Germany-28'}:
#
#    province {'id': 'prov-Germany-16', 'country': 'D', 'capital': 'cty-Germany-34'}:
#
#    province {'id': 'prov-Germany-17', 'country': 'D', 'capital': 'cty-Germany-39'}:
#
# country {'car_code': 'H', 'area': '93030', 'capital': 'cty-Hungary-Budapest', 'memberships': 'org-AG org-BIS org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EIB org-CERN org-ESA org-EU org-FAO org-G-9 org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICJ org-ICCt org-Interpol org-IDA org-IEA org-IFRCS org-IFC org-IFAD org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NATO org-NEA org-NSG org-OECD org-OSCE org-OPCW org-OAS org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-MINURSO org-UNFICYP org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO org-ZC'}
#    name {}: Hungary
#    localname {}: Magyar Köztársaság (a)
#    population {'measured': 'census', 'year': '1949'}: 9204799
#    population {'measured': 'census', 'year': '1960'}: 9961044
#    population {'measured': 'census', 'year': '1970'}: 10322099
#    population {'measured': 'census', 'year': '1980'}: 10709463
#    population {'measured': 'census', 'year': '1990'}: 10374823
#    population {'measured': 'census', 'year': '2001'}: 10198315
#    population {'measured': 'census', 'year': '2011'}: 9937628
#    population_growth {}: -0.21
#    infant_mortality {}: 5.09
#    gdp_total {}: 130600
#    gdp_agri {}: 3.4
#    gdp_ind {}: 28
#    gdp_serv {}: 68.7
#    inflation {}: 1.9
#    unemployment {}: 10.5
#    indep_date {'from': 'Austria-Hungary'}: 1918-11-18
#    government {}: parliamentary democracy
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '92.3'}: Hungarian
#    ethnicgroup {'percentage': '1.9'}: Roma
#    ethnicgroup {'percentage': '2'}: Serb
#    ethnicgroup {'percentage': '2.6'}: German
#    ethnicgroup {'percentage': '0.8'}: Slovak
#    ethnicgroup {'percentage': '0.7'}: Romanian
#    religion {'percentage': '51.9'}: Roman Catholic
#    religion {'percentage': '18.9'}: Protestant
#    language {'percentage': '93.6'}: Hungarian
#    border {'country': 'SRB', 'length': '151'}:
#    border {'country': 'A', 'length': '366'}:
#    border {'country': 'SK', 'length': '515'}:
#    border {'country': 'SLO', 'length': '102'}:
#    border {'country': 'UA', 'length': '103'}:
#    border {'country': 'HR', 'length': '329'}:
#    border {'country': 'RO', 'length': '443'}:
#    province {'id': 'prov-Hungary-2', 'country': 'H', 'capital': 'cty-Hungary-6'}:
#
#    province {'id': 'prov-Hungary-3', 'country': 'H', 'capital': 'cty-Hungary-10'}:
#
#    province {'id': 'prov-Hungary-4', 'country': 'H', 'capital': 'cty-Hungary-Bekescaba'}:
#
#    province {'id': 'prov-Hungary-5', 'country': 'H', 'capital': 'cty-Hungary-4'}:
#
#    province {'id': 'prov-Hungary-6', 'country': 'H', 'capital': 'cty-Hungary-Hodmezovasarhely'}:
#
#    province {'id': 'prov-Hungary-7', 'country': 'H', 'capital': 'cty-Hungary-9'}:
#
#    province {'id': 'prov-Hungary-8', 'country': 'H', 'capital': 'cty-Hungary-7'}:
#
#    province {'id': 'prov-Hungary-9', 'country': 'H', 'capital': 'cty-Hungary-3'}:
#
#    province {'id': 'prov-Hungary-10', 'country': 'H', 'capital': 'cty-Hungary-Eger'}:
#
#    province {'id': 'prov-Hungary-11', 'country': 'H', 'capital': 'cty-Hungary-Tatabanya'}:
#
#    province {'id': 'prov-Hungary-12', 'country': 'H', 'capital': 'cty-Hungary-Salgotarjan'}:
#
#    province {'id': 'prov-Hungary-13', 'country': 'H', 'capital': 'cty-Hungary-Budapest'}:
#
#    province {'id': 'prov-Hungary-14', 'country': 'H', 'capital': 'cty-Hungary-Kaposvar'}:
#
#    province {'id': 'prov-Hungary-15', 'country': 'H', 'capital': 'cty-Hungary-8'}:
#
#    province {'id': 'prov-Hungary-16', 'country': 'H', 'capital': 'cty-Hungary-Szolnok'}:
#
#    province {'id': 'prov-Hungary-17', 'country': 'H', 'capital': 'cty-Hungary-Szekszard'}:
#
#    province {'id': 'prov-Hungary-18', 'country': 'H', 'capital': 'cty-Hungary-Szombathely'}:
#
#    province {'id': 'prov-Hungary-19', 'country': 'H', 'capital': 'cty-Hungary-Veszprem'}:
#
#    province {'id': 'prov-Hungary-20', 'country': 'H', 'capital': 'cty-Hungary-Zalaegerszeg'}:
#
#    province {'id': 'prov-Hungary-21', 'country': 'H', 'capital': 'cty-Hungary-Budapest'}:
#
# country {'car_code': 'I', 'area': '301230', 'capital': 'cty-Italy-Rome', 'memberships': 'org-AfDB org-ADB org-AG org-BIS org-BSEC org-CDB org-SICA org-CEI org-CD org-SELEC org-CE org-CBSS org-EMU org-EAPC org-EBRD org-ECB org-EIB org-CERN org-ESA org-EU org-EITI org-FATF org-FAO org-G-10 org-G-20 org-G-7 org-G-8 org-IADB org-IGAD org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IEA org-IFRCS org-IFC org-IFAD org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-ITSO org-ITU org-ITUC org-LAIA org-MIGA org-NATO org-NEA org-NSG org-OECD org-OSCE org-OPCW org-OAS org-PIF org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UNMOGIP org-MINURSO org-UNMISS org-UNRWA org-UNTSO org-UPU org-WCO org-WHO org-WIPO org-WMO org-UNWTO org-WTO org-ZC'}
#    name {}: Italy
#    localname {}: Repubblica Italiana (la)
#    population {'measured': 'census', 'year': '1861'}: 22182377
#    population {'measured': 'census', 'year': '1871'}: 27303509
#    population {'measured': 'census', 'year': '1881'}: 28953480
#    population {'measured': 'census', 'year': '1901'}: 32965504
#    population {'measured': 'census', 'year': '1911'}: 35845048
#    population {'measured': 'census', 'year': '1921'}: 39943528
#    population {'measured': 'census', 'year': '1931'}: 41651000
#    population {'measured': 'census', 'year': '1936'}: 42943602
#    population {'measured': 'census', 'year': '1951'}: 47515537
#    population {'measured': 'census', 'year': '1961'}: 50623569
#    population {'measured': 'census', 'year': '1971'}: 54136547
#    population {'measured': 'census', 'year': '1981'}: 56556911
#    population {'measured': 'census', 'year': '1991'}: 56778031
#    population {'measured': 'census', 'year': '2001'}: 56995744
#    population {'measured': 'census', 'year': '2011'}: 59433744
#    population_growth {}: 0.3
#    infant_mortality {}: 3.31
#    gdp_total {}: 2068000
#    gdp_agri {}: 2
#    gdp_ind {}: 24.4
#    gdp_serv {}: 73.5
#    inflation {}: 1.2
#    unemployment {}: 12.4
#    indep_date {}: 1861-03-17
#    government {}: republic
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    religion {'percentage': '84.6'}: Roman Catholic
#    religion {'percentage': '2.0'}: Christian Orthodox
#    religion {'percentage': '0.9'}: Protestant
#    religion {'percentage': '2.1'}: Muslim
#    religion {'percentage': '0.3'}: Buddhist
#    religion {'percentage': '0.2'}: Hindu
#    language {'percentage': '98'}: Italian
#    language {'percentage': '0.7'}: German
#    language {'percentage': '0.2'}: French
#    language {'percentage': '0.2'}: Slovenian
#    language {'percentage': '0.1'}: Albanian
#    border {'country': 'F', 'length': '488'}:
#    border {'country': 'A', 'length': '430'}:
#    border {'country': 'SLO', 'length': '235'}:
#    border {'country': 'CH', 'length': '740'}:
#    border {'country': 'V', 'length': '3.2'}:
#    border {'country': 'RSM', 'length': '39'}:
#    province {'id': 'prov-Italy-2', 'country': 'I', 'capital': 'cty-Italy-5'}:
#
#    province {'id': 'prov-Italy-9', 'country': 'I', 'capital': 'cty-Italy-Aosta'}:
#
#    province {'id': 'prov-Italy-10', 'country': 'I', 'capital': 'cty-Italy-Milan'}:
#
#    province {'id': 'prov-Italy-20', 'country': 'I', 'capital': 'cty-Italy-51'}:
#
#    province {'id': 'prov-Italy-23', 'country': 'I', 'capital': 'cty-Italy-12'}:
#
#    province {'id': 'prov-Italy-31', 'country': 'I', 'capital': 'cty-Italy-16'}:
#
#    province {'id': 'prov-Italy-36', 'country': 'I', 'capital': 'cty-Italy-7'}:
#
#    province {'id': 'prov-Italy-41', 'country': 'I', 'capital': 'cty-Italy-8'}:
#
#    province {'id': 'prov-Italy-50', 'country': 'I', 'capital': 'cty-Italy-9'}:
#
#    province {'id': 'prov-Italy-60', 'country': 'I', 'capital': 'cty-Italy-27'}:
#
#    province {'id': 'prov-Italy-63', 'country': 'I', 'capital': 'cty-Italy-45'}:
#
#    province {'id': 'prov-Italy-68', 'country': 'I', 'capital': 'cty-Italy-Rome'}:
#
#    province {'id': 'prov-Italy-74', 'country': 'I', 'capital': 'cty-Italy-LAquila'}:
#
#    province {'id': 'prov-Italy-79', 'country': 'I', 'capital': 'cty-Italy-Campobasso'}:
#
#    province {'id': 'prov-Italy-82', 'country': 'I', 'capital': 'cty-Italy-4'}:
#
#    province {'id': 'prov-Italy-88', 'country': 'I', 'capital': 'cty-Italy-11'}:
#
#    province {'id': 'prov-Italy-94', 'country': 'I', 'capital': 'cty-Italy-Potenza'}:
#
#    province {'id': 'prov-Italy-97', 'country': 'I', 'capital': 'cty-Italy-41'}:
#
#    province {'id': 'prov-Italy-101', 'country': 'I', 'capital': 'cty-Italy-6'}:
#
#    province {'id': 'prov-Italy-111', 'country': 'I', 'capital': 'cty-Italy-18'}:
#
# country {'car_code': 'FL', 'area': '160', 'capital': 'cty-Liechtenstein-Vaduz', 'memberships': 'org-CD org-CE org-EBRD org-EFTA org-IPU org-IAEA org-ICJ org-ICCt org-Interpol org-IFRCS org-IOC org-ITSO org-ITU org-ITUC org-OSCE org-OPCW org-PCA org-UN org-UNCTAD org-UPU org-WIPO org-WTO'}
#    name {}: Liechtenstein
#    localname {}: Fürstentum Liechtenstein (das)
#    population {'measured': 'census', 'year': '1950'}: 13757
#    population {'measured': 'census', 'year': '1960'}: 16628
#    population {'measured': 'census', 'year': '1970'}: 21350
#    population {'measured': 'census', 'year': '1980'}: 25215
#    population {'measured': 'census', 'year': '1990'}: 29032
#    population {'year': '2001', 'measured': 'admin.'}: 33525
#    population {'year': '2006', 'measured': 'admin.'}: 35174
#    population {'year': '2012', 'measured': 'admin.'}: 36636
#    population_growth {}: 0.82
#    infant_mortality {}: 4.33
#    gdp_total {}: 5113
#    gdp_agri {}: 8
#    gdp_ind {}: 37
#    gdp_serv {}: 55
#    inflation {}: -0.7
#    unemployment {}: 2.3
#    indep_date {'from': 'Holy Roman Empire'}: 1806-07-12
#    government {}: hereditary constitutional monarchy
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '5'}: Italian
#    ethnicgroup {'percentage': '95'}: Alemannic
#    religion {'percentage': '76.2'}: Roman Catholic
#    religion {'percentage': '7'}: Protestant
#    language {'percentage': '100'}: German
#    border {'country': 'A', 'length': '37'}:
#    border {'country': 'CH', 'length': '41'}:
#    city {'id': 'cty-Liechtenstein-Vaduz', 'country': 'FL'}:
#
# country {'car_code': 'SK', 'area': '48845', 'capital': 'cty-Slovakia-Bratislava', 'memberships': 'org-AG org-BIS org-BSEC org-CEI org-CD org-CE org-CBSS org-EMU org-EAPC org-EBRD org-ECB org-EIB org-CERN org-EU org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICJ org-ICCt org-Interpol org-IDA org-IEA org-IFRCS org-IFC org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-OIF org-ITU org-ITUC org-MIGA org-NATO org-NEA org-NSG org-OECD org-OSCE org-OPCW org-OAS org-PCA org-UN org-UNCTAD org-UNESCO org-UNIDO org-UNFICYP org-UNTSO org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO org-ZC'}
#    name {}: Slovakia
#    population {'measured': 'est.', 'year': '1950'}: 3436574
#    population {'measured': 'est.', 'year': '1960'}: 4137224
#    population {'measured': 'est.', 'year': '1970'}: 4531874
#    population {'measured': 'est.', 'year': '1980'}: 4988654
#    population {'measured': 'est.', 'year': '1990'}: 5277709
#    population {'measured': 'est.', 'year': '2000'}: 5388010
#    population {'year': '2001', 'measured': 'census'}: 5379455
#    population {'year': '2011', 'measured': 'census'}: 5397036
#    population_growth {}: 0.03
#    infant_mortality {}: 5.35
#    gdp_total {}: 96960
#    gdp_agri {}: 3.1
#    gdp_ind {}: 30.8
#    gdp_serv {}: 67
#    inflation {}: 1.7
#    unemployment {}: 14.4
#    indep_date {'from': 'Czechoslovakia'}: 1993-01-01
#    government {}: parliamentary democracy
#    encompassed {'continent': 'europe', 'percentage': '100'}:
#    ethnicgroup {'percentage': '85.7'}: Slovak
#    ethnicgroup {'percentage': '9.7'}: Hungarian
#    ethnicgroup {'percentage': '1.7'}: Roma
#    ethnicgroup {'percentage': '1'}: Czech
#    ethnicgroup {'percentage': '0.3'}: Ukrainian
#    ethnicgroup {'percentage': '0.3'}: Ruthenian
#    ethnicgroup {'percentage': '0.1'}: German
#    ethnicgroup {'percentage': '0.1'}: Polish
# ...
#    elevation {}: 546
#    gmtOffset {}: -6
# airport {'iatacode': 'AEX', 'city': 'cty-United-States-168', 'country': 'USA'}
#    name {}: Alexandria Intl
#    latitude {}: 31.3274
#    longitude {}: -92.549833
#    elevation {}: 27
#    gmtOffset {}: -6
# airport {'iatacode': 'TLH', 'city': 'cty-United-States-141', 'country': 'USA'}
#    name {}: Tallahassee Rgnl
#    latitude {}: 30.396528
#    longitude {}: -84.350333
#    elevation {}: 25
#    gmtOffset {}: -5
# airport {'iatacode': 'ACT', 'city': 'cty-United-States-194', 'country': 'USA'}
#    name {}: Waco Rgnl
#    latitude {}: 31.611289
#    longitude {}: -97.230519
#    elevation {}: 157
#    gmtOffset {}: -6
# airport {'iatacode': 'ABQ', 'city': 'cty-United-States-38', 'country': 'USA'}
#    name {}: Albuquerque International Sunport
#    latitude {}: 35.0402222
#    longitude {}: -106.6091944
#    elevation {}: 1633
#    gmtOffset {}: -7
# airport {'iatacode': 'SAN', 'city': 'cty-United-States-7', 'country': 'USA'}
#    name {}: San Diego Intl
#    latitude {}: 32.733556
#    longitude {}: -117.189667
#    elevation {}: 5
#    gmtOffset {}: -8
# airport {'iatacode': 'SAT', 'city': 'cty-United-States-9', 'country': 'USA'}
#    name {}: San Antonio Intl
#    latitude {}: 29.533694
#    longitude {}: -98.469778
#    elevation {}: 247
#    gmtOffset {}: -6
# airport {'iatacode': 'SAV', 'city': 'cty-Georgia-Savannah', 'country': 'USA'}
#    name {}: Savannah Hilton Head Intl
#    latitude {}: 32.127583
#    longitude {}: -81.202139
#    elevation {}: 16
#    gmtOffset {}: -5
# airport {'iatacode': 'PWM', 'city': 'cty-United-States-28', 'country': 'USA'}
#    name {}: Portland Intl Jetport
#    latitude {}: 43.646161
#    longitude {}: -70.309281
#    elevation {}: 23
#    gmtOffset {}: -5
# airport {'iatacode': 'PVD', 'city': 'cty-United-States-122', 'country': 'USA'}
#    name {}: Theodore Francis Green State
#    latitude {}: 41.732581
#    longitude {}: -71.420383
#    elevation {}: 17
#    gmtOffset {}: -5
# airport {'iatacode': 'IND', 'city': 'cty-United-States-13', 'country': 'USA'}
#    name {}: Indianapolis Intl
#    latitude {}: 39.717331
#    longitude {}: -86.294383
#    elevation {}: 243
#    gmtOffset {}: -5
# airport {'iatacode': 'IAD', 'city': 'cty-United-States-22', 'country': 'USA'}
#    name {}: Washington Dulles Intl
#    latitude {}: 38.944533
#    longitude {}: -77.455811
#    elevation {}: 95
#    gmtOffset {}: -5
# airport {'iatacode': 'IAH', 'city': 'cty-United-States-5', 'country': 'USA'}
#    name {}: George Bush Intcntl Houston
#    latitude {}: 29.984433
#    longitude {}: -95.341442
#    elevation {}: 30
#    gmtOffset {}: -6
# airport {'iatacode': 'ICT', 'city': 'cty-United-States-53', 'country': 'USA'}
#    name {}: Wichita Mid Continent
#    latitude {}: 37.649944
#    longitude {}: -97.433056
#    elevation {}: 406
#    gmtOffset {}: -6
# airport {'iatacode': 'HOU', 'city': 'cty-United-States-5', 'country': 'USA'}
#    name {}: William P Hobby
#    latitude {}: 29.645419
#    longitude {}: -95.278889
#    elevation {}: 14
#    gmtOffset {}: -6
# airport {'iatacode': 'ROC', 'city': 'cty-United-States-74', 'country': 'USA'}
#    name {}: Greater Rochester Intl
#    latitude {}: 43.118866
#    longitude {}: -77.672389
#    elevation {}: 170
#    gmtOffset {}: -5
# airport {'iatacode': 'FLL', 'city': 'cty-United-States-124', 'country': 'USA'}
#    name {}: Fort Lauderdale Hollywood Intl
#    latitude {}: 26.072583
#    longitude {}: -80.15275
#    elevation {}: 3
#    gmtOffset {}: -5
# airport {'iatacode': 'OMA', 'city': 'cty-United-States-46', 'country': 'USA'}
#    name {}: Eppley Afld
#    latitude {}: 41.303167
#    longitude {}: -95.894069
#    elevation {}: 300
#    gmtOffset {}: -6
# airport {'iatacode': 'PDX', 'city': 'cty-United-States-28', 'country': 'USA'}
#    name {}: Portland Intl
#    latitude {}: 45.588722
#    longitude {}: -122.5975
#    elevation {}: 9
#    gmtOffset {}: -8
# airport {'iatacode': 'ORF', 'city': 'cty-United-States-71', 'country': 'USA'}
#    name {}: Norfolk Intl
#    latitude {}: 36.894611
#    longitude {}: -76.201222
#    elevation {}: 8
#    gmtOffset {}: -5
# airport {'iatacode': 'ORD', 'city': 'cty-United-States-4', 'country': 'USA'}
#    name {}: Chicago Ohare Intl
#    latitude {}: 41.978603
#    longitude {}: -87.904842
#    elevation {}: 204
#    gmtOffset {}: -6
# airport {'iatacode': 'FNT', 'city': 'cty-United-States-145', 'country': 'USA'}
#    name {}: Bishop International
#    latitude {}: 42.965424
#    longitude {}: -83.743629
#    elevation {}: 238
#    gmtOffset {}: -5
# airport {'iatacode': 'PHX', 'city': 'cty-United-States-8', 'country': 'USA'}
#    name {}: Phoenix Sky Harbor Intl
#    latitude {}: 33.434278
#    longitude {}: -112.011583
#    elevation {}: 346
#    gmtOffset {}: -7
# airport {'iatacode': 'PIT', 'city': 'cty-United-States-49', 'country': 'USA'}
#    name {}: Pittsburgh Intl
#    latitude {}: 40.491467
#    longitude {}: -80.232872
#    elevation {}: 367
#    gmtOffset {}: -5
# airport {'iatacode': 'PIR', 'city': 'cty-United-States-Pierre', 'country': 'USA'}
#    name {}: Pierre Regional Airport
#    latitude {}: 44.3827
#    longitude {}: -100.286
#    elevation {}: 531
#    gmtOffset {}: -6
# airport {'iatacode': 'PHL', 'city': 'cty-United-States-6', 'country': 'USA'}
#    name {}: Philadelphia Intl
#    latitude {}: 39.871944
#    longitude {}: -75.241139
#    elevation {}: 11
#    gmtOffset {}: -5
# airport {'iatacode': 'HLN', 'city': 'cty-United-States-Helena', 'country': 'USA'}
#    name {}: Helena Rgnl
#    latitude {}: 46.606806
#    longitude {}: -111.98275
#    elevation {}: 1182
#    gmtOffset {}: -7
# airport {'iatacode': 'GEG', 'city': 'cty-United-States-96', 'country': 'USA'}
#    name {}: Spokane Intl
#    latitude {}: 47.619861
#    longitude {}: -117.533833
#    elevation {}: 724
#    gmtOffset {}: -8
# airport {'iatacode': 'OKC', 'city': 'cty-United-States-31', 'country': 'USA'}
#    name {}: Will Rogers World
#    latitude {}: 35.393089
#    longitude {}: -97.600733
#    elevation {}: 395
#    gmtOffset {}: -6
# airport {'iatacode': 'RIC', 'city': 'cty-United-States-81', 'country': 'USA'}
#    name {}: Richmond Intl
#    latitude {}: 37.505167
#    longitude {}: -77.319667
#    elevation {}: 51
#    gmtOffset {}: -5
# airport {'iatacode': 'JFK', 'city': 'cty-United-States-2', 'country': 'USA'}
#    name {}: John F Kennedy Intl
#    latitude {}: 40.639751
#    longitude {}: -73.778925
#    elevation {}: 4
#    gmtOffset {}: -5
# airport {'iatacode': 'JAX', 'city': 'cty-United-States-15', 'country': 'USA'}
#    name {}: Jacksonville Intl
#    latitude {}: 30.494056
#    longitude {}: -81.687861
#    elevation {}: 9
#    gmtOffset {}: -5
# airport {'iatacode': 'JAN', 'city': 'cty-United-States-87', 'country': 'USA'}
#    name {}: Jackson Evers Intl
#    latitude {}: 32.311167
#    longitude {}: -90.075889
#    elevation {}: 105
#    gmtOffset {}: -6
# airport {'iatacode': 'SAF', 'city': 'cty-United-States-Santa-Fe', 'country': 'USA'}
#    name {}: Santa Fe Muni
#    latitude {}: 35.617108
#    longitude {}: -106.089422
#    elevation {}: 1935
#    gmtOffset {}: -7
# airport {'iatacode': 'OAJ', 'city': 'cty-United-States-15', 'country': 'USA'}
#    name {}: Albert J Ellis
#    latitude {}: 34.829164
#    longitude {}: -77.612139
#    elevation {}: 29
#    gmtOffset {}: -5
# airport {'iatacode': 'OAK', 'city': 'cty-United-States-44', 'country': 'USA'}
#    name {}: Metropolitan Oakland Intl
#    latitude {}: 37.721278
#    longitude {}: -122.220722
#    elevation {}: 3
#    gmtOffset {}: -8
# airport {'iatacode': 'JNU', 'city': 'cty-United-States-Juneau', 'country': 'USA'}
#    name {}: Juneau Intl
#    latitude {}: 58.354972
#    longitude {}: -134.576278
#    elevation {}: 6
#    gmtOffset {}: -9
# airport {'iatacode': 'ANC', 'city': 'cty-United-States-67', 'country': 'USA'}
#    name {}: Ted Stevens Anchorage Intl
#    latitude {}: 61.174361
#    longitude {}: -149.996361
#    elevation {}: 46
#    gmtOffset {}: -9
# airport {'iatacode': 'HNL', 'city': 'cty-United-States-36', 'country': 'USA'}
#    name {}: Honolulu Intl
#    latitude {}: 21.318681
#    longitude {}: -157.922428
#    elevation {}: 4
#    gmtOffset {}: -10
#    located_on {'island': 'island-Oahu'}:
# airport {'iatacode': 'ITO', 'city': 'stadt-Hilo-USA-HI', 'country': 'USA'}
#    name {}: Hilo Intl
#    latitude {}: 19.721375
#    longitude {}: -155.048469
#    elevation {}: 12
#    gmtOffset {}: -10
#    located_on {'island': 'island-Hawaii'}:
# airport {'iatacode': 'LNY', 'country': 'USA'}
#    name {}: Lanai
#    latitude {}: 20.785611
#    longitude {}: -156.951419
#    elevation {}: 399
#    gmtOffset {}: -10
#    located_on {'island': 'island-Lanai'}:
# airport {'iatacode': 'MKK', 'country': 'USA'}
#    name {}: Molokai
#    latitude {}: 21.152886
#    longitude {}: -157.096256
#    elevation {}: 138
#    gmtOffset {}: -10
#    located_on {'island': 'island-Molokai'}:
# airport {'iatacode': 'OGG', 'country': 'USA'}
#    name {}: Kahului
#    latitude {}: 20.89865
#    longitude {}: -156.430458
#    elevation {}: 16
#    gmtOffset {}: -10
#    located_on {'island': 'island-Maui'}:
# airport {'iatacode': 'MVD', 'city': 'cty-Uruguay-Montevideo', 'country': 'ROU'}
#    name {}: Carrasco Intl
#    latitude {}: -34.838417
#    longitude {}: -56.030806
#    elevation {}: 32
#    gmtOffset {}: -3
# airport {'iatacode': 'BHK', 'city': 'cty-Uzbekistan-6', 'country': 'UZB'}
#    name {}: Bukhara
#    latitude {}: 39.775
#    longitude {}: 64.483333
#    elevation {}: 229
#    gmtOffset {}: 5
# airport {'iatacode': 'UGC', 'city': 'cty-Uzbekistan-13', 'country': 'UZB'}
#    name {}: Urgench Airport
#    latitude {}: 41.5843
#    longitude {}: 60.6417
#    elevation {}: 98
#    gmtOffset {}: 5
# airport {'iatacode': 'TMJ', 'city': 'cty-Uzbekistan-Termiz', 'country': 'UZB'}
#    name {}: Termez Airport
#    latitude {}: 37.286667
#    longitude {}: 67.31
#    elevation {}: 313
#    gmtOffset {}: 5
# airport {'iatacode': 'TAS', 'city': 'cty-Uzbekistan-Tashkent', 'country': 'UZB'}
#    name {}: Yuzhny
#    latitude {}: 41.257861
#    longitude {}: 69.281186
#    elevation {}: 432
#    gmtOffset {}: 5
# airport {'iatacode': 'NCU', 'city': 'cty-Uzbekistan-9', 'country': 'UZB'}
#    name {}: Nukus Airport
#    latitude {}: 42.4884
#    longitude {}: 59.6233
#    elevation {}: 75
#    gmtOffset {}: 5
# airport {'iatacode': 'FEG', 'city': 'cty-Uzbekistan-7', 'country': 'UZB'}
#    name {}: Fergana Airport
#    latitude {}: 40.3588
#    longitude {}: 71.745
#    elevation {}: 604
#    gmtOffset {}: 5
# airport {'iatacode': 'SKD', 'city': 'cty-Uzbekistan-3', 'country': 'UZB'}
#    name {}: Samarkand
#    latitude {}: 39.700547
#    longitude {}: 66.983829
#    elevation {}: 678
#    gmtOffset {}: 5
# airport {'iatacode': 'VLI', 'city': 'cty-Vanuatu-Port-Vila', 'country': 'VU'}
#    name {}: Port Vila Bauerfield
#    latitude {}: -17.699325
#    longitude {}: 168.319794
#    elevation {}: 21
#    gmtOffset {}: 11
#    located_on {'island': 'island-Efate'}:
# airport {'iatacode': 'PZO', 'city': 'cty-Venezuela-6', 'country': 'YV'}
#    name {}: General Manuel Carlos Piar
#    latitude {}: 8.288528
#    longitude {}: -62.760361
#    elevation {}: 144
#    gmtOffset {}: -4
# airport {'iatacode': 'BLA', 'city': 'cty-Venezuela-10', 'country': 'YV'}
#    name {}: General Jose Antonio Anzoategui Intl
#    latitude {}: 10.107139
#    longitude {}: -64.689161
#    elevation {}: 8
#    gmtOffset {}: -4
# airport {'iatacode': 'PYH', 'city': 'cty-Venezuela-Puerto-Ayacucho', 'country': 'YV'}
#    name {}: Casique Aramare
#    latitude {}: 5.619992
#    longitude {}: -67.606103
#    elevation {}: 75
#    gmtOffset {}: -4
# airport {'iatacode': 'BNS', 'city': 'cty-Venezuela-19', 'country': 'YV'}
#    name {}: Barinas
#    latitude {}: 8.619575
#    longitude {}: -70.220825
#    elevation {}: 203
#    gmtOffset {}: -4
# airport {'iatacode': 'BRM', 'city': 'cty-Venezuela-5', 'country': 'YV'}
#    name {}: Barquisimeto Intl
#    latitude {}: 10.042747
#    longitude {}: -69.358619
#    elevation {}: 623
#    gmtOffset {}: -4
# airport {'iatacode': 'MAR', 'city': 'cty-Venezuela-Maracaibo', 'country': 'YV'}
#    name {}: La Chinita Intl
#    latitude {}: 10.558208
#    longitude {}: -71.727856
#    elevation {}: 72
#    gmtOffset {}: -4
# airport {'iatacode': 'VLN', 'city': 'cty-Venezuela-4', 'country': 'YV'}
#    name {}: Arturo Michelena Intl
#    latitude {}: 10.149733
#    longitude {}: -67.9284
#    elevation {}: 432
#    gmtOffset {}: -4
# airport {'iatacode': 'MUN', 'city': 'cty-Venezuela-13', 'country': 'YV'}
#    name {}: Maturin
#    latitude {}: 9.749067
#    longitude {}: -63.1534
#    elevation {}: 68
#    gmtOffset {}: -4
# airport {'iatacode': 'CCS', 'city': 'cty-Venezuela-Caracas', 'country': 'YV'}
#    name {}: Simon Bolivar Intl
#    latitude {}: 10.603117
#    longitude {}: -66.990583
#    elevation {}: 72
#    gmtOffset {}: -4
# airport {'iatacode': 'VKG', 'city': 'cty-Vietnam-20', 'country': 'VN'}
#    name {}: Rach Gia
#    latitude {}: 9.949676
#    longitude {}: 105.133659
#    elevation {}: 2
#    gmtOffset {}: 7
# airport {'iatacode': 'VII', 'city': 'cty-Vietnam-18', 'country': 'VN'}
#    name {}: Vinh Airport
#    latitude {}: 18.737569
#    longitude {}: 105.670764
#    elevation {}: 7
#    gmtOffset {}: 7
# airport {'iatacode': 'SGN', 'city': 'cty-Vietnam-2', 'country': 'VN'}
#    name {}: Tansonnhat Intl
#    latitude {}: 10.818797
#    longitude {}: 106.651856
#    elevation {}: 10
#    gmtOffset {}: 7
# airport {'iatacode': 'HAN', 'city': 'cty-Vietnam-Hanoi', 'country': 'VN'}
#    name {}: Noibai Intl
#    latitude {}: 21.221192
#    longitude {}: 105.807178
#    elevation {}: 12
#    gmtOffset {}: 7
# airport {'iatacode': 'HPH', 'city': 'cty-Vietnam-4', 'country': 'VN'}
#    name {}: Cat Bi International Airport
#    latitude {}: 20.819386
#    longitude {}: 106.724989
#    elevation {}: 2
#    gmtOffset {}: 7
# airport {'iatacode': 'VCA', 'city': 'cty-Vietnam-6', 'country': 'VN'}
#    name {}: Tra Noc Airport
#    latitude {}: 10.085119
#    longitude {}: 105.711922
#    elevation {}: 3
#    gmtOffset {}: 7
# airport {'iatacode': 'NHA', 'city': 'cty-Vietnam-7', 'country': 'VN'}
#    name {}: Nha Trang
#    latitude {}: 12.227467
#    longitude {}: 109.192322
#    elevation {}: 6
#    gmtOffset {}: 7
# airport {'iatacode': 'STT', 'city': 'cty-VIRG-Charlotte-Amalie', 'country': 'VIRG'}
#    name {}: Cyril E King
#    latitude {}: 18.337306
#    longitude {}: -64.973361
#    elevation {}: 7
#    gmtOffset {}: -4
#    located_on {'island': 'island-SaintThomas'}:
# airport {'iatacode': 'WLS', 'city': 'city-Mata-Utu-WAFU-WAFU', 'country': 'WAFU'}
#    name {}: Wallis
#    latitude {}: -13.238281
#    longitude {}: -176.199228
#    elevation {}: 24
#    gmtOffset {}: 12
#    located_on {'island': 'island-Uvea'}:
# airport {'iatacode': 'EUN', 'city': 'stadt-El_Aaiun-DARS-DARS', 'country': 'WSA'}
#    name {}: Hassan I Airport
#    latitude {}: 27.1517
#    longitude {}: -13.2192
#    elevation {}: 63
#    gmtOffset {}: 0
# airport {'iatacode': 'SAH', 'city': 'cty-Yemen-Sanaa', 'country': 'YE'}
#    name {}: Sanaa Intl
#    latitude {}: 15.476258
#    longitude {}: 44.219739
#    elevation {}: 2200
#    gmtOffset {}: 3
# airport {'iatacode': 'HOD', 'city': 'cty-Yemen-Hodeida', 'country': 'YE'}
#    name {}: Hodeidah Intl
#    latitude {}: 14.753
#    longitude {}: 42.976336
#    elevation {}: 13
#    gmtOffset {}: 3
# airport {'iatacode': 'TAI', 'city': 'cty-Yemen-Taiz', 'country': 'YE'}
#    name {}: Taiz Intl
#    latitude {}: 13.685964
#    longitude {}: 44.139056
#    elevation {}: 1475
#    gmtOffset {}: 3
# airport {'iatacode': 'ADE', 'city': 'cty-Yemen-Aden', 'country': 'YE'}
#    name {}: Aden Intl
#    latitude {}: 12.829542
#    longitude {}: 45.028792
#    elevation {}: 2
#    gmtOffset {}: 3
# airport {'iatacode': 'LVI', 'city': 'cty-Zambia-Livingstone', 'country': 'Z'}
#    name {}: Livingstone
#    latitude {}: -17.821756
#    longitude {}: 25.822692
#    elevation {}: 1007
#    gmtOffset {}: 2
# airport {'iatacode': 'NLA', 'city': 'cty-Zambia-3', 'country': 'Z'}
#    name {}: Ndola
#    latitude {}: -12.998139
#    longitude {}: 28.664944
#    elevation {}: 1270
#    gmtOffset {}: 2
# airport {'iatacode': 'LUN', 'city': 'cty-Zambia-2', 'country': 'Z'}
#    name {}: Lusaka Intl
#    latitude {}: -15.330817
#    longitude {}: 28.452628
#    elevation {}: 1152
#    gmtOffset {}: 2
# airport {'iatacode': 'BUQ', 'city': 'cty-Zimbabwe-2', 'country': 'ZW'}
#    name {}: J M Nkomo Intl
#    latitude {}: -20.017431
#    longitude {}: 28.617869
#    elevation {}: 1329
#    gmtOffset {}: 2
# airport {'iatacode': 'HRE', 'city': 'cty-Zimbabwe-1', 'country': 'ZW'}
#    name {}: Harare Intl
#    latitude {}: -17.931806
#    longitude {}: 31.092847
#    elevation {}: 1490
#    gmtOffset {}: 2

# %%
# print names of all countries and their infant_mortality rate
for element in root.iter('country'):
    if element.find('infant_mortality') is None:
        print(element.find('name').text + ': N/A' )
    else:
        print(element.find('name').text + ': ' + element.find('infant_mortality').text)
# Out:
# Albania: 13.19
# Greece: 4.78
# Macedonia: 7.9
# Serbia: 6.16
# Montenegro: N/A
# Kosovo: N/A
# Andorra: 3.69
# France: 3.31
# Spain: 3.33
# Austria: 4.16
# Czech Republic: 2.63
# Germany: 3.46
# Hungary: 5.09
# Italy: 3.31
# Liechtenstein: 4.33
# Slovakia: 5.35
# Slovenia: 4.04
# Switzerland: 3.73
# Belarus: 3.64
# Latvia: 7.91
# Lithuania: 6
# Poland: 6.19
# Ukraine: 8.1
# Russia: 7.08
# Belgium: 4.18
# Luxembourg: 4.28
# Netherlands: 3.66
# Bosnia and Herzegovina: 5.84
# Croatia: 5.87
# Bulgaria: 15.08
# Romania: 10.16
# Turkey: 21.43
# Denmark: 4.1
# Estonia: 6.7
# Faroe Islands: 5.71
# Finland: 3.36
# Norway: 2.48
# Sweden: 2.6
# Monaco: 1.81
# Gibraltar: 6.29
# Guernsey: 3.47
# Holy See: N/A
# Ceuta: N/A
# Melilla: N/A
# Iceland: 3.15
# Ireland: 3.74
# San Marino: 4.52
# Jersey: 3.86
# Malta: 3.59
# Isle of Man: 4.17
# Moldova: 12.93
# Portugal: 4.48
# Svalbard: N/A
# United Kingdom: 4.44
# Afghanistan: 117.23
# China: 14.79
# Iran: 39
# Pakistan: 57.48
# Tajikistan: 35.03
# Turkmenistan: 38.13
# Uzbekistan: 19.84
# Armenia: 13.97
# Georgia: 16.68
# Azerbaijan: 26.67
# Bahrain: 9.68
# Bangladesh: 45.67
# Myanmar: 44.91
# India: 43.19
# Bhutan: 37.89
# Brunei: 10.48
# Malaysia: 13.69
# Laos: 54.53
# Thailand: 9.86
# Cambodia: 51.36
# Vietnam: 18.99
# Kazakhstan: 21.61
# North Korea: 24.5
# Kyrgyzstan: 28.71
# Hong Kong: 2.73
# Macao: 3.13
# Mongolia: 23.15
# Nepal: 40.43
# Christmas Island: N/A
# Cocos Islands: N/A
# Cyprus: 8.54
# Gaza Strip: 30.6
# Israel: 3.98
# Egypt: 22.41
# Indonesia: 25.16
# Timor-Leste: 38.79
# Papua New Guinea: 39.67
# Iraq: 37.53
# Jordan: 15.73
# Kuwait: 7.51
# Saudi Arabia: 14.58
# Syria: 15.79
# Lebanon: 7.98
# West Bank: 28.6
# Japan: 2.13
# South Korea: 3.93
# Maldives: 24.59
# Oman: 14
# United Arab Emirates: 10.92
# Yemen: 50.41
# Philippines: 17.64
# Qatar: 6.42
# Singapore: 2.53
# Sri Lanka: 9.02
# Taiwan: 4.49
# Anguilla: 3.4
# Antigua and Barbuda: 13.29
# Aruba: 11.74
# Bahamas: 12.5
# Barbados: 10.93
# Belize: 20.31
# Guatemala: 23.51
# Mexico: 12.58
# Bermuda: 2.48
# British Virgin Islands: 13.45
# Canada: 4.71
# United States: 6.17
# Cayman Islands: 6.21
# Costa Rica: 8.7
# Nicaragua: 20.36
# Panama: 10.7
# Cuba: 4.7
# Dominica: 11.61
# Dominican Republic: 19.63
# Haiti: 49.43
# El Salvador: 18.44
# Honduras: 18.72
# Greenland: 9.42
# Grenada: 10.5
# Guadeloupe: 8.3
# Jamaica: 13.69
# Martinique: 7.1
# Montserrat: 13.66
# Curacao: N/A
# Sint Maarten: 9.05
# Saint Martin: N/A
# Saint Barthelemy: N/A
# Colombia: 15.02
# Puerto Rico: 7.73
# Saint Kitts and Nevis: 8.98
# Saint Lucia: 11.75
# Saint Pierre and Miquelon: 6.95
# Saint Vincent and the Grenadines: 13.07
# Trinidad and Tobago: 24.82
# Turks and Caicos Islands: 10.97
# Virgin Islands: 6.79
# American Samoa: 8.92
# Australia: 4.43
# Cook Islands: 14.33
# Fiji: 10.2
# French Polynesia: 4.78
# Guam: 5.51
# Kiribati: 35.37
# Marshall Islands: 21.39
# Micronesia: 21.93
# Nauru: 8.21
# New Caledonia: 5.46
# New Zealand: 4.59
# Niue: N/A
# Norfolk Island: N/A
# Northern Mariana Islands: 5.5
# Palau: 11.46
# Pitcairn: N/A
# Solomon Islands: 16.17
# Tonga: 12.36
# Tuvalu: 31.69
# Tokelau: N/A
# Vanuatu: 16.41
# Wallis and Futuna: 4.49
# Samoa: 20.5
# Argentina: 9.96
# Bolivia: 38.61
# Brazil: 19.21
# Chile: 7.02
# Paraguay: 20.75
# Uruguay: 8.97
# Peru: 20.21
# French Guiana: 14.6
# Guyana: 33.56
# Suriname: 27.07
# Venezuela: 19.33
# Ecuador: 17.93
# Falkland Islands: N/A
# Algeria: 21.76
# Libya: 11.87
# Mali: 104.34
# Mauritania: 56.06
# Morocco: 24.52
# Niger: 86.27
# Tunisia: 23.19
# Western Sahara: 145.82
# Angola: 79.99
# Congo: 59.34
# Namibia: 45.64
# Zaire: 73.15
# Zambia: 66.62
# Benin: 57.09
# Burkina Faso: 76.8
# Nigeria: 74.09
# Togo: 46.73
# Botswana: 9.38
# South Africa: 41.61
# Zimbabwe: 26.55
# Cote dIvoire: 60.16
# Ghana: 38.52
# Burundi: 63.44
# Rwanda: 59.59
# Tanzania: 43.74
# Cameroon: 55.1
# Central African Republic: 92.86
# Chad: 90.3
# Equatorial Guinea: 71.12
# Gabon: 47.03
# Cape Verde: 24.28
# Sudan: 52.86
# South Sudan: 68.16
# Comoros: 65.31
# Guinea: 55.24
# Liberia: 69.19
# Djibouti: 50.2
# Eritrea: 38.44
# Ethiopia: 55.77
# Somalia: 100.14
# Kenya: 40.71
# Gambia: 65.74
# Senegal: 52.72
# Guinea-Bissau: 90.92
# Sierra Leone: 73.29
# Uganda: 60.82
# Lesotho: 50.48
# Madagascar: 44.88
# Malawi: 48.01
# Mozambique: 72.42
# Mauritius: 10.59
# Mayotte: 56.29
# Swaziland: 54.82
# Reunion: 7.5
# Saint Helena: 17.63
# Sao Tome and Principe: 49.16
# Seychelles: 10.77

# %%
# build a list of list elements to create dataframe
list = []
for element in root.iter('country'):
    if element.find('infant_mortality') is None:
        l = [element.find('name').text,element.find('infant_mortality')]
    else:
        l = [element.find('name').text,float(element.find('infant_mortality').text)]
    list.append(l)
    
list
# Out:
# [['Albania', 13.19],
#  ['Greece', 4.78],
#  ['Macedonia', 7.9],
#  ['Serbia', 6.16],
#  ['Montenegro', None],
#  ['Kosovo', None],
#  ['Andorra', 3.69],
#  ['France', 3.31],
#  ['Spain', 3.33],
#  ['Austria', 4.16],
#  ['Czech Republic', 2.63],
#  ['Germany', 3.46],
#  ['Hungary', 5.09],
#  ['Italy', 3.31],
#  ['Liechtenstein', 4.33],
#  ['Slovakia', 5.35],
#  ['Slovenia', 4.04],
#  ['Switzerland', 3.73],
#  ['Belarus', 3.64],
#  ['Latvia', 7.91],
#  ['Lithuania', 6.0],
#  ['Poland', 6.19],
#  ['Ukraine', 8.1],
#  ['Russia', 7.08],
#  ['Belgium', 4.18],
#  ['Luxembourg', 4.28],
#  ['Netherlands', 3.66],
#  ['Bosnia and Herzegovina', 5.84],
#  ['Croatia', 5.87],
#  ['Bulgaria', 15.08],
#  ['Romania', 10.16],
#  ['Turkey', 21.43],
#  ['Denmark', 4.1],
#  ['Estonia', 6.7],
#  ['Faroe Islands', 5.71],
#  ['Finland', 3.36],
#  ['Norway', 2.48],
#  ['Sweden', 2.6],
#  ['Monaco', 1.81],
#  ['Gibraltar', 6.29],
#  ['Guernsey', 3.47],
#  ['Holy See', None],
#  ['Ceuta', None],
#  ['Melilla', None],
#  ['Iceland', 3.15],
#  ['Ireland', 3.74],
#  ['San Marino', 4.52],
#  ['Jersey', 3.86],
#  ['Malta', 3.59],
#  ['Isle of Man', 4.17],
#  ['Moldova', 12.93],
#  ['Portugal', 4.48],
#  ['Svalbard', None],
#  ['United Kingdom', 4.44],
#  ['Afghanistan', 117.23],
#  ['China', 14.79],
#  ['Iran', 39.0],
#  ['Pakistan', 57.48],
#  ['Tajikistan', 35.03],
#  ['Turkmenistan', 38.13],
#  ['Uzbekistan', 19.84],
#  ['Armenia', 13.97],
#  ['Georgia', 16.68],
#  ['Azerbaijan', 26.67],
#  ['Bahrain', 9.68],
#  ['Bangladesh', 45.67],
#  ['Myanmar', 44.91],
#  ['India', 43.19],
#  ['Bhutan', 37.89],
#  ['Brunei', 10.48],
#  ['Malaysia', 13.69],
#  ['Laos', 54.53],
#  ['Thailand', 9.86],
#  ['Cambodia', 51.36],
#  ['Vietnam', 18.99],
#  ['Kazakhstan', 21.61],
#  ['North Korea', 24.5],
#  ['Kyrgyzstan', 28.71],
#  ['Hong Kong', 2.73],
#  ['Macao', 3.13],
#  ['Mongolia', 23.15],
#  ['Nepal', 40.43],
#  ['Christmas Island', None],
#  ['Cocos Islands', None],
#  ['Cyprus', 8.54],
#  ['Gaza Strip', 30.6],
#  ['Israel', 3.98],
#  ['Egypt', 22.41],
#  ['Indonesia', 25.16],
#  ['Timor-Leste', 38.79],
#  ['Papua New Guinea', 39.67],
#  ['Iraq', 37.53],
#  ['Jordan', 15.73],
#  ['Kuwait', 7.51],
#  ['Saudi Arabia', 14.58],
#  ['Syria', 15.79],
#  ['Lebanon', 7.98],
#  ['West Bank', 28.6],
#  ['Japan', 2.13],
#  ['South Korea', 3.93],
#  ['Maldives', 24.59],
#  ['Oman', 14.0],
#  ['United Arab Emirates', 10.92],
#  ['Yemen', 50.41],
#  ['Philippines', 17.64],
#  ['Qatar', 6.42],
#  ['Singapore', 2.53],
#  ['Sri Lanka', 9.02],
#  ['Taiwan', 4.49],
#  ['Anguilla', 3.4],
#  ['Antigua and Barbuda', 13.29],
#  ['Aruba', 11.74],
#  ['Bahamas', 12.5],
#  ['Barbados', 10.93],
#  ['Belize', 20.31],
#  ['Guatemala', 23.51],
#  ['Mexico', 12.58],
#  ['Bermuda', 2.48],
#  ['British Virgin Islands', 13.45],
#  ['Canada', 4.71],
#  ['United States', 6.17],
#  ['Cayman Islands', 6.21],
#  ['Costa Rica', 8.7],
#  ['Nicaragua', 20.36],
#  ['Panama', 10.7],
#  ['Cuba', 4.7],
#  ['Dominica', 11.61],
#  ['Dominican Republic', 19.63],
#  ['Haiti', 49.43],
#  ['El Salvador', 18.44],
#  ['Honduras', 18.72],
#  ['Greenland', 9.42],
#  ['Grenada', 10.5],
#  ['Guadeloupe', 8.3],
#  ['Jamaica', 13.69],
#  ['Martinique', 7.1],
#  ['Montserrat', 13.66],
#  ['Curacao', None],
#  ['Sint Maarten', 9.05],
#  ['Saint Martin', None],
#  ['Saint Barthelemy', None],
#  ['Colombia', 15.02],
#  ['Puerto Rico', 7.73],
#  ['Saint Kitts and Nevis', 8.98],
#  ['Saint Lucia', 11.75],
#  ['Saint Pierre and Miquelon', 6.95],
#  ['Saint Vincent and the Grenadines', 13.07],
#  ['Trinidad and Tobago', 24.82],
#  ['Turks and Caicos Islands', 10.97],
#  ['Virgin Islands', 6.79],
#  ['American Samoa', 8.92],
#  ['Australia', 4.43],
#  ['Cook Islands', 14.33],
#  ['Fiji', 10.2],
#  ['French Polynesia', 4.78],
#  ['Guam', 5.51],
#  ['Kiribati', 35.37],
#  ['Marshall Islands', 21.39],
#  ['Micronesia', 21.93],
#  ['Nauru', 8.21],
#  ['New Caledonia', 5.46],
#  ['New Zealand', 4.59],
#  ['Niue', None],
#  ['Norfolk Island', None],
#  ['Northern Mariana Islands', 5.5],
#  ['Palau', 11.46],
#  ['Pitcairn', None],
#  ['Solomon Islands', 16.17],
#  ['Tonga', 12.36],
#  ['Tuvalu', 31.69],
#  ['Tokelau', None],
#  ['Vanuatu', 16.41],
#  ['Wallis and Futuna', 4.49],
#  ['Samoa', 20.5],
#  ['Argentina', 9.96],
#  ['Bolivia', 38.61],
#  ['Brazil', 19.21],
#  ['Chile', 7.02],
#  ['Paraguay', 20.75],
#  ['Uruguay', 8.97],
#  ['Peru', 20.21],
#  ['French Guiana', 14.6],
#  ['Guyana', 33.56],
#  ['Suriname', 27.07],
#  ['Venezuela', 19.33],
#  ['Ecuador', 17.93],
#  ['Falkland Islands', None],
#  ['Algeria', 21.76],
#  ['Libya', 11.87],
#  ['Mali', 104.34],
#  ['Mauritania', 56.06],
#  ['Morocco', 24.52],
#  ['Niger', 86.27],
#  ['Tunisia', 23.19],
#  ['Western Sahara', 145.82],
#  ['Angola', 79.99],
#  ['Congo', 59.34],
#  ['Namibia', 45.64],
#  ['Zaire', 73.15],
#  ['Zambia', 66.62],
#  ['Benin', 57.09],
#  ['Burkina Faso', 76.8],
#  ['Nigeria', 74.09],
#  ['Togo', 46.73],
#  ['Botswana', 9.38],
#  ['South Africa', 41.61],
#  ['Zimbabwe', 26.55],
#  ['Cote dIvoire', 60.16],
#  ['Ghana', 38.52],
#  ['Burundi', 63.44],
#  ['Rwanda', 59.59],
#  ['Tanzania', 43.74],
#  ['Cameroon', 55.1],
#  ['Central African Republic', 92.86],
#  ['Chad', 90.3],
#  ['Equatorial Guinea', 71.12],
#  ['Gabon', 47.03],
#  ['Cape Verde', 24.28],
#  ['Sudan', 52.86],
#  ['South Sudan', 68.16],
#  ['Comoros', 65.31],
#  ['Guinea', 55.24],
#  ['Liberia', 69.19],
#  ['Djibouti', 50.2],
#  ['Eritrea', 38.44],
#  ['Ethiopia', 55.77],
#  ['Somalia', 100.14],
#  ['Kenya', 40.71],
#  ['Gambia', 65.74],
#  ['Senegal', 52.72],
#  ['Guinea-Bissau', 90.92],
#  ['Sierra Leone', 73.29],
#  ['Uganda', 60.82],
#  ['Lesotho', 50.48],
#  ['Madagascar', 44.88],
#  ['Malawi', 48.01],
#  ['Mozambique', 72.42],
#  ['Mauritius', 10.59],
#  ['Mayotte', 56.29],
#  ['Swaziland', 54.82],
#  ['Reunion', 7.5],
#  ['Saint Helena', 17.63],
#  ['Sao Tome and Principe', 49.16],
#  ['Seychelles', 10.77]]

# %%
df = pd.DataFrame(list,columns=['country','infant_mortality'])
df.head()
# Out:
#       country  infant_mortality
# 0     Albania             13.19
# 1      Greece              4.78
# 2   Macedonia              7.90
# 3      Serbia              6.16
# 4  Montenegro               NaN

# %%
# 1. 10 countries with the lowest infant mortality rates
df = df.sort_values('infant_mortality')
df.head(10)
# Out:
#             country  infant_mortality
# 38           Monaco              1.81
# 98            Japan              2.13
# 117         Bermuda              2.48
# 36           Norway              2.48
# 106       Singapore              2.53
# 37           Sweden              2.60
# 10   Czech Republic              2.63
# 78        Hong Kong              2.73
# 79            Macao              3.13
# 44          Iceland              3.15

# %%
root[0][32][5].attrib
# Out:
# {'measured': 'estimate', 'year': '1990'}

# %%
# build a list of list elements to create dataframe
list = []

for element in root.iter('city'):
    sub_list = element.findall('population')
    
    for item in sub_list:
        if item is None:
            l = [element.find('name').text,item]
        else:
            l = [element.find('name').text,int(item.text)]
            
        list.append(l)
    
list
# Out:
# [['Tirana', 192000],
#  ['Tirana', 244153],
#  ['Tirana', 418495],
#  ['Shkodër', 62000],
#  ['Shkodër', 77075],
#  ['Durrës', 60000],
#  ['Durrës', 113249],
#  ['Vlorë', 56000],
#  ['Vlorë', 79513],
#  ['Elbasan', 53000],
#  ['Elbasan', 78703],
#  ['Korçë', 52000],
#  ['Korçë', 51152],
#  ['Kavala', 56705],
#  ['Kavala', 60187],
#  ['Kavala', 63774],
#  ['Kavala', 58790],
#  ['Athina', 885737],
#  ['Athina', 816556],
#  ['Athina', 789166],
#  ['Athina', 664046],
#  ['Peiraias', 196389],
#  ['Peiraias', 187399],
#  ['Peiraias', 181933],
#  ['Peiraias', 163688],
#  ['Peristeri', 141971],
#  ['Peristeri', 146743],
#  ['Peristeri', 139981],
#  ['Acharnes', 65035],
#  ['Acharnes', 82555],
#  ['Acharnes', 106943],
#  ['Patra', 142163],
#  ['Patra', 190463],
#  ['Patra', 210494],
#  ['Patra', 213984],
#  ['Kerkyra', 101236],
#  ['Kerkyra', 108652],
#  ['Kerkyra', 102071],
#  ['Ioannina', 92425],
#  ['Ioannina', 103101],
#  ['Ioannina', 112486],
#  ['Thessaloniki', 406413],
#  ['Thessaloniki', 424220],
#  ['Thessaloniki', 397156],
#  ['Thessaloniki', 325182],
#  ['Iraklio', 102398],
#  ['Iraklio', 146536],
#  ['Iraklio', 163115],
#  ['Iraklio', 173993],
#  ['Chania', 83712],
#  ['Chania', 98202],
#  ['Chania', 108642],
#  ['Rhodes', 96159],
#  ['Rhodes', 115334],
#  ['Rhodes', 115490],
#  ['Lamia', 75315],
#  ['Chalkida', 85573],
#  ['Chalkida', 92809],
#  ['Chalkida', 102223],
#  ['Larissa', 102426],
#  ['Larissa', 129429],
#  ['Larissa', 145981],
#  ['Larissa', 162591],
#  ['Volos', 71378],
#  ['Volos', 132917],
#  ['Volos', 142923],
#  ['Volos', 144449],
#  ['Karyes', 233],
#  ['Skopje', 506926],
#  ['Skopje', 514967],
#  ['Kumanovo', 105484],
#  ['Kumanovo', 107745],
#  ['Beograd', 1407073],
#  ['Beograd', 1576124],
#  ['Beograd', 1639121],
#  ['Novi Sad', 299294],
#  ['Novi Sad', 335701],
#  ['Niš', 250518],
#  ['Niš', 257867],
#  ['Podgorica', 136473],
#  ['Podgorica', 150977],
#  ['Prishtine', 148090],
#  ['Prishtine', 199654],
#  ['Prishtine', 198214],
#  ['Andorra la Vella', 15600],
#  ['Andorra la Vella', 20787],
#  ['Andorra la Vella', 22256],
#  ['Strasbourg', 252338],
#  ['Strasbourg', 264115],
#  ['Strasbourg', 276867],
#  ['Strasbourg', 272222],
#  ['Mulhouse', 108357],
#  ['Mulhouse', 110359],
#  ['Mulhouse', 112260],
#  ['Mulhouse', 110351],
#  ['Bordeaux', 210336],
#  ['Bordeaux', 215363],
#  ['Bordeaux', 235878],
#  ['Bordeaux', 239399],
#  ['Clermont-Ferrand', 136181],
#  ['Clermont-Ferrand', 137140],
#  ['Clermont-Ferrand', 142449],
#  ['Clermont-Ferrand', 140957],
#  ['Caen', 112846],
#  ['Caen', 113987],
#  ['Caen', 113249],
#  ['Caen', 108793],
#  ['Rennes', 197536],
#  ['Rennes', 206229],
#  ['Rennes', 214813],
#  ['Rennes', 208033],
#  ['Brest', 147956],
#  ['Brest', 149634],
#  ['Brest', 148316],
#  ['Brest', 140547],
#  ['Dijon', 146703],
#  ['Dijon', 149867],
#  ['Dijon', 155340],
#  ['Dijon', 151672],
#  ['Orléans', 105111],
#  ['Orléans', 113126],
#  ['Orléans', 116256],
#  ['Orléans', 114185],
#  ['Tours', 129509],
#  ['Tours', 132820],
#  ['Tours', 140252],
#  ['Tours', 134633],
#  ['Reims', 180620],
#  ['Reims', 187206],
#  ['Reims', 188078],
#  ['Reims', 180752],
#  ['Ajaccio', 58949],
#  ['Ajaccio', 52880],
#  ['Ajaccio', 64432],
#  ['Ajaccio', 66245],
#  ['Besançon', 113828],
#  ['Besançon', 117733],
#  ['Besançon', 121012],
#  ['Besançon', 115879],
#  ['Rouen', 102723],
#  ['Rouen', 106592],
#  ['Rouen', 110276],
#  ['Rouen', 111553],
#  ['Le Havre', 195854],
#  ['Le Havre', 190905],
#  ['Le Havre', 185311],
#  ['Le Havre', 174156],
#  ['Paris', 2152423],
#  ['Paris', 2125246],
#  ['Paris', 2201578],
#  ['Paris', 2249975],
#  ['Boulogne-Billancourt', 101743],
#  ['Boulogne-Billancourt', 106367],
#  ['Boulogne-Billancourt', 111280],
#  ['Boulogne-Billancourt', 116220],
#  ['Argenteuil', 104189],
#  ['Argenteuil', 104282],
#  ['Montreuil', 102369],
#  ['Montreuil', 103068],
#  ['Saint-Paul', 87712],
#  ['Saint-Paul', 100818],
#  ['Saint-Paul', 103916],
#  ['Montpellier', 207996],
#  ['Montpellier', 225392],
#  ['Montpellier', 254974],
#  ['Montpellier', 264538],
#  ['Nîmes', 128471],
#  ['Nîmes', 133424],
#  ['Nîmes', 147114],
#  ['Nîmes', 144940],
#  ['Perpignan', 105983],
#  ['Perpignan', 105115],
#  ['Perpignan', 117500],
#  ['Perpignan', 118238],
#  ['Limoges', 133464],
#  ['Limoges', 133968],
#  ['Limoges', 139026],
#  ['Limoges', 137758],
#  ['Metz', 119594],
#  ['Metz', 123776],
#  ['Metz', 126706],
#  ['Metz', 119962],
#  ['Nancy', 99351],
#  ['Nancy', 103605],
#  ['Nancy', 107434],
#  ['Nancy', 105382],
#  ['Toulouse', 358688],
#  ['Toulouse', 390350],
#  ['Toulouse', 444392],
#  ['Toulouse', 447340],
#  ['Lille', 172142],
#  ['Lille', 212597],
#  ['Lille', 232432],
#  ['Lille', 227533],
#  ['Nantes', 244995],
#  ['Nantes', 270251],
#  ['Nantes', 290871],
#  ['Nantes', 287845],
#  ['Angers', 141404],
#  ['Angers', 151279],
#  ['Angers', 156965],
#  ['Angers', 148803],
#  ['Le Mans', 145502],
#  ['Le Mans', 146105],
#  ['Le Mans', 148169],
#  ['Le Mans', 143240],
#  ['Amiens', 131872],
#  ['Amiens', 135501],
#  ['Amiens', 139271],
#  ['Amiens', 133327],
#  ['Poitiers', 78894],
#  ['Poitiers', 83448],
#  ['Poitiers', 89253],
#  ['Poitiers', 87646],
#  ['Marseille', 800550],
#  ['Marseille', 798430],
#  ['Marseille', 847084],
#  ['Marseille', 850636],
#  ['Nice', 342439],
#  ['Nice', 342738],
#  ['Nice', 350735],
#  ['Nice', 344064],
#  ['Toulon', 167619],
#  ['Toulon', 160639],
#  ['Toulon', 170041],
#  ['Toulon', 163974],
#  ['Aix-en-Provence', 123842],
#  ['Aix-en-Provence', 134222],
#  ['Aix-en-Provence', 145721],
#  ['Aix-en-Provence', 140684],
#  ['Lyon', 415487],
#  ['Lyon', 445452],
#  ['Lyon', 480778],
#  ['Lyon', 491268],
#  ['Grenoble', 150758],
#  ['Grenoble', 153317],
#  ['Grenoble', 158746],
#  ['Grenoble', 157424],
#  ['Saint-Étienne', 199396],
#  ['Saint-Étienne', 180210],
#  ['Saint-Étienne', 180773],
#  ['Saint-Étienne', 170049],
#  ['Villeurbanne', 116872],
#  ['Villeurbanne', 124215],
#  ['Villeurbanne', 138596],
#  ['Villeurbanne', 145034],
#  ['Sevilla', 701927],
#  ['Sevilla', 714148],
#  ['Sevilla', 684633],
#  ['Sevilla', 698042],
#  ['Almería', 168025],
#  ['Almería', 167361],
#  ['Almería', 166328],
#  ['Almería', 189680],
#  ['Cádiz', 143129],
#  ['Cádiz', 155438],
#  ['Cádiz', 133363],
#  ['Cádiz', 124014],
#  ['Córdoba', 309961],
#  ['Córdoba', 315948],
#  ['Córdoba', 308072],
#  ['Córdoba', 328326],
#  ['Granada', 241471],
#  ['Granada', 271180],
#  ['Granada', 240661],
#  ['Granada', 241003],
#  ['Huelva', 139991],
#  ['Huelva', 145049],
#  ['Huelva', 142284],
#  ['Huelva', 147808],
#  ['Málaga', 528079],
#  ['Málaga', 531443],
#  ['Málaga', 524414],
#  ['Málaga', 561435],
#  ['Jerez de la Frontera', 181602],
#  ['Jerez de la Frontera', 190390],
#  ['Jerez de la Frontera', 183273],
#  ['Jerez de la Frontera', 211784],
#  ['Jaén', 107184],
#  ['Jaén', 112772],
#  ['Jaén', 112590],
#  ['Jaén', 116469],
#  ['Algeciras', 101972],
#  ['Algeciras', 103787],
#  ['Algeciras', 101468],
#  ['Algeciras', 117695],
#  ['Marbella', 98377],
#  ['Marbella', 100036],
#  ['Marbella', 135124],
#  ['Dos Hermanas', 92506],
#  ['Dos Hermanas', 101988],
#  ['Dos Hermanas', 128433],
#  ['Zaragoza', 603367],
#  ['Zaragoza', 606620],
#  ['Zaragoza', 614905],
#  ['Zaragoza', 678115],
#  ['Oviedo', 199549],
#  ['Oviedo', 201712],
#  ['Oviedo', 201154],
#  ['Oviedo', 225005],
#  ['Gijón', 265491],
#  ['Gijón', 269644],
#  ['Gijón', 266419],
#  ['Gijón', 276969],
#  ['Palma de Mallorca', 319181],
#  ['Palma de Mallorca', 322008],
#  ['Palma de Mallorca', 333801],
#  ['Palma de Mallorca', 402044],
#  ['Vitoria-Gasteiz', 216527],
#  ['Vitoria-Gasteiz', 214148],
#  ['Vitoria-Gasteiz', 216852],
#  ['Vitoria-Gasteiz', 240753],
#  ['Bilbao', 358467],
#  ['Bilbao', 371876],
#  ['Bilbao', 349972],
#  ['Bilbao', 351356],
#  ['Barakaldo', 98649],
#  ['Barakaldo', 103594],
#  ['Barakaldo', 94478],
#  ['Barakaldo', 100064],
#  ['Donostia', 178229],
#  ['Donostia', 177929],
#  ['Donostia', 178377],
#  ['Donostia', 185512],
#  ['Santa Cruz de Tenerife', 211930],
#  ['Santa Cruz de Tenerife', 203929],
#  ['Santa Cruz de Tenerife', 188477],
#  ['Santa Cruz de Tenerife', 204476],
#  ['San Cristóbal de La Laguna', 127945],
#  ['San Cristóbal de La Laguna', 125183],
#  ['San Cristóbal de La Laguna', 128822],
#  ['San Cristóbal de La Laguna', 152025],
#  ['Las Palmas de Gran Canaria', 352641],
#  ['Las Palmas de Gran Canaria', 371787],
#  ['Las Palmas de Gran Canaria', 354863],
#  ['Las Palmas de Gran Canaria', 381271],
#  ['Telde', 83733],
#  ['Telde', 87949],
#  ['Telde', 101080],
#  ['Santander', 184165],
#  ['Santander', 194822],
#  ['Santander', 180717],
#  ['Santander', 178095],
#  ['Valladolid', 319946],
#  ['Valladolid', 336917],
#  ['Valladolid', 316580],
#  ['Valladolid', 311682],
#  ['Burgos', 161984],
#  ['Burgos', 166251],
#  ['Burgos', 166187],
#  ['Burgos', 178864],
#  ['León', 139809],
#  ['León', 147311],
#  ['León', 130916],
#  ['León', 131411],
#  ['Salamanca', 158457],
#  ['Salamanca', 167382],
#  ['Salamanca', 156368],
#  ['Salamanca', 151658],
#  ['Albacete', 145454],
#  ['Albacete', 141179],
#  ['Albacete', 148934],
#  ['Albacete', 171999],
#  ['Barcelona', 1505581],
#  ['Barcelona', 1630867],
#  ['Barcelona', 1503884],
#  ['Barcelona', 1611013],
#  ['Lleida', 112207],
#  ['Lleida', 114234],
#  ['Lleida', 112199],
#  ['Lleida', 137283],
#  ['Tarragona', 112795],
#  ['Tarragona', 114630],
#  ['Tarragona', 113129],
#  ['Tarragona', 133223],
#  ['Reus', 89034],
#  ['Reus', 89006],
#  ['Reus', 106849],
#  ['Hospitalet de Llobregat', 248521],
#  ['Hospitalet de Llobregat', 266242],
#  ['Hospitalet de Llobregat', 239019],
#  ['Hospitalet de Llobregat', 256509],
#  ['Badalona', 209606],
#  ['Badalona', 219340],
#  ['Badalona', 205836],
#  ['Badalona', 219241],
#  ['Sabadell', 184859],
#  ['Sabadell', 189006],
#  ['Sabadell', 183788],
#  ['Sabadell', 206949],
#  ['Terrassa', 165654],
#  ['Terrassa', 161428],
#  ['Terrassa', 173775],
#  ['Terrassa', 214406],
#  ['Santa Coloma de Gramenet', 120958],
#  ['Santa Coloma de Gramenet', 131764],
#  ['Santa Coloma de Gramenet', 112992],
#  ['Santa Coloma de Gramenet', 119391],
#  ['Mataró', 103265],
#  ['Mataró', 102117],
#  ['Mataró', 106358],
#  ['Mataró', 123367],
#  ['Badajoz', 134710],
#  ['Badajoz', 130153],
#  ['Badajoz', 133519],
#  ['Badajoz', 151214],
#  ['A Coruña', 243134],
#  ['A Coruña', 255087],
#  ['A Coruña', 236379],
#  ['A Coruña', 245053],
#  ['Vigo', 283110],
#  ['Vigo', 288573],
#  ['Vigo', 280186],
#  ['Vigo', 295623],
#  ['Ourense', 107965],
#  ['Ourense', 108547],
#  ['Ourense', 107510],
#  ['Ourense', 107314],
#  ['Madrid', 2881506],
#  ['Madrid', 3041101],
#  ['Madrid', 2938723],
#  ['Madrid', 3198645],
#  ['Móstoles', 195311],
#  ['Móstoles', 199141],
#  ['Móstoles', 196524],
#  ['Móstoles', 203493],
#  ['Leganés', 173163],
#  ['Leganés', 178162],
#  ['Leganés', 173584],
#  ['Leganés', 185758],
#  ['Alcalá de Henares', 163831],
#  ['Alcalá de Henares', 166250],
#  ['Alcalá de Henares', 176434],
#  ['Alcalá de Henares', 200505],
#  ['Fuenlabrada', 167458],
#  ['Fuenlabrada', 158212],
#  ['Fuenlabrada', 182705],
#  ['Fuenlabrada', 196986],
#  ['Getafe', 143629],
#  ['Getafe', 144368],
#  ['Getafe', 151479],
#  ['Getafe', 168642],
#  ['Alcorcón', 143970],
#  ['Alcorcón', 142165],
#  ['Alcorcón', 153100],
#  ['Alcorcón', 167217],
#  ['Torrejón de Ardoz', 91186],
#  ['Torrejón de Ardoz', 97887],
#  ['Torrejón de Ardoz', 123213],
#  ['Parla', 79213],
#  ['Parla', 122045],
#  ['Alcobendas', 86146],
#  ['Alcobendas', 92090],
#  ['Alcobendas', 110351],
#  ['Murcia', 349040],
#  ['Murcia', 341531],
#  ['Murcia', 370745],
#  ['Murcia', 437667],
#  ['Cartagena', 175628],
#  ['Cartagena', 179659],
#  ['Cartagena', 184686],
#  ['Cartagena', 215757],
#  ['Pamplona', 171150],
#  ['Pamplona', 182465],
#  ['Pamplona', 183964],
#  ['Pamplona', 195943],
#  ['Logroño', 125617],
#  ['Logroño', 124823],
#  ['Logroño', 133058],
#  ['Logroño', 152698],
#  ['Valencia', 739412],
#  ['Valencia', 764293],
#  ['Valencia', 738441],
#  ['Valencia', 792054],
#  ['Alicante', 272432],
#  ['Alicante', 274964],
#  ['Alicante', 284580],
#  ['Alicante', 329325],
#  ['Elche', 191713],
#  ['Elche', 191305],
#  ['Elche', 194767],
#  ['Elche', 227417],
#  ['Castellón de la Plana', 137741],
#  ['Castellón de la Plana', 139094],
#  ['Castellón de la Plana', 147667],
#  ['Castellón de la Plana', 176298],
#  ['Eisenstadt', 10102],
#  ['Eisenstadt', 10349],
#  ['Eisenstadt', 11332],
#  ['Eisenstadt', 13101],
#  ['Eisenstadt', 13485],
#  ['Klagenfurt', 87321],
#  ['Klagenfurt', 89415],
#  ['Klagenfurt', 90141],
#  ['Klagenfurt', 93949],
#  ['Klagenfurt', 96531],
#  ['Villach', 54640],
#  ['Villach', 57497],
#  ['Villach', 59089],
#  ['Villach', 59942],
#  ['Wien', 1539848],
#  ['Wien', 1583000],
#  ['Wien', 1550123],
#  ['Wien', 1698822],
#  ['Wien', 1761738],
#  ['Linz', 203044],
#  ['Linz', 203000],
#  ['Linz', 183904],
#  ['Linz', 189311],
#  ['Linz', 193511],
#  ['Wels', 52594],
#  ['Wels', 56478],
#  ['Wels', 58574],
#  ['Wels', 59239],
#  ['Innsbruck', 118112],
#  ['Innsbruck', 118000],
#  ['Innsbruck', 113392],
#  ['Innsbruck', 119249],
#  ['Innsbruck', 124386],
#  ['Graz', 237810],
#  ['Graz', 238000],
#  ['Graz', 226244],
#  ['Graz', 257328],
#  ['Graz', 269211],
#  ['Salzburg', 143978],
#  ['Salzburg', 144000],
#  ['Salzburg', 142662],
#  ['Salzburg', 147571],
#  ['Salzburg', 146676],
#  ['St. Pölten', 51102],
#  ['St. Pölten', 50026],
#  ['St. Pölten', 49121],
#  ['St. Pölten', 51688],
#  ['St. Pölten', 52100],
#  ['Praha', 1215000],
#  ['Praha', 1169106],
#  ['Praha', 1289556],
#  ['České Budějovice', 174000],
#  ['České Budějovice', 97339],
#  ['České Budějovice', 95589],
#  ['Brno', 393000],
#  ['Brno', 376172],
#  ['Brno', 404820],
#  ['Karlovy Vary', 53358],
#  ['Karlovy Vary', 53310],
#  ['Jihlava', 50702],
#  ['Jihlava', 51162],
#  ['Hradec Králové', 164000],
#  ['Hradec Králové', 97155],
#  ['Hradec Králové', 95594],
#  ['Liberec', 160000],
#  ['Liberec', 99102],
#  ['Liberec', 104973],
#  ['Ostrava', 332000],
#  ['Ostrava', 316744],
#  ['Ostrava', 311508],
#  ['Olomouc', 225000],
#  ['Olomouc', 102607],
#  ['Olomouc', 101954],
#  ['Pardubice', 163000],
#  ['Pardubice', 90889],
#  ['Pardubice', 90844],
#  ['Plzeň', 175000],
#  ['Plzeň', 166118],
#  ['Plzeň', 171346],
#  ['Ústí nad Labem', 95436],
#  ['Ústí nad Labem', 98596],
#  ['Zlín', 198000],
#  ['Zlín', 78833],
#  ['Zlín', 77137],
#  ['Stuttgart', 551904],
#  ['Stuttgart', 599415],
#  ['Stuttgart', 582443],
#  ['Stuttgart', 585890],
#  ['Mannheim', 295191],
#  ['Mannheim', 318446],
#  ['Mannheim', 307730],
#  ['Mannheim', 290117],
#  ['Karlsruhe', 260591],
#  ['Karlsruhe', 279329],
#  ['Karlsruhe', 277204],
#  ['Karlsruhe', 289173],
#  ['Freiburg', 178672],
#  ['Freiburg', 209628],
#  ['Heidelberg', 127768],
#  ['Heidelberg', 146751],
#  ['Heilbronn', 110970],
#  ['Heilbronn', 116059],
#  ['Pforzheim', 106530],
#  ['Pforzheim', 114411],
#  ['Ulm', 103494],
#  ['Ulm', 116761],
#  ['Reutlingen', 98853],
#  ['Reutlingen', 109799],
#  ['München', 1185421],
#  ['München', 1256638],
#  ['München', 1210223],
#  ['München', 1348335],
#  ['Nürnberg', 470943],
#  ['Nürnberg', 500198],
#  ['Nürnberg', 488400],
#  ['Nürnberg', 486314],
#  ['Augsburg', 242819],
#  ['Augsburg', 264852],
#  ['Augsburg', 254982],
#  ['Augsburg', 267767],
#  ['Würzburg', 123378],
#  ['Würzburg', 124297],
#  ['Regensburg', 118639],
#  ['Regensburg', 135403],
#  ['Ingolstadt', 96071],
#  ['Ingolstadt', 124927],
#  ['Fürth', 97480],
#  ['Fürth', 115613],
#  ['Erlangen', 99808],
#  ['Erlangen', 103719],
#  ['Berlin', 3260000],
#  ['Berlin', 3465748],
#  ['Berlin', 3382169],
#  ['Berlin', 3292365],
#  ['Potsdam', 156021],
#  ['Cottbus', 99984],
#  ['Bremen', 533455],
#  ['Bremen', 554377],
#  ['Bremen', 539403],
#  ['Bremen', 542707],
#  ['Bremerhaven', 126629],
#  ['Bremerhaven', 108156],
#  ['Hamburg', 1592770],
#  ['Hamburg', 1688785],
#  ['Hamburg', 1715392],
#  ['Hamburg', 1706696],
#  ['Wiesbaden', 251871],
#  ['Wiesbaden', 268069],
#  ['Wiesbaden', 270109],
#  ['Wiesbaden', 269121],
#  ['Frankfurt am Main', 618266],
#  ['Frankfurt am Main', 663952],
#  ['Frankfurt am Main', 646550],
#  ['Frankfurt am Main', 667925],
#  ['Kassel', 187288],
#  ['Kassel', 190765],
#  ['Darmstadt', 134272],
#  ['Darmstadt', 143499],
#  ['Offenbach am Main', 111386],
#  ['Offenbach am Main', 113443],
#  ['Schwerin', 128328],
#  ['Schwerin', 91293],
#  ['Rostock', 249349],
#  ['Rostock', 200265],
#  ['Hannover', 494864],
#  ['Hannover', 523627],
#  ['Hannover', 515001],
#  ['Hannover', 506416],
#  ['Braunschweig', 252351],
#  ['Braunschweig', 242537],
#  ['Osnabrück', 150807],
#  ['Osnabrück', 153699],
#  ['Oldenburg', 140149],
#  ['Oldenburg', 157267],
#  ['Göttingen', 114698],
#  ['Göttingen', 115843],
#  ['Wolfsburg', 124896],
#  ['Wolfsburg', 119984],
#  ['Salzgitter', 111069],
#  ['Salzgitter', 98895],
#  ['Hildesheim', 103449],
#  ['Hildesheim', 99554],
#  ['Düsseldorf', 563531],
#  ['Düsseldorf', 578135],
#  ['Düsseldorf', 569364],
#  ['Düsseldorf', 586291],
#  ['Köln', 928309],
#  ['Köln', 960631],
#  ['Köln', 962884],
#  ['Köln', 1005775],
#  ['Essen', 623427],
#  ['Essen', 627269],
#  ['Essen', 595243],
#  ['Essen', 566201],
#  ['Dortmund', 584089],
#  ['Dortmund', 600669],
#  ['Dortmund', 588994],
#  ['Dortmund', 571143],
#  ['Duisburg', 525378],
#  ['Duisburg', 539094],
#  ['Duisburg', 514915],
#  ['Duisburg', 488468],
#  ['Bochum', 386271],
#  ['Bochum', 400356],
#  ['Bochum', 391147],
#  ['Bochum', 362286],
#  ['Wuppertal', 365662],
#  ['Wuppertal', 388102],
#  ['Wuppertal', 366434],
#  ['Wuppertal', 342661],
#  ['Bielefeld', 305566],
#  ['Bielefeld', 324287],
#  ['Bielefeld', 321758],
#  ['Bielefeld', 326870],
#  ['Gelsenkirchen', 287508],
#  ['Gelsenkirchen', 295368],
#  ['Gelsenkirchen', 278695],
#  ['Gelsenkirchen', 258766],
#  ['Bonn', 276653],
#  ['Bonn', 298227],
#  ['Bonn', 302247],
#  ['Bonn', 305765],
#  ['Mönchengladbach', 249587],
#  ['Mönchengladbach', 265069],
#  ['Mönchengladbach', 263014],
#  ['Mönchengladbach', 255188],
#  ['Münster', 246186],
#  ['Münster', 267072],
#  ['Münster', 265609],
#  ['Münster', 289576],
#  ['Krefeld', 232261],
#  ['Krefeld', 222247],
#  ['Aachen', 229740],
#  ['Aachen', 236420],
#  ['Oberhausen', 220286],
#  ['Oberhausen', 210216],
#  ['Hagen', 209363],
#  ['Hagen', 187944],
#  ['Hamm', 171170],
#  ['Hamm', 176037],
#  ['Herne', 174238],
#  ['Herne', 155160],
#  ['Mülheim an der Ruhr', 176423],
#  ['Mülheim an der Ruhr', 166865],
#  ['Solingen', 159103],
#  ['Solingen', 155265],
#  ['Leverkusen', 154692],
#  ['Leverkusen', 158984],
#  ['Neuss', 142178],
#  ['Neuss', 150568],
#  ['Paderborn', 110715],
#  ['Paderborn', 142365],
#  ['Recklinghausen', 119991],
#  ['Recklinghausen', 115958],
#  ['Remscheid', 120132],
#  ['Remscheid', 110708],
#  ['Bottrop', 114640],
#  ['Bottrop', 117311],
#  ['Siegen', 106384],
#  ['Siegen', 99187],
#  ['Moers', 100872],
#  ['Moers', 104009],
#  ['Witten', 102902],
#  ['Witten', 96382],
#  ['Bergisch Gladbach', 100589],
#  ['Bergisch Gladbach', 108878],
#  ['Mainz', 172529],
#  ['Mainz', 200344],
#  ['Ludwigshafen', 156601],
#  ['Ludwigshafen', 157584],
#  ['Koblenz', 108246],
#  ['Koblenz', 107825],
#  ['Kaiserslautern', 97326],
#  ['Kaiserslautern', 96340],
#  ['Trier', 94118],
#  ['Trier', 105671],
#  ['Saarbrücken', 188702],
#  ['Saarbrücken', 175853],
#  ['Dresden', 542252],
#  ['Dresden', 481676],
#  ['Dresden', 477807],
#  ['Dresden', 512354],
#  ['Leipzig', 600543],
#  ['Leipzig', 496647],
#  ['Leipzig', 493208],
#  ['Leipzig', 502979],
#  ['Chemnitz', 335983],
#  ['Chemnitz', 240253],
#  ['Zwickau', 130455],
#  ['Zwickau', 93081],
#  ['Magdeburg', 288975],
#  ['Magdeburg', 228144],
#  ['Halle', 329625],
#  ['Halle', 229153],
#  ['Kiel', 237767],
#  ['Kiel', 235782],
#  ['Lübeck', 210497],
#  ['Lübeck', 210305],
#  ['Erfurt', 200868],
#  ['Gera', 96067],
#  ['Jena', 105739],
#  ['Pécs', 170039],
#  ['Pécs', 171000],
#  ['Pécs', 162498],
#  ['Pécs', 156049],
#  ['Kecskemét', 102516],
#  ['Kecskemét', 105000],
#  ['Kecskemét', 107749],
#  ['Kecskemét', 111411],
#  ['Békéscsaba', 67157],
#  ['Békéscsaba', 67968],
#  ['Békéscsaba', 62050],
#  ['Miskolc', 196442],
#  ['Miskolc', 192000],
#  ['Miskolc', 184125],
#  ['Miskolc', 167754],
#  ['Szeged', 169930],
#  ['Szeged', 178000],
#  ['Szeged', 168273],
#  ['Szeged', 168048],
#  ['Székesfehérvár', 108958],
#  ['Székesfehérvár', 109000],
#  ['Székesfehérvár', 106346],
#  ['Székesfehérvár', 100570],
#  ['Győr', 129331],
#  ['Győr', 130000],
#  ['Győr', 129412],
#  ['Győr', 129527],
#  ['Debrecen', 212235],
#  ['Debrecen', 216000],
#  ['Debrecen', 211034],
#  ['Debrecen', 211320],
#  ['Eger', 61892],
#  ['Eger', 58331],
#  ['Eger', 56569],
#  ['Tatabánya', 74277],
#  ['Tatabánya', 72470],
#  ['Tatabánya', 67753],
#  ['Kaposvár', 71788],
#  ['Kaposvár', 68697],
#  ['Kaposvár', 66245],
#  ['Nyíregyháza', 114152],
#  ['Nyíregyháza', 115000],
#  ['Nyíregyháza', 118795],
#  ['Nyíregyháza', 119746],
#  ['Szolnok', 78328],
#  ['Szolnok', 77631],
#  ['Szolnok', 72953],
#  ['Szombathely', 85617],
#  ['Szombathely', 81920],
#  ['Szombathely', 78884],
#  ['Veszprém', 63867],
#  ['Veszprém', 62851],
#  ['Veszprém', 61721],
#  ['Zalaegerszeg', 62212],
#  ['Zalaegerszeg', 61654],
#  ['Zalaegerszeg', 59499],
#  ['Budapest', 2016681],
#  ['Budapest', 2016000],
#  ['Budapest', 1777921],
#  ['Budapest', 1729040],
#  ['Novara', 102473],
#  ['Novara', 101921],
#  ['Novara', 101952],
#  ['Torino', 961916],
#  ['Torino', 857433],
#  ['Torino', 872367],
#  ['Bérgamo', 115655],
#  ['Bérgamo', 110691],
#  ['Bérgamo', 115349],
#  ['Bréscia', 200722],
#  ['Bréscia', 187865],
#  ['Bréscia', 189902],
#  ['Milano', 1371008],
#  ['Milano', 1182693],
#  ['Milano', 1242123],
#  ['Monza', 121151],
#  ['Monza', 117068],
#  ['Monza', 119856],
#  ['Bolzano', 98233],
#  ['Bolzano', 93079],
#  ['Bolzano', 102575],
#  ['Trento', 101545],
#  ['Trento', 104844],
#  ['Trento', 114198],
#  ['Pádova', 215025],
#  ['Pádova', 203350],
#  ['Pádova', 206192],
#  ['Verona', 252689],
#  ['Verona', 243474],
#  ['Verona', 252520],
#  ['Vicenza', 107076],
#  ['Vicenza', 106069],
#  ['Vicenza', 111500],
#  ['Venézia', 308717],
#  ['Venézia', 266181],
#  ['Venézia', 261362],
#  ['Trieste', 229216],
#  ['Trieste', 209520],
#  ['Trieste', 202123],
#  ['La Spezia', 101442],
#  ['La Spezia', 91391],
#  ['La Spezia', 92659],
#  ['Génova', 675659],
#  ['Génova', 603560],
#  ['Génova', 586180],
#  ['Bologna', 404322],
#  ['Bologna', 369955],
#  ['Bologna', 371337],
#  ['Ferrara', 137336],
#  ['Ferrara', 130461],
#  ['Ferrara', 132545],
#  ['Forlí', 109228],
#  ['Forlí', 108363],
#  ['Forlí', 116434],
#  ['Módena', 176148],
#  ['Módena', 175442],
#  ['Módena', 179149],
#  ['Parma', 168905],
#  ['Parma', 156172],
#  ['Parma', 175895],
#  ['Piacenza', 102252],
#  ['Piacenza', 95132],
#  ['Piacenza', 100311],
#  ['Ravenna', 135435],
#  ['Ravenna', 138204],
#  ['Ravenna', 153740],
#  ["Réggio nell'Emilia", 131419],
#  ["Réggio nell'Emilia", 141383],
#  ["Réggio nell'Emilia", 162082],
#  ['Rímini', 128119],
#  ['Rímini', 128301],
#  ['Rímini', 139601],
#  ['Livorno', 167445],
#  ['Livorno', 148143],
#  ['Livorno', 157052],
#  ['Pisa', 98928],
#  ['Pisa', 89694],
#  ['Pisa', 85858],
#  ['Firenze', 402316],
#  ['Firenze', 352227],
#  ['Firenze', 358079],
#  ['Prato', 165364],
#  ['Prato', 170388],
#  ['Prato', 185456],
#  ['Perúgia', 143698],
#  ['Perúgia', 148575],
#  ['Perúgia', 162449],
#  ['Terni', 107333],
#  ['Terni', 103964],
#  ['Terni', 109193],
#  ['Ancona', 101179],
#  ['Ancona', 100402],
#  ['Ancona', 100497],
#  ['Roma', 2693383],
#  ['Roma', 2459776],
#  ['Roma', 2617175],
#  ['Latina', 105543],
#  ['Latina', 108711],
#  ['Latina', 117892],
#  ['Pescara', 121367],
#  ['Pescara', 115197],
#  ['Pescara', 117166],
#  ['Salerno', 153436],
#  ['Salerno', 144078],
#  ['Salerno', 132608],
#  ['Nápoli', 1054601],
#  ['Nápoli', 993386],
#  ['Nápoli', 962003],
#  ['Torre del Greco', 101361],
#  ['Torre del Greco', 90607],
#  ['Torre del Greco', 85922],
#  ['Giugliano in Campania', 60096],
#  ['Giugliano in Campania', 91265],
#  ['Giugliano in Campania', 108793],
#  ['Bari', 341273],
#  ['Bari', 312452],
#  ['Bari', 315933],
#  ['Fóggia', 155042],
#  ['Fóggia', 146072],
#  ['Fóggia', 147036],
#  ['Lecce', 100884],
#  ['Lecce', 83303],
#  ['Lecce', 89916],
#  ['Andria', 90063],
#  ['Andria', 95653],
#  ['Andria', 100052],
#  ['Táranto', 232200],
#  ['Táranto', 201349],
#  ['Táranto', 200154],
#  ['Catanzaro', 96614],
#  ['Catanzaro', 95251],
#  ['Catanzaro', 89364],
#  ['Cosenza', 86664],
#  ['Cosenza', 72998],
#  ['Cosenza', 69484],
#  ['Réggio di Calabria', 169709],
#  ['Réggio di Calabria', 179384],
#  ['Réggio di Calabria', 180817],
#  ['Palermo', 697162],
#  ['Palermo', 652640],
#  ['Palermo', 657561],
#  ['Messina', 272461],
#  ['Messina', 236621],
#  ['Messina', 243262],
#  ['Catánia', 330037],
#  ['Catánia', 306464],
#  ['Catánia', 293902],
#  ['Siracusa', 126136],
#  ['Siracusa', 121000],
#  ['Siracusa', 118385],
#  ['Cágliari', 203254],
#  ['Cágliari', 158351],
#  ['Cágliari', 149883],
#  ...]

# %%
df = pd.DataFrame(list,columns=['city_name','population'])
df.head()
# Out:
#   city_name  population
# 0    Tirana      192000
# 1    Tirana      244153
# 2    Tirana      418495
# 3   Shkodër       62000
# 4   Shkodër       77075

# %%
# 2. 10 cities with the largest population
df = df.groupby('city_name',as_index=False).max()
df = df.sort_values('population',ascending = False)
df.head(10)
# Out:
#       city_name  population
# 2380   Shanghai    22315474
# 1127   Istanbul    13710512
# 686       Delhi    12877470
# 1742     Mumbai    12442373
# 1729     Moskva    11979529
# 283     Beijing    11716620
# 2535  São Paulo    11152344
# 2631    Tianjin    11090314
# 941   Guangzhou    11071424
# 2393   Shenzhen    10358381

# %%
# build a list of list elements to create dataframe
ethnic_list = []

for element in root.iter('country'):
    sub_list = element.findall('ethnicgroup')
    
    for item in sub_list:
        d = item.attrib
        if item is None:
            l = [element.find('name').text,item,round(float(d['percentage'])/100,2)]
        else:
            l = [element.find('name').text,item.text,round(float(d['percentage'])/100,2)]
            
        ethnic_list.append(l)
    
ethnic_list
# Out:
# [['Albania', 'Albanian', 0.95],
#  ['Albania', 'Greek', 0.03],
#  ['Greece', 'Greek', 0.93],
#  ['Macedonia', 'Macedonian', 0.64],
#  ['Macedonia', 'Albanian', 0.25],
#  ['Macedonia', 'Turkish', 0.04],
#  ['Macedonia', 'Gypsy', 0.03],
#  ['Macedonia', 'Serb', 0.02],
#  ['Serbia', 'Serb', 0.83],
#  ['Serbia', 'Montenegrin', 0.01],
#  ['Serbia', 'Hungarian', 0.04],
#  ['Serbia', 'Roma', 0.01],
#  ['Serbia', 'Bosniak', 0.02],
#  ['Serbia', 'Croat', 0.01],
#  ['Montenegro', 'Montenegrin', 0.43],
#  ['Montenegro', 'Serb', 0.32],
#  ['Montenegro', 'Bosniak', 0.08],
#  ['Montenegro', 'Albanian', 0.05],
#  ['Kosovo', 'Albanian', 0.92],
#  ['Kosovo', 'Serbian', 0.05],
#  ['Andorra', 'Spanish', 0.43],
#  ['Andorra', 'Andorran', 0.33],
#  ['Andorra', 'Portuguese', 0.11],
#  ['Andorra', 'French', 0.02],
#  ['Andorra', 'African', 0.05],
#  ['Spain', 'Mediterranean Nordic', 1.0],
#  ['Austria', 'Austrian', 0.91],
#  ['Austria', 'Turkish', 0.02],
#  ['Austria', 'Slovene', 0.01],
#  ['Austria', 'Croat', 0.02],
#  ['Austria', 'Serbs', 0.02],
#  ['Austria', 'German', 0.01],
#  ['Czech Republic', 'Czech', 0.9],
#  ['Czech Republic', 'Moravian', 0.04],
#  ['Czech Republic', 'Slovak', 0.02],
#  ['Czech Republic', 'German', 0.01],
#  ['Czech Republic', 'Polish', 0.01],
#  ['Czech Republic', 'Roma', 0.0],
#  ['Czech Republic', 'Hungarian', 0.0],
#  ['Germany', 'German', 0.92],
#  ['Germany', 'Turkish', 0.02],
#  ['Hungary', 'Hungarian', 0.92],
#  ['Hungary', 'Roma', 0.02],
#  ['Hungary', 'Serb', 0.02],
#  ['Hungary', 'German', 0.03],
#  ['Hungary', 'Slovak', 0.01],
#  ['Hungary', 'Romanian', 0.01],
#  ['Liechtenstein', 'Italian', 0.05],
#  ['Liechtenstein', 'Alemannic', 0.95],
#  ['Slovakia', 'Slovak', 0.86],
#  ['Slovakia', 'Hungarian', 0.1],
#  ['Slovakia', 'Roma', 0.02],
#  ['Slovakia', 'Czech', 0.01],
#  ['Slovakia', 'Ukrainian', 0.0],
#  ['Slovakia', 'Ruthenian', 0.0],
#  ['Slovakia', 'German', 0.0],
#  ['Slovakia', 'Polish', 0.0],
#  ['Slovenia', 'Slovene', 0.91],
#  ['Slovenia', 'Croat', 0.03],
#  ['Slovenia', 'Serb', 0.02],
#  ['Slovenia', 'Bosniak', 0.01],
#  ['Switzerland', 'German', 0.65],
#  ['Switzerland', 'French', 0.18],
#  ['Switzerland', 'Italian', 0.1],
#  ['Switzerland', 'Romansch', 0.01],
#  ['Belarus', 'Belorussian', 0.81],
#  ['Belarus', 'Russian', 0.11],
#  ['Belarus', 'Polish', 0.04],
#  ['Belarus', 'Ukrainian', 0.02],
#  ['Latvia', 'Latvian', 0.59],
#  ['Latvia', 'Russian', 0.28],
#  ['Latvia', 'Belorussian', 0.04],
#  ['Latvia', 'Ukrainian', 0.03],
#  ['Latvia', 'Polish', 0.02],
#  ['Latvia', 'Lithuanian', 0.01],
#  ['Lithuania', 'Lithuanian', 0.84],
#  ['Lithuania', 'Polish', 0.06],
#  ['Lithuania', 'Russian', 0.05],
#  ['Lithuania', 'Belorussian', 0.01],
#  ['Poland', 'German', 0.01],
#  ['Poland', 'Polish', 0.98],
#  ['Poland', 'Ukrainian', 0.01],
#  ['Poland', 'Byelorussian', 0.01],
#  ['Ukraine', 'Ukrainian', 0.78],
#  ['Ukraine', 'Russian', 0.17],
#  ['Ukraine', 'Belorussian', 0.01],
#  ['Ukraine', 'Moldovan', 0.01],
#  ['Ukraine', 'Crimean Tatar', 0.01],
#  ['Ukraine', 'Bulgarian', 0.0],
#  ['Ukraine', 'Hungarian', 0.0],
#  ['Ukraine', 'Romanian', 0.0],
#  ['Ukraine', 'Polish', 0.0],
#  ['Ukraine', 'Jewish', 0.0],
#  ['Russia', 'Russian', 0.8],
#  ['Russia', 'Tatar', 0.04],
#  ['Russia', 'Ukrainian', 0.02],
#  ['Russia', 'Bashkir', 0.01],
#  ['Russia', 'Chuvash', 0.01],
#  ['Belgium', 'Fleming', 0.58],
#  ['Belgium', 'Walloon', 0.31],
#  ['Luxembourg', 'Luxembourgish', 0.63],
#  ['Luxembourg', 'Portuguese', 0.13],
#  ['Luxembourg', 'French', 0.04],
#  ['Luxembourg', 'Italian', 0.04],
#  ['Luxembourg', 'German', 0.02],
#  ['Netherlands', 'Dutch', 0.81],
#  ['Netherlands', 'Indonesian', 0.02],
#  ['Netherlands', 'Turkish', 0.02],
#  ['Netherlands', 'Moroccan', 0.02],
#  ['Netherlands', 'Surinamese', 0.02],
#  ['Netherlands', 'Caribbean', 0.01],
#  ['Bosnia and Herzegovina', 'Muslim', 0.48],
#  ['Bosnia and Herzegovina', 'Bosniak', 0.37],
#  ['Bosnia and Herzegovina', 'Croat', 0.14],
#  ['Croatia', 'Croat', 0.9],
#  ['Croatia', 'Serb', 0.04],
#  ['Croatia', 'Hungarian', 0.01],
#  ['Croatia', 'Muslim', 0.01],
#  ['Croatia', 'Slovene', 0.01],
#  ['Bulgaria', 'Bulgarian', 0.77],
#  ['Bulgaria', 'Turkish', 0.08],
#  ['Bulgaria', 'Roma', 0.04],
#  ['Bulgaria', 'Macedonian', 0.03],
#  ['Bulgaria', 'Russian', 0.0],
#  ['Bulgaria', 'Armenian', 0.0],
#  ['Romania', 'Romanian', 0.89],
#  ['Romania', 'Hungarian', 0.07],
#  ['Romania', 'Roma', 0.03],
#  ['Romania', 'German', 0.0],
#  ['Romania', 'Ukrainian', 0.0],
#  ['Romania', 'Russian', 0.0],
#  ['Romania', 'Turkish', 0.0],
#  ['Turkey', 'Turkish', 0.85],
#  ['Turkey', 'Kurdish', 0.12],
#  ['Turkey', 'Arabic', 0.01],
#  ['Estonia', 'Estonian', 0.69],
#  ['Estonia', 'Russian', 0.26],
#  ['Estonia', 'Ukrainian', 0.02],
#  ['Estonia', 'Belorussian', 0.01],
#  ['Estonia', 'Finn', 0.01],
#  ['Faroe Islands', 'Scandinavian', 1.0],
#  ['Finland', 'Finn', 0.93],
#  ['Finland', 'Swede', 0.06],
#  ['Finland', 'Russian', 0.01],
#  ['Finland', 'Estonian', 0.0],
#  ['Norway', 'Norwegian', 0.82],
#  ['Norway', 'Sami', 0.01],
#  ['Sweden', 'Swede', 0.83],
#  ['Sweden', 'Finn', 0.05],
#  ['Monaco', 'French', 0.47],
#  ['Monaco', 'Monegasque', 0.22],
#  ['Monaco', 'Italian', 0.19],
#  ['Guernsey', 'Norman-French', 1.0],
#  ['Iceland', 'Celt', 1.0],
#  ['Ireland', 'Irish', 0.87],
#  ['Ireland', 'Asian', 0.01],
#  ['Ireland', 'African', 0.01],
#  ['Jersey', 'Norman-French', 1.0],
#  ['Moldova', 'Moldavian/Romanian', 0.78],
#  ['Moldova', 'Ukrainian', 0.08],
#  ['Moldova', 'Russian', 0.06],
#  ['Moldova', 'Gagauz', 0.04],
#  ['Moldova', 'Bulgarian', 0.02],
#  ['Svalbard', 'Norwegian', 0.55],
#  ['Svalbard', 'Russian Ukrainian', 0.44],
#  ['United Kingdom', 'English', 0.84],
#  ['United Kingdom', 'Scottish', 0.09],
#  ['United Kingdom', 'Welsh', 0.05],
#  ['United Kingdom', 'Northern Irish', 0.03],
#  ['United Kingdom', 'African', 0.02],
#  ['United Kingdom', 'Indian', 0.02],
#  ['United Kingdom', 'Pakistani', 0.01],
#  ['Afghanistan', 'Tajik', 0.25],
#  ['Afghanistan', 'Pashtun', 0.38],
#  ['Afghanistan', 'Uzbek', 0.06],
#  ['Afghanistan', 'Hazara', 0.19],
#  ['China', 'Han Chinese', 0.92],
#  ['Iran', 'Arab', 0.03],
#  ['Iran', 'Persian', 0.51],
#  ['Iran', 'Baloch', 0.02],
#  ['Iran', 'Azerbaijani', 0.24],
#  ['Iran', 'Kurd', 0.07],
#  ['Iran', 'Lur', 0.02],
#  ['Iran', 'Turkmen', 0.02],
#  ['Iran', 'Gilaki Mazandarani', 0.08],
#  ['Tajikistan', 'Tajik', 0.8],
#  ['Tajikistan', 'Uzbek', 0.15],
#  ['Tajikistan', 'Russian', 0.01],
#  ['Tajikistan', 'Kyrgyz', 0.01],
#  ['Turkmenistan', 'Turkmen', 0.85],
#  ['Turkmenistan', 'Uzbek', 0.05],
#  ['Turkmenistan', 'Russian', 0.04],
#  ['Uzbekistan', 'Uzbek', 0.8],
#  ['Uzbekistan', 'Russian', 0.06],
#  ['Uzbekistan', 'Tajik', 0.05],
#  ['Uzbekistan', 'Kazak', 0.03],
#  ['Uzbekistan', 'Karakalpak', 0.03],
#  ['Uzbekistan', 'Tatar', 0.01],
#  ['Armenia', 'Armenian', 0.98],
#  ['Armenia', 'Russian', 0.01],
#  ['Armenia', 'Yezidi', 0.01],
#  ['Georgia', 'Georgian', 0.84],
#  ['Georgia', 'Azeri', 0.07],
#  ['Georgia', 'Russian', 0.01],
#  ['Azerbaijan', 'Azeri', 0.91],
#  ['Azerbaijan', 'Dagestani', 0.02],
#  ['Azerbaijan', 'Russian', 0.02],
#  ['Azerbaijan', 'Armenian', 0.01],
#  ['Bahrain', 'Arab', 0.1],
#  ['Bahrain', 'Asian', 0.13],
#  ['Bahrain', 'Bahraini', 0.63],
#  ['Bahrain', 'Iranian', 0.08],
#  ['Bangladesh', 'Bengali', 0.98],
#  ['Myanmar', 'Indian', 0.02],
#  ['Myanmar', 'Chinese', 0.03],
#  ['Myanmar', 'Burman', 0.68],
#  ['Myanmar', 'Shan', 0.09],
#  ['Myanmar', 'Karen', 0.07],
#  ['Myanmar', 'Rakhine', 0.04],
#  ['Myanmar', 'Mon', 0.02],
#  ['India', 'Dravidian', 0.25],
#  ['India', 'Indo-Aryan', 0.72],
#  ['India', 'Mongol', 0.03],
#  ['Bhutan', 'Bhote', 0.5],
#  ['Bhutan', 'Nepalese', 0.35],
#  ['Brunei', 'Chinese', 0.2],
#  ['Brunei', 'Malay', 0.64],
#  ['Malaysia', 'Malay', 0.5],
#  ['Malaysia', 'Chinese', 0.24],
#  ['Malaysia', 'Indian', 0.07],
#  ['Malaysia', 'Borneo indigenous', 0.11],
#  ['Laos', 'Lao Loum', 0.68],
#  ['Laos', 'Lao Theung', 0.22],
#  ['Laos', 'Lao Soung Hmong Yao', 0.09],
#  ['Laos', 'Vietnamese/Chinese', 0.01],
#  ['Thailand', 'Chinese', 0.14],
#  ['Thailand', 'Thai', 0.75],
#  ['Cambodia', 'Chinese', 0.01],
#  ['Cambodia', 'Khmer', 0.9],
#  ['Cambodia', 'Vietnamese', 0.05],
#  ['Vietnam', 'Viet/Kinh', 0.86],
#  ['Vietnam', 'Tay', 0.02],
#  ['Vietnam', 'Thai', 0.02],
#  ['Vietnam', 'Muong', 0.01],
#  ['Vietnam', 'Khmer', 0.01],
#  ['Vietnam', 'Mong', 0.01],
#  ['Vietnam', 'Nung', 0.01],
#  ['Kazakhstan', 'Kazakh', 0.63],
#  ['Kazakhstan', 'Russian', 0.24],
#  ['Kazakhstan', 'Uzbek', 0.03],
#  ['Kazakhstan', 'Ukrainian', 0.02],
#  ['Kazakhstan', 'Uighur', 0.01],
#  ['Kazakhstan', 'Tatar', 0.01],
#  ['Kazakhstan', 'German', 0.01],
#  ['Kyrgyzstan', 'Kyrgyz', 0.65],
#  ['Kyrgyzstan', 'Uzbek', 0.14],
#  ['Kyrgyzstan', 'Russian', 0.12],
#  ['Kyrgyzstan', 'Dungan', 0.01],
#  ['Kyrgyzstan', 'Ukrainian', 0.01],
#  ['Kyrgyzstan', 'Uighur', 0.01],
#  ['Hong Kong', 'Chinese', 0.95],
#  ['Hong Kong', 'Filipino', 0.02],
#  ['Hong Kong', 'Indonesian', 0.01],
#  ['Macao', 'Chinese', 0.95],
#  ['Macao', 'Portuguese', 0.03],
#  ['Mongolia', 'Mongol', 0.95],
#  ['Mongolia', 'Kazak', 0.05],
#  ['Christmas Island', 'Chinese', 0.7],
#  ['Christmas Island', 'Malay', 0.1],
#  ['Christmas Island', 'European', 0.2],
#  ['Cyprus', 'Greek', 0.77],
#  ['Cyprus', 'Turkish', 0.18],
#  ['Gaza Strip', 'Jewish', 0.01],
#  ['Gaza Strip', 'Palestinian Arab', 0.99],
#  ['Israel', 'Jewish', 0.76],
#  ['Israel', 'Arab', 0.23],
#  ['Egypt', 'European', 0.01],
#  ['Egypt', 'Eastern Hamitic', 0.99],
#  ['Indonesia', 'Javanese', 0.45],
#  ['Indonesia', 'Sundanese', 0.14],
#  ['Indonesia', 'Madurese', 0.07],
#  ['Indonesia', 'Malay', 0.07],
#  ['Iraq', 'Kurdish', 0.15],
#  ['Iraq', 'Arab', 0.75],
#  ['Iraq', 'Assyrian', 0.05],
#  ['Jordan', 'Armenian', 0.01],
#  ['Jordan', 'Arab', 0.98],
#  ['Jordan', 'Circassian', 0.01],
#  ['Kuwait', 'Arab', 0.35],
#  ['Kuwait', 'Iranian', 0.04],
#  ['Kuwait', 'South Asian', 0.09],
#  ['Kuwait', 'Kuwaiti', 0.45],
#  ['Saudi Arabia', 'Arab', 0.9],
#  ['Saudi Arabia', 'Afro-Asian', 0.1],
#  ['Syria', 'Arab', 0.9],
#  ['Lebanon', 'Armenian', 0.04],
#  ['Lebanon', 'Arab', 0.95],
#  ['West Bank', 'Jewish', 0.17],
#  ['West Bank', 'Palestinian Arab', 0.83],
#  ['Japan', 'Japanese', 0.99],
#  ['United Arab Emirates', 'South Asian', 0.5],
#  ['United Arab Emirates', 'Emiri', 0.19],
#  ['United Arab Emirates', 'Arab Iranian', 0.23],
#  ['Philippines', 'Chinese', 0.01],
#  ['Philippines', 'Malay', 0.95],
#  ['Qatar', 'Indian', 0.18],
#  ['Qatar', 'Pakistani', 0.18],
#  ['Qatar', 'Arab', 0.4],
#  ['Qatar', 'Iranian', 0.1],
#  ['Singapore', 'Indian', 0.06],
#  ['Singapore', 'Chinese', 0.76],
#  ['Singapore', 'Malay', 0.15],
#  ['Sri Lanka', 'Sinhalese', 0.74],
#  ['Sri Lanka', 'Tamil', 0.18],
#  ['Sri Lanka', 'Arab', 0.07],
#  ['Sri Lanka', 'Vedda', 0.01],
#  ['Taiwan', 'Chinese', 0.14],
#  ['Taiwan', 'Taiwanese', 0.84],
#  ['Anguilla', 'Black', 0.9],
#  ['Anguilla', 'Mulatto', 0.05],
#  ['Anguilla', 'White', 0.04],
#  ['Aruba', 'European/Caribbean Amerindian', 0.8],
#  ['Barbados', 'European', 0.04],
#  ['Barbados', 'African', 0.8],
#  ['Belize', 'Mestizo', 0.49],
#  ['Belize', 'Creole', 0.25],
#  ['Belize', 'Maya', 0.11],
#  ['Belize', 'Garifuna', 0.06],
#  ['Guatemala', 'Mestizo', 0.5],
#  ['Guatemala', 'European', 0.1],
#  ['Guatemala', 'Amerindian', 0.3],
#  ['Mexico', 'Mestizo', 0.6],
#  ['Mexico', 'Amerindian', 0.3],
#  ['Mexico', 'European', 0.09],
#  ['Bermuda', 'Black', 0.54],
#  ['Bermuda', 'White', 0.34],
#  ['Bermuda', 'Mixed', 0.06],
#  ['British Virgin Islands', 'Black', 0.83],
#  ['British Virgin Islands', 'White', 0.07],
#  ['British Virgin Islands', 'Amerindian', 0.03],
#  ['British Virgin Islands', 'Mixed', 0.05],
#  ['Canada', 'British Isles', 0.28],
#  ['Canada', 'French', 0.23],
#  ['Canada', 'European', 0.15],
#  ['Canada', 'Inuit', 0.02],
#  ['United States', 'European', 0.8],
#  ['United States', 'African', 0.13],
#  ['United States', 'Asian', 0.04],
#  ['United States', 'Amerindian', 0.01],
#  ['Cayman Islands', 'Black', 0.2],
#  ['Cayman Islands', 'White', 0.2],
#  ['Cayman Islands', 'Mixed', 0.4],
#  ['Costa Rica', 'Mestizo', 0.74],
#  ['Costa Rica', 'European', 0.2],
#  ['Costa Rica', 'African', 0.03],
#  ['Costa Rica', 'Amerindian', 0.01],
#  ['Costa Rica', 'Chinese', 0.01],
#  ['Nicaragua', 'Mestizo', 0.69],
#  ['Nicaragua', 'European', 0.17],
#  ['Nicaragua', 'African', 0.09],
#  ['Nicaragua', 'Amerindian', 0.05],
#  ['Panama', 'Mestizo', 0.84],
#  ['Panama', 'European', 0.1],
#  ['Panama', 'Amerindian', 0.06],
#  ['Cuba', 'European', 0.65],
#  ['Cuba', 'Mestizo', 0.12],
#  ['Cuba', 'Mulatto', 0.12],
#  ['Cuba', 'African', 0.1],
#  ['Dominica', 'Carib Indians', 1.0],
#  ['Dominican Republic', 'Mulatto', 0.73],
#  ['Dominican Republic', 'European', 0.16],
#  ['Dominican Republic', 'African', 0.11],
#  ['Haiti', 'African', 0.95],
#  ['Haiti', 'Mulatto', 0.03],
#  ['Haiti', 'European', 0.02],
#  ['El Salvador', 'Mestizo', 0.9],
#  ['El Salvador', 'European', 0.09],
#  ['El Salvador', 'Amerindian', 0.01],
#  ['Honduras', 'Mestizo', 0.9],
#  ['Honduras', 'Amerindian', 0.07],
#  ['Honduras', 'African', 0.02],
#  ['Honduras', 'European', 0.01],
#  ['Greenland', 'Danish', 0.14],
#  ['Greenland', 'Greenlander', 0.86],
#  ['Grenada', 'African', 1.0],
#  ['Guadeloupe', 'Chinese', 0.05],
#  ['Jamaica', 'African', 0.76],
#  ['Jamaica', 'Afro-European', 0.15],
#  ['Jamaica', 'Afro-East Indian', 0.03],
#  ['Jamaica', 'Afro-Chinese', 0.01],
#  ['Martinique', 'Chinese', 0.05],
#  ['Martinique', 'African-white-Indian', 0.9],
#  ['Colombia', 'Mestizo', 0.58],
#  ['Colombia', 'European', 0.2],
#  ['Colombia', 'Mulatto', 0.14],
#  ['Colombia', 'African', 0.04],
#  ['Colombia', 'black-Amerindian', 0.03],
#  ['Colombia', 'Amerindian', 0.01],
#  ['Puerto Rico', 'White', 0.8],
#  ['Puerto Rico', 'Black', 0.08],
#  ['Puerto Rico', 'Amerindian', 0.0],
#  ['Puerto Rico', 'Asian', 0.0],
#  ['Saint Kitts and Nevis', 'African', 1.0],
#  ['Saint Lucia', 'African', 0.9],
#  ['Saint Lucia', 'East Indian', 0.03],
#  ['Saint Pierre and Miquelon', 'Basques Bretons', 1.0],
#  ['Trinidad and Tobago', 'Chinese', 0.01],
#  ['Trinidad and Tobago', 'East Indian', 0.4],
#  ['Turks and Caicos Islands', 'African', 0.9],
#  ['American Samoa', 'Caucasian', 0.02],
#  ['American Samoa', 'Tongan', 0.04],
#  ['American Samoa', 'Samoan', 0.89],
#  ['Australia', 'European', 0.92],
#  ['Australia', 'Asian', 0.07],
#  ['Cook Islands', 'Polynesian', 0.94],
#  ['Fiji', 'Indian', 0.46],
#  ['Fiji', 'Fijian', 0.49],
#  ['French Polynesia', 'French', 0.1],
#  ['French Polynesia', 'Chinese', 0.12],
#  ['French Polynesia', 'Polynesian', 0.78],
#  ['Guam', 'Chamorro', 0.37],
#  ['Guam', 'Filipino', 0.26],
#  ['Kiribati', 'Micronesian', 1.0],
#  ['Marshall Islands', 'Micronesian', 1.0],
#  ['Micronesia', 'Polynesian', 1.0],
#  ['Nauru', 'Chinese', 0.08],
#  ['Nauru', 'European', 0.08],
#  ['Nauru', 'Nauruan', 0.58],
#  ['Nauru', 'Pacific Islander', 0.26],
#  ['New Caledonia', 'Vietnamese', 0.01],
#  ['New Caledonia', 'European', 0.34],
#  ['New Caledonia', 'Melanesian', 0.44],
#  ['New Caledonia', 'Wallisian', 0.09],
#  ['New Caledonia', 'Indonesian', 0.03],
#  ['New Zealand', 'European', 0.57],
#  ['New Zealand', 'Asian', 0.08],
#  ['New Zealand', 'Maori', 0.07],
#  ['New Zealand', 'Pacific Islander', 0.05],
#  ['Niue', 'Polynesian', 1.0],
#  ['Northern Mariana Islands', 'Asian', 0.56],
#  ['Northern Mariana Islands', 'Pacific Islander', 0.36],
#  ['Northern Mariana Islands', 'Caucasian', 0.02],
#  ['Pitcairn', 'Bounty', 1.0],
#  ['Solomon Islands', 'Chinese', 0.0],
#  ['Solomon Islands', 'European', 0.01],
#  ['Solomon Islands', 'Polynesian', 0.04],
#  ['Solomon Islands', 'Micronesian', 0.01],
#  ['Solomon Islands', 'Melanesian', 0.93],
#  ['Tuvalu', 'Polynesian', 0.96],
#  ['Tokelau', 'Polynesian', 0.95],
#  ['Vanuatu', 'French', 0.04],
#  ['Vanuatu', 'Melanesian', 0.94],
#  ['Wallis and Futuna', 'Polynesian', 1.0],
#  ['Samoa', 'Europeans', 0.0],
#  ['Samoa', 'Samoan', 0.93],
#  ['Samoa', 'Euronesians', 0.07],
#  ['Argentina', 'European', 0.97],
#  ['Bolivia', 'Quechua', 0.3],
#  ['Bolivia', 'Mestizo', 0.3],
#  ['Bolivia', 'Aymara', 0.25],
#  ['Bolivia', 'European', 0.15],
#  ['Brazil', 'European', 0.54],
#  ['Brazil', 'Mulatto', 0.39],
#  ['Brazil', 'African', 0.06],
#  ['Chile', 'Amerindian', 0.03],
#  ['Chile', 'European', 0.95],
#  ['Paraguay', 'Mestizo', 0.95],
#  ['Uruguay', 'European', 0.88],
#  ['Uruguay', 'Mestizo', 0.08],
#  ['Uruguay', 'African', 0.04],
#  ['Peru', 'Amerindian', 0.45],
#  ['Peru', 'Mestizo', 0.37],
#  ['Peru', 'European', 0.15],
#  ['French Guiana', 'Amerindian', 0.12],
#  ['Guyana', 'East Indian', 0.43],
#  ['Guyana', 'African', 0.3],
#  ['Guyana', 'Amerindian', 0.09],
#  ['Suriname', 'Hindustani', 0.37],
#  ['Suriname', 'Creole', 0.31],
#  ['Suriname', 'Javanese', 0.15],
#  ['Suriname', 'African', 0.1],
#  ['Suriname', 'Chinese', 0.02],
#  ['Suriname', 'Amerindian', 0.02],
#  ['Suriname', 'Europeans', 0.01],
#  ['Ecuador', 'Mestizo', 0.65],
#  ['Ecuador', 'Amerindian', 0.25],
#  ['Ecuador', 'European', 0.07],
#  ['Ecuador', 'African', 0.03],
#  ['Falkland Islands', 'Christian', 0.67],
#  ['Falkland Islands', 'None', 0.32],
#  ['Algeria', 'European', 0.01],
#  ['Algeria', 'Arab-Berber', 0.99],
#  ['Libya', 'Berber Arab', 0.97],
#  ['Mali', 'Mande', 0.5],
#  ['Mali', 'Peuhl', 0.17],
#  ['Mali', 'Voltaic', 0.12],
#  ['Mali', 'Songhai', 0.06],
#  ['Mali', 'Tuareg', 0.1],
#  ['Mauritania', 'Maur', 0.3],
#  ['Mauritania', 'Black Maur', 0.4],
#  ['Morocco', 'Jewish', 0.0],
#  ['Morocco', 'Arab-Berber', 0.99],
#  ['Niger', 'Fula', 0.09],
#  ['Niger', 'Hausa', 0.56],
#  ['Niger', 'Djerma', 0.22],
#  ['Niger', 'Tuareg', 0.08],
#  ['Niger', 'Beri Beri', 0.04],
#  ['Niger', 'Gourmantche', 0.01],
#  ['Tunisia', 'Jewish', 0.01],
#  ['Tunisia', 'European', 0.01],
#  ['Tunisia', 'Arab-Berber', 0.98],
#  ['Angola', 'European', 0.01],
#  ['Angola', 'Ovimbundu', 0.37],
#  ['Angola', 'Kimbundu', 0.25],
#  ['Angola', 'Bakongo', 0.13],
#  ['Zaire', 'Mangbetu-Azande', 0.45],
#  ['Zambia', 'European', 0.01],
#  ['Zambia', 'African', 0.99],
#  ['Benin', 'African', 0.99],
#  ['Burkina Faso', 'Mossi', 0.24],
#  ['Nigeria', 'African', 0.99],
#  ['Togo', 'African', 0.99],
#  ['Togo', 'European Syrian-Lebanese', 0.01],
#  ['Botswana', 'Batswana', 0.95],
#  ['Botswana', 'Kgalagadi', 0.04],
#  ['South Africa', 'Indian', 0.03],
#  ['South Africa', 'Colored', 0.09],
#  ['Zimbabwe', 'Asian', 0.01],
#  ['Zimbabwe', 'African', 0.98],
#  ['Cote dIvoire', 'Malinke', 0.11],
#  ['Cote dIvoire', 'Baoule', 0.23],
#  ['Cote dIvoire', 'Bete', 0.18],
#  ['Cote dIvoire', 'Senoufou', 0.15],
#  ['Ghana', 'European', 0.0],
#  ['Ghana', 'African', 1.0],
#  ['Rwanda', 'Hutu', 0.8],
#  ['Rwanda', 'Tutsi', 0.19],
#  ['Rwanda', 'Twa', 0.01],
#  ['Tanzania', 'Bantu', 0.95],
#  ['Cameroon', 'African', 0.13],
#  ['Cameroon', 'Fulani', 0.1],
#  ['Cameroon', 'Cameroon Highlanders', 0.31],
#  ['Cameroon', 'Equatorial Bantu', 0.19],
#  ['Cameroon', 'Kirdi', 0.11],
#  ['Cameroon', 'Northwestern Bantu', 0.08],
#  ['Cameroon', 'Eastern Nigritic', 0.07],
#  ['Central African Republic', 'Baya', 0.34],
#  ['Central African Republic', 'Banda', 0.27],
#  ['Central African Republic', 'Sara', 0.1],
#  ['Central African Republic', 'Mandjia', 0.21],
#  ['Central African Republic', 'Mboum', 0.04],
#  ['Central African Republic', 'MBaka', 0.04],
#  ['Cape Verde', 'European', 0.01],
#  ['Cape Verde', 'African', 0.28],
#  ['Cape Verde', 'Creole', 0.71],
#  ['Sudan', 'Arab', 0.7],
#  ['Sudan', 'Beja', 0.06],
#  ['Guinea', 'Malinke', 0.3],
#  ['Guinea', 'Peuhl', 0.4],
#  ['Guinea', 'Soussou', 0.2],
#  ['Liberia', 'African', 0.95],
#  ['Liberia', 'Americo-Liberians', 0.05],
#  ['Djibouti', 'Italian', 0.05],
#  ['Djibouti', 'Afar', 0.35],
#  ['Djibouti', 'Somali', 0.6],
#  ['Eritrea', 'Tigrinya', 0.55],
#  ['Eritrea', 'Tigre', 0.3],
#  ['Eritrea', 'Saho', 0.04],
#  ['Eritrea', 'Kunama', 0.02],
#  ['Eritrea', 'Rashaida', 0.02],
#  ['Eritrea', 'Bilen', 0.02],
#  ['Ethiopia', 'Oromo', 0.34],
#  ['Ethiopia', 'Amhara', 0.27],
#  ['Ethiopia', 'Somali', 0.06],
#  ['Ethiopia', 'Tigraway', 0.06],
#  ['Ethiopia', 'Sidama', 0.04],
#  ['Ethiopia', 'Gurage', 0.03],
#  ['Ethiopia', 'Welaita', 0.02],
#  ['Ethiopia', 'Hadiya', 0.02],
#  ['Ethiopia', 'Afar', 0.02],
#  ['Somalia', 'Somali', 0.85],
#  ['Kenya', 'Arab', 0.01],
#  ['Kenya', 'Kikuyu', 0.22],
#  ['Kenya', 'Luhya', 0.14],
#  ['Kenya', 'Luo', 0.13],
#  ['Kenya', 'Kalenjin', 0.12],
#  ['Kenya', 'Kamba', 0.11],
#  ['Kenya', 'Kisii', 0.06],
#  ['Kenya', 'Meru', 0.06],
#  ['Gambia', 'African', 0.99],
#  ['Senegal', 'Fulani', 0.17],
#  ['Senegal', 'Wolof', 0.36],
#  ['Senegal', 'Diola', 0.09],
#  ['Senegal', 'Mandingo', 0.09],
#  ['Senegal', 'Serer', 0.17],
#  ['Senegal', 'Toucouleur', 0.09],
#  ['Senegal', 'European Lebanese', 0.01],
#  ['Guinea-Bissau', 'European', 0.01],
#  ['Guinea-Bissau', 'African', 0.99],
#  ['Sierra Leone', 'Asian', 0.01],
#  ['Sierra Leone', 'African', 0.99],
#  ['Uganda', 'Rwanda', 0.06],
#  ['Uganda', 'Arab', 0.01],
#  ['Uganda', 'Baganda', 0.17],
#  ['Uganda', 'Karamojong', 0.12],
#  ['Uganda', 'Basogo', 0.08],
#  ['Uganda', 'Iteso', 0.08],
#  ['Uganda', 'Langi', 0.06],
#  ['Uganda', 'Bagisu', 0.05],
#  ['Uganda', 'Acholi', 0.04],
#  ['Uganda', 'Lugbara', 0.04],
#  ['Uganda', 'Bunyoro', 0.03],
#  ['Uganda', 'Batobo', 0.03],
#  ['Lesotho', 'Sotho', 1.0],
#  ['Mozambique', 'European', 0.0],
#  ['Mozambique', 'Indian', 0.0],
#  ['Mozambique', 'Euro-African', 0.0],
#  ['Mauritius', 'Creole', 0.27],
#  ['Mauritius', 'Indo-Mauritian', 0.68],
#  ['Mauritius', 'Sino-Mauritian', 0.03],
#  ['Mauritius', 'Franco-Mauritian', 0.02],
#  ['Swaziland', 'European', 0.03],
#  ['Swaziland', 'African', 0.97],
#  ['Saint Helena', 'African descent', 0.5],
#  ['Saint Helena', 'White', 0.25],
#  ['Saint Helena', 'Chinese', 0.25],
#  ['Sao Tome and Principe', 'European', 1.0],
#  ['Seychelles', 'Seychellois', 1.0]]

# %%
# build a list of list elements to create dataframe
pop_list = []

for element in root.iter('country'):
    sub_list = element.findall('population')
    
    for item in sub_list:
        d = item.attrib
        # key_list = list(d.keys())
        
        if item is None:
            l = [element.find('name').text,item,d['year']]
        else:
            l = [element.find('name').text,int(item.text),d['year']]

        pop_list.append(l)
    
pop_list
# Out:
# [['Albania', 1214489, '1950'],
#  ['Albania', 1618829, '1960'],
#  ['Albania', 2138966, '1970'],
#  ['Albania', 2734776, '1980'],
#  ['Albania', 3446882, '1990'],
#  ['Albania', 3249136, '1997'],
#  ['Albania', 3304948, '2000'],
#  ['Albania', 3069275, '2001'],
#  ['Albania', 2800138, '2011'],
#  ['Greece', 1096810, '1861'],
#  ['Greece', 1457894, '1870'],
#  ['Greece', 1679470, '1879'],
#  ['Greece', 2433806, '1896'],
#  ['Greece', 2631592, '1907'],
#  ['Greece', 5016889, '1920'],
#  ['Greece', 6204684, '1928'],
#  ['Greece', 7344860, '1940'],
#  ['Greece', 7632801, '1951'],
#  ['Greece', 8388553, '1961'],
#  ['Greece', 8768372, '1971'],
#  ['Greece', 9739589, '1981'],
#  ['Greece', 10217335, '1991'],
#  ['Greece', 10934097, '2001'],
#  ['Greece', 10816286, '2011'],
#  ['Macedonia', 808724, '1921'],
#  ['Macedonia', 949958, '1931'],
#  ['Macedonia', 1152986, '1948'],
#  ['Macedonia', 1304514, '1953'],
#  ['Macedonia', 1406003, '1961'],
#  ['Macedonia', 1647308, '1971'],
#  ['Macedonia', 1909136, '1981'],
#  ['Macedonia', 2033964, '1991'],
#  ['Macedonia', 1935034, '1994'],
#  ['Macedonia', 2022547, '2002'],
#  ['Macedonia', 2059794, '2011'],
#  ['Serbia', 6732256, '1950'],
#  ['Serbia', 7657958, '1960'],
#  ['Serbia', 8236185, '1970'],
#  ['Serbia', 9057483, '1980'],
#  ['Serbia', 9735429, '1990'],
#  ['Serbia', 7620531, '1991'],
#  ['Serbia', 7498001, '2002'],
#  ['Serbia', 7120666, '2011'],
#  ['Montenegro', 311341, '1921'],
#  ['Montenegro', 360044, '1931'],
#  ['Montenegro', 377189, '1948'],
#  ['Montenegro', 419873, '1953'],
#  ['Montenegro', 471894, '1961'],
#  ['Montenegro', 529604, '1971'],
#  ['Montenegro', 584310, '1981'],
#  ['Montenegro', 615035, '1991'],
#  ['Montenegro', 620145, '2003'],
#  ['Montenegro', 620029, '2011'],
#  ['Kosovo', 1584440, '1981'],
#  ['Kosovo', 1956196, '1991'],
#  ['Kosovo', 1733872, '2011'],
#  ['Andorra', 6197, '1950'],
#  ['Andorra', 13414, '1960'],
#  ['Andorra', 24279, '1970'],
#  ['Andorra', 36063, '1980'],
#  ['Andorra', 46166, '1989'],
#  ['Andorra', 66334, '2001'],
#  ['Andorra', 81222, '2006'],
#  ['Andorra', 78115, '2011'],
#  ['France', 40502513, '1946'],
#  ['France', 42777162, '1954'],
#  ['France', 46520271, '1962'],
#  ['France', 49778540, '1968'],
#  ['France', 52591584, '1975'],
#  ['France', 54334871, '1982'],
#  ['France', 56615155, '1990'],
#  ['France', 60185831, '1999'],
#  ['France', 60825000, '2006'],
#  ['France', 64933400, '2011'],
#  ['Spain', 18618086, '1900'],
#  ['Spain', 19995686, '1910'],
#  ['Spain', 21389842, '1920'],
#  ['Spain', 23677794, '1930'],
#  ['Spain', 25877971, '1940'],
#  ['Spain', 27976755, '1950'],
#  ['Spain', 30528539, '1960'],
#  ['Spain', 34040657, '1970'],
#  ['Spain', 37683363, '1981'],
#  ['Spain', 38871331, '1991'],
#  ['Spain', 40847371, '2001'],
#  ['Spain', 46815916, '2011'],
#  ['Austria', 4497873, '1869'],
#  ['Austria', 6648310, '1910'],
#  ['Austria', 6760233, '1934'],
#  ['Austria', 6933905, '1951'],
#  ['Austria', 7073807, '1961'],
#  ['Austria', 7491526, '1971'],
#  ['Austria', 7555338, '1981'],
#  ['Austria', 7795786, '1991'],
#  ['Austria', 8032926, '2001'],
#  ['Austria', 8375290, '2010'],
#  ['Austria', 8499759, '2013'],
#  ['Czech Republic', 8876260, '1950'],
#  ['Czech Republic', 9577974, '1960'],
#  ['Czech Republic', 9827923, '1970'],
#  ['Czech Republic', 10313309, '1980'],
#  ['Czech Republic', 10325976, '1990'],
#  ['Czech Republic', 10321120, '1997'],
#  ['Czech Republic', 10250398, '2000'],
#  ['Czech Republic', 10230060, '2001'],
#  ['Czech Republic', 10562214, '2011'],
#  ['Germany', 68230796, '1950'],
#  ['Germany', 82501000, '1997'],
#  ['Germany', 82217837, '2007'],
#  ['Germany', 80219695, '2011'],
#  ['Hungary', 9204799, '1949'],
#  ['Hungary', 9961044, '1960'],
#  ['Hungary', 10322099, '1970'],
#  ['Hungary', 10709463, '1980'],
#  ['Hungary', 10374823, '1990'],
#  ['Hungary', 10198315, '2001'],
#  ['Hungary', 9937628, '2011'],
#  ['Italy', 22182377, '1861'],
#  ['Italy', 27303509, '1871'],
#  ['Italy', 28953480, '1881'],
#  ['Italy', 32965504, '1901'],
#  ['Italy', 35845048, '1911'],
#  ['Italy', 39943528, '1921'],
#  ['Italy', 41651000, '1931'],
#  ['Italy', 42943602, '1936'],
#  ['Italy', 47515537, '1951'],
#  ['Italy', 50623569, '1961'],
#  ['Italy', 54136547, '1971'],
#  ['Italy', 56556911, '1981'],
#  ['Italy', 56778031, '1991'],
#  ['Italy', 56995744, '2001'],
#  ['Italy', 59433744, '2011'],
#  ['Liechtenstein', 13757, '1950'],
#  ['Liechtenstein', 16628, '1960'],
#  ['Liechtenstein', 21350, '1970'],
#  ['Liechtenstein', 25215, '1980'],
#  ['Liechtenstein', 29032, '1990'],
#  ['Liechtenstein', 33525, '2001'],
#  ['Liechtenstein', 35174, '2006'],
#  ['Liechtenstein', 36636, '2012'],
#  ['Slovakia', 3436574, '1950'],
#  ['Slovakia', 4137224, '1960'],
#  ['Slovakia', 4531874, '1970'],
#  ['Slovakia', 4988654, '1980'],
#  ['Slovakia', 5277709, '1990'],
#  ['Slovakia', 5388010, '2000'],
#  ['Slovakia', 5379455, '2001'],
#  ['Slovakia', 5397036, '2011'],
#  ['Slovenia', 1101854, '1857'],
#  ['Slovenia', 1128768, '1869'],
#  ['Slovenia', 1182223, '1880'],
#  ['Slovenia', 1234056, '1890'],
#  ['Slovenia', 1268055, '1900'],
#  ['Slovenia', 1321098, '1910'],
#  ['Slovenia', 1054919, '1921'],
#  ['Slovenia', 1144298, '1931'],
#  ['Slovenia', 1391873, '1948'],
#  ['Slovenia', 1466425, '1953'],
#  ['Slovenia', 1591523, '1961'],
#  ['Slovenia', 1727137, '1971'],
#  ['Slovenia', 1891864, '1981'],
#  ['Slovenia', 1913355, '1991'],
#  ['Slovenia', 1964036, '2002'],
#  ['Slovenia', 2046976, '2010'],
#  ['Slovenia', 2050189, '2011'],
#  ['Slovenia', 2058821, '2013'],
#  ['Switzerland', 4668088, '1950'],
#  ['Switzerland', 5296120, '1960'],
#  ['Switzerland', 6169357, '1970'],
#  ['Switzerland', 6303608, '1980'],
#  ['Switzerland', 6673920, '1990'],
#  ['Switzerland', 7204055, '2000'],
#  ['Switzerland', 7785806, '2009'],
#  ['Switzerland', 8139631, '2013'],
#  ['Belarus', 7745003, '1950'],
#  ['Belarus', 8054648, '1959'],
#  ['Belarus', 9002338, '1970'],
#  ['Belarus', 9532516, '1979'],
#  ['Belarus', 10151806, '1989'],
#  ['Belarus', 10045237, '1999'],
#  ['Belarus', 9503807, '2009'],
#  ['Belarus', 9460692, '2013'],
#  ['Latvia', 1929387, '1897'],
#  ['Latvia', 1596131, '1920'],
#  ['Latvia', 1844805, '1925'],
#  ['Latvia', 1900045, '1930'],
#  ['Latvia', 1950502, '1935'],
#  ['Latvia', 2093458, '1959'],
#  ['Latvia', 2502816, '1979'],
#  ['Latvia', 2666567, '1989'],
#  ['Latvia', 2377383, '2000'],
#  ['Latvia', 2070371, '2011'],
#  ['Latvia', 2201196, '2013'],
#  ['Lithuania', 2567402, '1950'],
#  ['Lithuania', 2696700, '1959'],
#  ['Lithuania', 3118900, '1970'],
#  ['Lithuania', 3391490, '1979'],
#  ['Lithuania', 3674802, '1989'],
#  ['Lithuania', 3483972, '2001'],
#  ['Lithuania', 3043429, '2011'],
#  ['Lithuania', 2979310, '2013'],
#  ['Poland', 23929757, '1946'],
#  ['Poland', 24613684, '1950'],
#  ['Poland', 29405729, '1960'],
#  ['Poland', 32749400, '1970'],
#  ['Poland', 35061450, '1978'],
#  ['Poland', 37878641, '1988'],
#  ['Poland', 38230000, '2002'],
#  ['Poland', 38167786, '2005'],
#  ['Poland', 38153389, '2009'],
#  ['Poland', 38501000, '2011'],
#  ['Poland', 38533789, '2012'],
#  ['Ukraine', 37297652, '1950'],
#  ['Ukraine', 41869046, '1959'],
#  ['Ukraine', 47126517, '1970'],
#  ['Ukraine', 49609333, '1979'],
#  ['Ukraine', 51706742, '1989'],
#  ['Ukraine', 48457102, '2001'],
#  ['Ukraine', 45778534, '2011'],
#  ['Ukraine', 45633637, '2012'],
#  ['Russia', 102798657, '1950'],
#  ['Russia', 120057109, '1960'],
#  ['Russia', 130357806, '1970'],
#  ['Russia', 138535754, '1980'],
#  ['Russia', 148148752, '1990'],
#  ['Russia', 148178487, '1997'],
#  ['Russia', 146762881, '2000'],
#  ['Russia', 142856536, '2010'],
#  ['Russia', 143347059, '2013'],
#  ['Russia', 143666931, '2014'],
#  ['Belgium', 8879814, '1947'],
#  ['Belgium', 9189741, '1961'],
#  ['Belgium', 9650944, '1970'],
#  ['Belgium', 9963374, '1981'],
#  ['Belgium', 9947782, '1990'],
#  ['Belgium', 9978681, '1991'],
#  ['Belgium', 10239085, '2000'],
#  ['Belgium', 10296350, '2001'],
#  ['Belgium', 11099554, '2013'],
#  ['Luxembourg', 290992, '1947'],
#  ['Luxembourg', 314889, '1960'],
#  ['Luxembourg', 334790, '1966'],
#  ['Luxembourg', 339841, '1970'],
#  ['Luxembourg', 364602, '1981'],
#  ['Luxembourg', 384634, '1991'],
#  ['Luxembourg', 435479, '2000'],
#  ['Luxembourg', 439539, '2001'],
#  ['Luxembourg', 469086, '2006'],
#  ['Luxembourg', 524853, '2012'],
#  ['Netherlands', 2078487, '1795'],
#  ['Netherlands', 2202191, '1815'],
#  ['Netherlands', 2613487, '1830'],
#  ['Netherlands', 2860559, '1840'],
#  ['Netherlands', 3056879, '1849'],
#  ['Netherlands', 3309128, '1859'],
#  ['Netherlands', 3579529, '1869'],
#  ['Netherlands', 4012693, '1879'],
#  ['Netherlands', 4511415, '1889'],
#  ['Netherlands', 5104137, '1899'],
#  ['Netherlands', 5858175, '1909'],
#  ['Netherlands', 6865314, '1920'],
#  ['Netherlands', 7935565, '1930'],
#  ['Netherlands', 9625499, '1947'],
#  ['Netherlands', 11461964, '1960'],
#  ['Netherlands', 13060115, '1971'],
#  ['Netherlands', 15568034, '1997'],
#  ['Netherlands', 16105285, '2002'],
#  ['Netherlands', 16208562, '2004'],
#  ['Netherlands', 16577516, '2010'],
#  ['Netherlands', 16843181, '2014'],
#  ['Bosnia and Herzegovina', 2565277, '1948'],
#  ['Bosnia and Herzegovina', 2847790, '1953'],
#  ['Bosnia and Herzegovina', 3277948, '1961'],
#  ['Bosnia and Herzegovina', 3746111, '1971'],
#  ['Bosnia and Herzegovina', 4124256, '1981'],
#  ['Bosnia and Herzegovina', 4377033, '1991'],
#  ['Bosnia and Herzegovina', 3791622, '2013'],
#  ['Croatia', 3850295, '1950'],
#  ['Croatia', 4059048, '1960'],
#  ['Croatia', 4171014, '1970'],
#  ['Croatia', 4426221, '1971'],
#  ['Croatia', 4601469, '1981'],
#  ['Croatia', 4784265, '1991'],
#  ['Croatia', 4437460, '2001'],
#  ['Croatia', 4290612, '2011'],
#  ['Bulgaria', 3154375, '1887'],
#  ['Bulgaria', 3310713, '1892'],
#  ['Bulgaria', 3744283, '1900'],
#  ['Bulgaria', 4035575, '1905'],
#  ['Bulgaria', 4337513, '1910'],
#  ['Bulgaria', 4846971, '1920'],
#  ['Bulgaria', 5528741, '1926'],
#  ['Bulgaria', 6077939, '1934'],
#  ['Bulgaria', 7029349, '1946'],
#  ['Bulgaria', 7613709, '1956'],
#  ['Bulgaria', 8227866, '1965'],
#  ['Bulgaria', 8727771, '1975'],
#  ['Bulgaria', 8948649, '1985'],
#  ['Bulgaria', 8487317, '1992'],
#  ['Bulgaria', 7932984, '2001'],
#  ['Bulgaria', 7351234, '2011'],
#  ['Bulgaria', 7284552, '2012'],
#  ['Romania', 15872624, '1948'],
#  ['Romania', 17489450, '1956'],
#  ['Romania', 19103163, '1966'],
#  ['Romania', 21559910, '1977'],
#  ['Romania', 22810035, '1992'],
#  ['Romania', 21657162, '1996'],
#  ['Romania', 21680974, '2002'],
#  ['Romania', 21498616, '2009'],
#  ['Romania', 20121641, '2011'],
#  ['Turkey', 13648270, '1927'],
#  ['Turkey', 16158018, '1935'],
#  ['Turkey', 17820950, '1940'],
#  ['Turkey', 18790174, '1945'],
#  ['Turkey', 20947188, '1950'],
#  ['Turkey', 24064763, '1955'],
#  ['Turkey', 27754820, '1960'],
#  ['Turkey', 31391421, '1965'],
#  ['Turkey', 35605176, '1970'],
#  ['Turkey', 40347719, '1975'],
#  ['Turkey', 44736957, '1980'],
#  ['Turkey', 50664458, '1985'],
#  ['Turkey', 56473035, '1990'],
#  ['Turkey', 62484478, '1997'],
#  ['Turkey', 67808719, '2000'],
#  ['Turkey', 70586256, '2007'],
#  ['Turkey', 75627384, '2012'],
#  ['Denmark', 4281275, '1950'],
#  ['Denmark', 4448401, '1955'],
#  ['Denmark', 4585256, '1960'],
#  ['Denmark', 4767597, '1965'],
#  ['Denmark', 4937579, '1970'],
#  ['Denmark', 5123989, '1981'],
#  ['Denmark', 5146469, '1991'],
#  ['Denmark', 5349212, '2001'],
#  ['Denmark', 5427459, '2006'],
#  ['Denmark', 5534738, '2010'],
#  ['Denmark', 5580516, '2012'],
#  ['Estonia', 881455, '1881'],
#  ['Estonia', 958351, '1897'],
#  ['Estonia', 1107059, '1922'],
#  ['Estonia', 1126413, '1934'],
#  ['Estonia', 1196791, '1959'],
#  ['Estonia', 1356079, '1970'],
#  ['Estonia', 1464476, '1979'],
#  ['Estonia', 1565662, '1989'],
#  ['Estonia', 1370052, '2000'],
#  ['Estonia', 1340127, '2010'],
#  ['Estonia', 1294455, '2011'],
#  ['Faroe Islands', 31781, '1950'],
#  ['Faroe Islands', 32456, '1955'],
#  ['Faroe Islands', 34596, '1960'],
#  ['Faroe Islands', 37122, '1966'],
#  ['Faroe Islands', 38612, '1970'],
#  ['Faroe Islands', 41969, '1977'],
#  ['Faroe Islands', 43857, '1997'],
#  ['Faroe Islands', 48668, '2009'],
#  ['Faroe Islands', 48197, '2013'],
#  ['Finland', 4008299, '1950'],
#  ['Finland', 4430228, '1960'],
#  ['Finland', 4606740, '1970'],
#  ['Finland', 4779454, '1980'],
#  ['Finland', 4986705, '1990'],
#  ['Finland', 5105230, '1997'],
#  ['Finland', 5176482, '2000'],
#  ['Finland', 5300484, '2007'],
#  ['Finland', 5401267, '2012'],
#  ['Finland', 5455068, '2014'],
#  ['Norway', 3265278, '1950'],
#  ['Norway', 3582016, '1960'],
#  ['Norway', 3875719, '1970'],
#  ['Norway', 4082525, '1980'],
#  ['Norway', 4240375, '1990'],
#  ['Norway', 4383807, '1997'],
#  ['Norway', 4491572, '2000'],
#  ['Norway', 4520947, '2001'],
#  ['Norway', 4920305, '2011'],
#  ['Norway', 5051275, '2013'],
#  ['Sweden', 7009913, '1950'],
#  ['Sweden', 7479602, '1960'],
#  ['Sweden', 8049049, '1970'],
#  ['Sweden', 8310915, '1980'],
#  ['Sweden', 8559107, '1990'],
#  ['Sweden', 8900954, '1997'],
#  ['Sweden', 8872284, '2000'],
#  ['Sweden', 9011392, '2004'],
#  ['Sweden', 9340682, '2009'],
#  ['Sweden', 9555893, '2012'],
#  ['Monaco', 20000, '1950'],
#  ['Monaco', 20202, '1951'],
#  ['Monaco', 20422, '1956'],
#  ['Monaco', 22297, '1961'],
#  ['Monaco', 21783, '1962'],
#  ['Monaco', 23035, '1968'],
#  ['Monaco', 25029, '1975'],
#  ['Monaco', 27063, '1982'],
#  ['Monaco', 29972, '1990'],
#  ['Monaco', 32020, '2000'],
#  ['Monaco', 31109, '2008'],
#  ['Monaco', 36845, '2010'],
#  ['Gibraltar', 1816, '1753'],
#  ['Gibraltar', 2710, '1767'],
#  ['Gibraltar', 3201, '1777'],
#  ['Gibraltar', 3386, '1787'],
#  ['Gibraltar', 2890, '1791'],
#  ['Gibraltar', 10136, '1814'],
#  ['Gibraltar', 15002, '1834'],
#  ['Gibraltar', 15823, '1844'],
#  ['Gibraltar', 18695, '1871'],
#  ['Gibraltar', 18014, '1878'],
#  ['Gibraltar', 18381, '1881'],
#  ['Gibraltar', 19100, '1891'],
#  ['Gibraltar', 20355, '1901'],
#  ['Gibraltar', 19120, '1911'],
#  ['Gibraltar', 18061, '1921'],
#  ['Gibraltar', 17405, '1931'],
#  ['Gibraltar', 20845, '1951'],
#  ['Gibraltar', 23926, '1961'],
#  ['Gibraltar', 26818, '1970'],
#  ['Gibraltar', 28719, '1981'],
#  ['Gibraltar', 28074, '1991'],
#  ['Gibraltar', 27495, '2001'],
#  ['Gibraltar', 27495, '2011'],
#  ['Guernsey', 43652, '1951'],
#  ['Guernsey', 45068, '1961'],
#  ['Guernsey', 51458, '1971'],
#  ['Guernsey', 53637, '1976'],
#  ['Guernsey', 53313, '1981'],
#  ['Guernsey', 55482, '1986'],
#  ['Guernsey', 58867, '1991'],
#  ['Guernsey', 58681, '1996'],
#  ['Guernsey', 59807, '2001'],
#  ['Holy See', 840, '1997'],
#  ['Holy See', 842, '2014'],
#  ['Ceuta', 73182, '1960'],
#  ['Ceuta', 67187, '1970'],
#  ['Ceuta', 70864, '1981'],
#  ['Ceuta', 73208, '1991'],
#  ['Ceuta', 75694, '2001'],
#  ['Ceuta', 82376, '2011'],
#  ['Melilla', 79056, '1960'],
#  ['Melilla', 64642, '1970'],
#  ['Melilla', 58449, '1981'],
#  ['Melilla', 63670, '1991'],
#  ['Melilla', 66411, '2001'],
#  ['Melilla', 78476, '2011'],
#  ['Iceland', 78470, '1901'],
#  ['Iceland', 85183, '1910'],
#  ['Iceland', 94690, '1920'],
#  ['Iceland', 108861, '1930'],
#  ['Iceland', 121474, '1940'],
#  ['Iceland', 143973, '1950'],
#  ['Iceland', 175680, '1960'],
#  ['Iceland', 204578, '1970'],
#  ['Iceland', 229187, '1980'],
#  ['Iceland', 255708, '1990'],
#  ['Iceland', 282849, '2000'],
#  ['Iceland', 293577, '2005'],
#  ['Iceland', 318452, '2011'],
#  ['Ireland', 3221823, '1901'],
#  ['Ireland', 3139688, '1911'],
#  ['Ireland', 2971992, '1926'],
#  ['Ireland', 2968420, '1936'],
#  ['Ireland', 2955107, '1946'],
#  ['Ireland', 2960593, '1951'],
#  ['Ireland', 2898264, '1956'],
#  ['Ireland', 2818341, '1961'],
#  ['Ireland', 2884002, '1966'],
#  ['Ireland', 2978248, '1971'],
#  ['Ireland', 3368217, '1979'],
#  ['Ireland', 3443405, '1981'],
#  ['Ireland', 3540643, '1986'],
#  ['Ireland', 3525719, '1991'],
#  ['Ireland', 3626087, '1996'],
#  ['Ireland', 3917203, '2002'],
#  ['Ireland', 4239848, '2006'],
#  ['Ireland', 4588252, '2011'],
#  ['San Marino', 12781, '1950'],
#  ['San Marino', 15393, '1960'],
#  ['San Marino', 19136, '1970'],
#  ['San Marino', 19149, '1976'],
#  ['San Marino', 24521, '1997'],
#  ['San Marino', 26941, '2000'],
#  ['San Marino', 31851, '2010'],
#  ['San Marino', 32440, '2012'],
#  ['Jersey', 28600, '1821'],
#  ['Jersey', 36582, '1831'],
#  ['Jersey', 47544, '1841'],
#  ['Jersey', 57020, '1851'],
#  ['Jersey', 55613, '1861'],
#  ['Jersey', 56627, '1871'],
#  ['Jersey', 52445, '1881'],
#  ['Jersey', 54518, '1891'],
#  ['Jersey', 52576, '1901'],
#  ['Jersey', 51898, '1911'],
#  ['Jersey', 49701, '1921'],
#  ['Jersey', 50462, '1931'],
#  ['Jersey', 51080, '1939'],
#  ['Jersey', 57310, '1951'],
#  ['Jersey', 59489, '1961'],
#  ['Jersey', 69329, '1971'],
#  ['Jersey', 71018, '1976'],
#  ['Jersey', 76050, '1981'],
#  ['Jersey', 80212, '1986'],
#  ['Jersey', 82809, '1989'],
#  ['Jersey', 84082, '1991'],
#  ['Jersey', 85150, '1996'],
#  ['Jersey', 87186, '2001'],
#  ['Jersey', 97857, '2011'],
#  ['Malta', 305991, '1948'],
#  ['Malta', 319620, '1957'],
#  ['Malta', 314216, '1967'],
#  ['Malta', 345418, '1985'],
#  ['Malta', 378132, '1995'],
#  ['Malta', 404962, '2005'],
#  ['Malta', 417432, '2010'],
#  ['Malta', 417432, '2011'],
#  ['Isle of Man', 55253, '1950'],
#  ['Isle of Man', 54024, '1951'],
#  ['Isle of Man', 47166, '1961'],
#  ['Isle of Man', 49312, '1966'],
#  ['Isle of Man', 53228, '1971'],
#  ['Isle of Man', 60496, '1976'],
#  ['Isle of Man', 64679, '1981'],
#  ['Isle of Man', 64282, '1986'],
#  ['Isle of Man', 69788, '1991'],
#  ['Isle of Man', 71714, '1996'],
#  ['Isle of Man', 76315, '2001'],
#  ['Isle of Man', 80058, '2006'],
#  ['Isle of Man', 84497, '2011'],
#  ['Moldova', 2341003, '1950'],
#  ['Moldova', 2513483, '1959'],
#  ['Moldova', 3085080, '1970'],
#  ['Moldova', 3372051, '1979'],
#  ['Moldova', 3657665, '1989'],
#  ['Moldova', 3383332, '2004'],
#  ['Moldova', 3559541, '2012'],
#  ['Portugal', 3829618, '1864'],
#  ['Portugal', 4550699, '1878'],
#  ['Portugal', 5049729, '1890'],
#  ['Portugal', 5423132, '1900'],
#  ['Portugal', 5960056, '1911'],
#  ['Portugal', 6032991, '1920'],
#  ['Portugal', 6825883, '1930'],
#  ['Portugal', 7755423, '1940'],
#  ['Portugal', 8510240, '1950'],
#  ['Portugal', 8889392, '1960'],
#  ['Portugal', 8611125, '1970'],
#  ['Portugal', 9833014, '1981'],
#  ['Portugal', 9862540, '1991'],
#  ['Portugal', 10356117, '2001'],
#  ['Portugal', 10561614, '2011'],
#  ['Svalbard', 2116, '1987'],
#  ['Svalbard', 1872, '2014'],
#  ['United Kingdom', 50616012, '1950'],
#  ['United Kingdom', 52544326, '1960'],
#  ['United Kingdom', 55645296, '1970'],
#  ['United Kingdom', 56302877, '1980'],
#  ['United Kingdom', 57214478, '1990'],
#  ['United Kingdom', 54888844, '1991'],
#  ['United Kingdom', 58789194, '2001'],
#  ['United Kingdom', 63182178, '2011'],
#  ['United Kingdom', 64105654, '2013'],
#  ['Afghanistan', 7450738, '1950'],
#  ['Afghanistan', 8774440, '1960'],
#  ['Afghanistan', 11015621, '1970'],
#  ['Afghanistan', 13051358, '1979'],
#  ['Afghanistan', 22575900, '2006'],
#  ['Afghanistan', 24485600, '2009'],
#  ['Afghanistan', 26023100, '2013'],
#  ['China', 543776080, '1950'],
#  ['China', 650680114, '1960'],
#  ['China', 814377714, '1970'],
#  ['China', 984015677, '1980'],
#  ['China', 1165428967, '1990'],
#  ['China', 1242612226, '2000'],
#  ['China', 1339724852, '2010'],
#  ['China', 1360720000, '2013'],
#  ['Iran', 17119263, '1950'],
#  ['Iran', 18954704, '1956'],
#  ['Iran', 25078923, '1966'],
#  ['Iran', 33708744, '1976'],
#  ['Iran', 49445010, '1986'],
#  ['Iran', 55837163, '1991'],
#  ['Iran', 60055488, '1996'],
#  ['Iran', 70495782, '2006'],
#  ['Iran', 75149669, '2011'],
#  ['Pakistan', 37542380, '1950'],
#  ['Pakistan', 31883037, '1951'],
#  ['Pakistan', 46116934, '1961'],
#  ['Pakistan', 65309000, '1972'],
#  ['Pakistan', 84525300, '1981'],
#  ['Pakistan', 132352279, '1998'],
#  ['Pakistan', 143832014, '2000'],
#  ['Pakistan', 173149306, '2010'],
#  ['Tajikistan', 1485000, '1939'],
#  ['Tajikistan', 1981000, '1959'],
#  ['Tajikistan', 2898000, '1970'],
#  ['Tajikistan', 3806220, '1979'],
#  ['Tajikistan', 5092603, '1989'],
#  ['Tajikistan', 6127493, '2000'],
#  ['Tajikistan', 7564502, '2010'],
#  ['Tajikistan', 8161100, '2014'],
#  ['Turkmenistan', 1211000, '1950'],
#  ['Turkmenistan', 1516375, '1959'],
#  ['Turkmenistan', 2764748, '1979'],
#  ['Turkmenistan', 3522717, '1989'],
#  ['Turkmenistan', 4993500, '1995'],
#  ['Turkmenistan', 5478900, '2001'],
#  ['Turkmenistan', 5041995, '2010'],
#  ['Uzbekistan', 6313997, '1950'],
#  ['Uzbekistan', 8558503, '1960'],
#  ['Uzbekistan', 11972994, '1970'],
#  ['Uzbekistan', 16026812, '1980'],
#  ['Uzbekistan', 20555113, '1990'],
#  ['Uzbekistan', 23418381, '1997'],
#  ['Uzbekistan', 24828562, '2000'],
#  ['Uzbekistan', 27769270, '2010'],
#  ['Armenia', 881300, '1926'],
#  ['Armenia', 1282300, '1939'],
#  ['Armenia', 1763048, '1959'],
#  ['Armenia', 2491900, '1970'],
#  ['Armenia', 3037259, '1979'],
#  ['Armenia', 3304776, '1989'],
#  ['Armenia', 3213011, '2001'],
#  ['Armenia', 3018854, '2011'],
#  ['Armenia', 3026879, '2013'],
#  ['Georgia', 3527004, '1950'],
#  ['Georgia', 4044045, '1959'],
#  ['Georgia', 4993182, '1979'],
#  ['Georgia', 5400841, '1989'],
#  ['Georgia', 4371535, '2002'],
#  ['Georgia', 4483800, '2013'],
#  ['Azerbaijan', 1806700, '1897'],
#  ['Azerbaijan', 2313700, '1926'],
#  ['Azerbaijan', 3205200, '1939'],
#  ['Azerbaijan', 3697717, '1959'],
#  ['Azerbaijan', 5117100, '1970'],
#  ['Azerbaijan', 6026515, '1979'],
#  ['Azerbaijan', 7021178, '1989'],
#  ['Azerbaijan', 7953438, '1999'],
#  ['Azerbaijan', 8922447, '2009'],
#  ['Azerbaijan', 9356500, '2013'],
#  ['Bahrain', 89970, '1941'],
#  ['Bahrain', 109650, '1950'],
#  ['Bahrain', 143135, '1959'],
#  ['Bahrain', 182203, '1965'],
#  ['Bahrain', 216078, '1971'],
#  ['Bahrain', 350798, '1981'],
#  ['Bahrain', 508037, '1991'],
#  ['Bahrain', 650604, '2001'],
#  ['Bahrain', 1106509, '2008'],
#  ['Bahrain', 1234596, '2010'],
#  ['Bangladesh', 28927786, '1901'],
#  ['Bangladesh', 31555056, '1911'],
#  ['Bangladesh', 33254096, '1921'],
#  ['Bangladesh', 35604170, '1931'],
#  ['Bangladesh', 41997297, '1941'],
#  ['Bangladesh', 44165740, '1951'],
#  ['Bangladesh', 55222663, '1961'],
#  ['Bangladesh', 76398000, '1974'],
#  ['Bangladesh', 89912000, '1981'],
#  ['Bangladesh', 106314992, '1991'],
#  ['Bangladesh', 124355263, '2001'],
#  ['Bangladesh', 149772364, '2011'],
#  ['Myanmar', 7722053, '1891'],
#  ['Myanmar', 10490624, '1901'],
#  ['Myanmar', 12115217, '1911'],
#  ['Myanmar', 13212000, '1921'],
#  ['Myanmar', 14667000, '1931'],
#  ['Myanmar', 16823798, '1941'],
#  ['Myanmar', 28084513, '1973'],
#  ['Myanmar', 34124908, '1983'],
#  ['Myanmar', 45975625, '1997'],
#  ['Myanmar', 52171000, '2002'],
#  ['Myanmar', 51419420, '2014'],
#  ['India', 238396327, '1901'],
#  ['India', 252093390, '1911'],
#  ['India', 251321213, '1921'],
#  ['India', 278977238, '1931'],
#  ['India', 318660580, '1941'],
#  ['India', 361088090, '1951'],
#  ['India', 439234771, '1961'],
#  ['India', 548159652, '1971'],
#  ['India', 683329097, '1981'],
#  ['India', 843387888, '1991'],
#  ['India', 1028610328, '2001'],
#  ['India', 1210854977, '2011'],
#  ['Bhutan', 176795, '1950'],
#  ['Bhutan', 224155, '1960'],
#  ['Bhutan', 291555, '1970'],
#  ['Bhutan', 412745, '1980'],
#  ['Bhutan', 535738, '1990'],
#  ['Bhutan', 564350, '2000'],
#  ['Bhutan', 672425, '2005'],
#  ['Bhutan', 733004, '2013'],
#  ['Brunei', 48001, '1950'],
#  ['Brunei', 81817, '1960'],
#  ['Brunei', 129719, '1970'],
#  ['Brunei', 136256, '1971'],
#  ['Brunei', 192832, '1981'],
#  ['Brunei', 260482, '1991'],
#  ['Brunei', 332844, '2001'],
#  ['Brunei', 393372, '2011'],
#  ['Malaysia', 6109907, '1950'],
#  ['Malaysia', 8160975, '1960'],
#  ['Malaysia', 10623732, '1970'],
#  ['Malaysia', 13136109, '1980'],
#  ['Malaysia', 18379655, '1991'],
#  ['Malaysia', 23274690, '2000'],
#  ['Malaysia', 27565821, '2010'],
#  ['Laos', 1682917, '1950'],
#  ['Laos', 2119731, '1960'],
#  ['Laos', 2685174, '1970'],
#  ['Laos', 3250924, '1980'],
#  ['Laos', 3570000, '1985'],
#  ['Laos', 4581258, '1995'],
#  ['Laos', 5621982, '2005'],
#  ['Laos', 6514432, '2012'],
#  ['Thailand', 8149487, '1909'],
#  ['Thailand', 9207355, '1919'],
#  ['Thailand', 11506207, '1929'],
#  ['Thailand', 14464105, '1937'],
#  ['Thailand', 17442689, '1947'],
#  ['Thailand', 20095130, '1956'],
#  ['Thailand', 26257916, '1960'],
#  ['Thailand', 34397374, '1970'],
#  ['Thailand', 44824540, '1980'],
#  ['Thailand', 54548530, '1990'],
#  ['Thailand', 60916441, '2000'],
#  ['Thailand', 65981659, '2010'],
#  ['Cambodia', 4432716, '1950'],
#  ['Cambodia', 5720019, '1960'],
#  ['Cambodia', 5728771, '1962'],
#  ['Cambodia', 11437656, '1998'],
#  ['Cambodia', 13395682, '2008'],
#  ['Cambodia', 14364931, '2010'],
#  ['Vietnam', 24949467, '1950'],
#  ['Vietnam', 32912298, '1960'],
#  ['Vietnam', 43782542, '1970'],
#  ['Vietnam', 54897387, '1980'],
#  ['Vietnam', 68909883, '1990'],
#  ['Vietnam', 76327900, '1999'],
#  ['Vietnam', 85846997, '2009'],
#  ['Vietnam', 88772900, '2012'],
#  ['Kazakhstan', 6702996, '1950'],
#  ['Kazakhstan', 9303801, '1959'],
#  ['Kazakhstan', 13026274, '1970'],
#  ['Kazakhstan', 14709508, '1979'],
#  ['Kazakhstan', 16232324, '1989'],
#  ['Kazakhstan', 14981281, '1999'],
#  ['Kazakhstan', 16009597, '2009'],
#  ['Kazakhstan', 17165239, '2014'],
#  ['North Korea', 6014099, '1925'],
#  ['North Korea', 6537303, '1930'],
#  ['North Korea', 7920279, '1940'],
#  ['North Korea', 8554857, '1944'],
#  ['North Korea', 20522351, '1993'],
#  ['North Korea', 23349859, '2008'],
#  ['North Korea', 24500520, '2010'],
#  ['Kyrgyzstan', 1740000, '1950'],
#  ['Kyrgyzstan', 2065837, '1959'],
#  ['Kyrgyzstan', 3522832, '1979'],
#  ['Kyrgyzstan', 4257755, '1989'],
#  ['Kyrgyzstan', 4850734, '1999'],
#  ['Kyrgyzstan', 5107640, '2009'],
#  ['Kyrgyzstan', 5776600, '2014'],
#  ['Hong Kong', 283205, '1901'],
#  ['Hong Kong', 456739, '1911'],
#  ['Hong Kong', 625166, '1921'],
#  ['Hong Kong', 849751, '1931'],
#  ['Hong Kong', 3133131, '1961'],
#  ['Hong Kong', 3936630, '1971'],
#  ['Hong Kong', 4986560, '1981'],
#  ['Hong Kong', 5522281, '1991'],
#  ['Hong Kong', 6217556, '1996'],
#  ['Hong Kong', 6708389, '2001'],
#  ['Hong Kong', 6864346, '2006'],
#  ['Hong Kong', 7071576, '2011'],
#  ['Macao', 187772, '1950'],
#  ['Macao', 169299, '1960'],
#  ['Macao', 248636, '1970'],
#  ['Macao', 241729, '1981'],
#  ['Macao', 355693, '1991'],
#  ['Macao', 435235, '2001'],
#  ['Macao', 502113, '2006'],
#  ['Macao', 552503, '2011'],
#  ['Mongolia', 738200, '1935'],
#  ['Mongolia', 759061, '1944'],
#  ['Mongolia', 845481, '1956'],
#  ['Mongolia', 1017158, '1963'],
#  ['Mongolia', 1197595, '1969'],
#  ['Mongolia', 1595006, '1979'],
#  ['Mongolia', 2044000, '1989'],
#  ['Mongolia', 2400314, '2000'],
#  ['Mongolia', 2754685, '2010'],
#  ['Nepal', 5638749, '1911'],
#  ['Nepal', 5573788, '1920'],
#  ['Nepal', 5532574, '1930'],
#  ['Nepal', 6283649, '1941'],
#  ['Nepal', 8256625, '1954'],
#  ['Nepal', 9412996, '1961'],
#  ['Nepal', 11555983, '1971'],
#  ['Nepal', 15022839, '1981'],
#  ['Nepal', 18489097, '1991'],
#  ['Nepal', 23151423, '2001'],
#  ['Nepal', 26494504, '2011'],
#  ['Christmas Island', 2771, '2001'],
#  ['Christmas Island', 2072, '2011'],
#  ['Cocos Islands', 628, '2005'],
#  ['Cocos Islands', 596, '2010'],
#  ['Cyprus', 186173, '1881'],
#  ['Cyprus', 209286, '1891'],
#  ['Cyprus', 237022, '1901'],
#  ['Cyprus', 274108, '1911'],
#  ['Cyprus', 310715, '1921'],
#  ['Cyprus', 347959, '1931'],
#  ['Cyprus', 450114, '1946'],
#  ['Cyprus', 573566, '1960'],
#  ['Cyprus', 631778, '1973'],
#  ['Cyprus', 612851, '1976'],
#  ['Cyprus', 512098, '1982'],
#  ['Cyprus', 602025, '1992'],
#  ['Cyprus', 689565, '2001'],
#  ['Cyprus', 840407, '2011'],
#  ['Gaza Strip', 1022207, '1997'],
#  ['Gaza Strip', 1416963, '2007'],
#  ['Gaza Strip', 1760037, '2014'],
#  ['Israel', 1257971, '1950'],
#  ['Israel', 2089891, '1960'],
#  ['Israel', 2179491, '1961'],
#  ['Israel', 3147683, '1972'],
#  ['Israel', 4037620, '1983'],
#  ['Israel', 5548523, '1995'],
#  ['Israel', 7412200, '2008'],
#  ['Israel', 7552000, '2009'],
#  ['Israel', 7420368, '2010'],
#  ['Egypt', 18967000, '1947'],
#  ['Egypt', 26085000, '1960'],
#  ['Egypt', 36626204, '1976'],
#  ['Egypt', 48254238, '1986'],
#  ['Egypt', 59312914, '1996'],
#  ['Egypt', 72798031, '2006'],
#  ['Egypt', 81395541, '2012'],
#  ['Egypt', 83667047, '2013'],
#  ['Indonesia', 72592192, '1950'],
#  ['Indonesia', 88692697, '1960'],
#  ['Indonesia', 97100000, '1961'],
#  ['Indonesia', 119208229, '1971'],
#  ['Indonesia', 147490298, '1980'],
#  ['Indonesia', 179378946, '1990'],
#  ['Indonesia', 205132458, '2000'],
#  ['Indonesia', 237641326, '2010'],
#  ['Indonesia', 252124458, '2014'],
#  ['Timor-Leste', 433398, '1950'],
#  ['Timor-Leste', 499681, '1960'],
#  ['Timor-Leste', 604392, '1970'],
#  ['Timor-Leste', 555350, '1980'],
#  ['Timor-Leste', 747557, '1990'],
#  ['Timor-Leste', 787340, '2001'],
#  ['Timor-Leste', 923198, '2004'],
#  ['Timor-Leste', 1066582, '2010'],
#  ['Papua New Guinea', 1708192, '1950'],
#  ['Papua New Guinea', 1966957, '1960'],
#  ['Papua New Guinea', 2184986, '1966'],
#  ['Papua New Guinea', 2489936, '1971'],
#  ['Papua New Guinea', 3010727, '1980'],
#  ['Papua New Guinea', 3761954, '1990'],
#  ['Papua New Guinea', 5190786, '2000'],
#  ['Papua New Guinea', 7275324, '2011'],
#  ['Iraq', 5719191, '1950'],
#  ['Iraq', 6339960, '1957'],
#  ['Iraq', 8047415, '1965'],
#  ['Iraq', 12000497, '1977'],
#  ['Iraq', 16335199, '1987'],
#  ['Iraq', 22046244, '1997'],
#  ['Iraq', 25897848, '2003'],
#  ['Iraq', 33330512, '2011'],
#  ['Jordan', 448861, '1950'],
#  ['Jordan', 888632, '1960'],
#  ['Jordan', 1706226, '1961'],
#  ['Jordan', 2100019, '1979'],
#  ['Jordan', 4139458, '1994'],
#  ['Jordan', 5103639, '2004'],
#  ['Jordan', 6249000, '2011'],
#  ['Kuwait', 152249, '1950'],
#  ['Kuwait', 190794, '1957'],
#  ['Kuwait', 303874, '1961'],
#  ['Kuwait', 467339, '1965'],
#  ['Kuwait', 738663, '1970'],
#  ['Kuwait', 994837, '1975'],
#  ['Kuwait', 1357952, '1980'],
#  ['Kuwait', 1697301, '1985'],
#  ['Kuwait', 1575570, '1995'],
#  ['Kuwait', 2193651, '2005'],
#  ['Kuwait', 2991580, '2010'],
#  ['Saudi Arabia', 3121336, '1950'],
#  ['Saudi Arabia', 4072110, '1960'],
#  ['Saudi Arabia', 5802967, '1970'],
#  ['Saudi Arabia', 9843265, '1980'],
#  ['Saudi Arabia', 16206078, '1990'],
#  ['Saudi Arabia', 16948388, '1992'],
#  ['Saudi Arabia', 19409058, '1997'],
#  ['Saudi Arabia', 22678262, '2004'],
#  ['Saudi Arabia', 27136977, '2010'],
#  ['Syria', 3413329, '1950'],
#  ['Syria', 4565121, '1960'],
#  ['Syria', 6304685, '1970'],
#  ['Syria', 9046144, '1981'],
#  ['Syria', 13782315, '1994'],
#  ['Syria', 17920844, '2004'],
#  ['Syria', 20866000, '2010'],
#  ['Lebanon', 1334618, '1950'],
#  ['Lebanon', 1804927, '1960'],
#  ['Lebanon', 2126325, '1970'],
#  ['Lebanon', 3111829, '1996'],
#  ['Lebanon', 3759136, '2007'],
#  ['Lebanon', 4341092, '2010'],
#  ['West Bank', 1873476, '1997'],
#  ['West Bank', 2350583, '2007'],
#  ['West Bank', 2790331, '2014'],
#  ['Japan', 82199470, '1950'],
#  ['Japan', 92500754, '1960'],
#  ['Japan', 103707537, '1970'],
#  ['Japan', 115912104, '1980'],
#  ['Japan', 122249285, '1990'],
#  ['Japan', 125449703, '1997'],
#  ['Japan', 125714674, '2000'],
#  ['Japan', 127767994, '2005'],
#  ['Japan', 128057352, '2010'],
#  ['Japan', 127298000, '2013'],
#  ['South Korea', 20166756, '1949'],
#  ['South Korea', 21502386, '1955'],
#  ['South Korea', 24989241, '1960'],
#  ['South Korea', 29159640, '1966'],
#  ['South Korea', 31435252, '1970'],
#  ['South Korea', 34678972, '1975'],
#  ['South Korea', 37406815, '1980'],
#  ['South Korea', 40419652, '1985'],
#  ['South Korea', 43390374, '1990'],
#  ['South Korea', 44553710, '1995'],
#  ['South Korea', 46136101, '2000'],
#  ['South Korea', 48219172, '2010'],
#  ['South Korea', 51141463, '2013'],
#  ['Maldives', 73716, '1950'],
#  ['Maldives', 88960, '1960'],
#  ['Maldives', 97743, '1965'],
#  ['Maldives', 103801, '1967'],
#  ['Maldives', 128697, '1974'],
#  ['Maldives', 142832, '1977'],
#  ['Maldives', 180088, '1985'],
#  ['Maldives', 213215, '1990'],
#  ['Maldives', 244814, '1995'],
#  ['Maldives', 270101, '2000'],
#  ['Maldives', 298968, '2006'],
#  ['Maldives', 325694, '2010'],
#  ['Maldives', 341256, '2014'],
#  ['Oman', 456418, '1950'],
#  ['Oman', 551737, '1960'],
#  ['Oman', 723850, '1970'],
#  ['Oman', 1154375, '1980'],
#  ['Oman', 1810103, '1990'],
#  ['Oman', 2018074, '1993'],
#  ['Oman', 2186548, '1997'],
#  ['Oman', 2340815, '2003'],
#  ['Oman', 2773479, '2010'],
#  ['Oman', 3623001, '2012'],
#  ['United Arab Emirates', 69590, '1950'],
#  ['United Arab Emirates', 89608, '1960'],
#  ['United Arab Emirates', 180226, '1968'],
#  ['United Arab Emirates', 557887, '1975'],
#  ['United Arab Emirates', 1042099, '1980'],
#  ['United Arab Emirates', 1379303, '1985'],
#  ['United Arab Emirates', 2411041, '1995'],
#  ['United Arab Emirates', 4106427, '2005'],
#  ['United Arab Emirates', 5066000, '2009'],
#  ['United Arab Emirates', 8441537, '2010'],
#  ['Yemen', 4661279, '1950'],
#  ['Yemen', 5099785, '1960'],
#  ['Yemen', 6096574, '1970'],
#  ['Yemen', 7906977, '1980'],
#  ['Yemen', 11790249, '1990'],
#  ['Yemen', 14587807, '1994'],
#  ['Yemen', 19684603, '2004'],
#  ['Yemen', 24527000, '2012'],
#  ['Philippines', 1502574, '1799'],
#  ['Philippines', 1561251, '1800'],
#  ['Philippines', 1933331, '1812'],
#  ['Philippines', 2106230, '1819'],
#  ['Philippines', 2593287, '1829'],
#  ['Philippines', 3096031, '1840'],
#  ['Philippines', 3857424, '1850'],
#  ['Philippines', 4290381, '1858'],
#  ['Philippines', 4712006, '1870'],
#  ['Philippines', 5567685, '1877'],
#  ['Philippines', 5984727, '1887'],
#  ['Philippines', 6261339, '1896'],
#  ['Philippines', 7635426, '1903'],
#  ['Philippines', 10314310, '1918'],
#  ...]

# %%
df1 = pd.DataFrame(ethnic_list,columns=['country','ethnic_group','percent_population'])
df2 = pd.DataFrame(pop_list,columns=['country','population','year'])
# df1.head(), df2.head()

# %%
df3 = df2.groupby('country',as_index=False).max()[['country','year']]
df2 = df2.sort_values('country').reset_index(drop=True)

# %%
df3.head()
# Out:
#           country  year
# 0     Afghanistan  2013
# 1         Albania  2011
# 2         Algeria  2010
# 3  American Samoa  2010
# 4         Andorra  2011

# %%
df2.head()
# Out:
#        country  population  year
# 0  Afghanistan    26023100  2013
# 1  Afghanistan     7450738  1950
# 2  Afghanistan     8774440  1960
# 3  Afghanistan    11015621  1970
# 4  Afghanistan    13051358  1979

# %%
df2 = df2.merge(df3)
df2.head()
# Out:
#           country  population  year
# 0     Afghanistan    26023100  2013
# 1         Albania     2800138  2011
# 2         Algeria    37062820  2010
# 3  American Samoa       55519  2010
# 4         Andorra       78115  2011

# %%
df = df1.merge(df2,how='left')
df = df.drop('year',axis=1)
df.head()
# Out:
#      country ethnic_group  percent_population  population
# 0    Albania     Albanian                0.95     2800138
# 1    Albania        Greek                0.03     2800138
# 2     Greece        Greek                0.93    10816286
# 3  Macedonia   Macedonian                0.64     2059794
# 4  Macedonia     Albanian                0.25     2059794

# %%
df['ethnic_population'] = round(df.percent_population * df.population,0)
df = df.astype({'ethnic_population': int})
df.head()
# Out:
#      country ethnic_group  percent_population  population  ethnic_population
# 0    Albania     Albanian                0.95     2800138            2660131
# 1    Albania        Greek                0.03     2800138              84004
# 2     Greece        Greek                0.93    10816286           10059146
# 3  Macedonia   Macedonian                0.64     2059794            1318268
# 4  Macedonia     Albanian                0.25     2059794             514948

# %%
df = df.groupby('ethnic_group',as_index=False).sum()[['ethnic_group','ethnic_population']]
df.head()
# Out:
#            ethnic_group  ethnic_population
# 0                Acholi            1394273
# 1                  Afar            1978333
# 2               African          318460485
# 3       African descent               2832
# 4  African-white-Indian             353062

# %%
# 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
df.sort_values('ethnic_population',ascending=False).head(10)
# Out:
#     ethnic_group  ethnic_population
# 113  Han Chinese         1251862400
# 120   Indo-Aryan          871815583
# 89      European          495529606
# 2        African          318460485
# 77     Dravidian          302713744
# 176      Mestizo          157735294
# 42       Bengali          146776917
# 217      Russian          132126454
# 128     Japanese          126025020
# 163        Malay          120166051

# %%
# build a list of list elements to create dataframe
code_list = []

for element in root.iter('country'):
    d = element.attrib
    l = [element.find('name').text,d['car_code']]
    code_list.append(l)
    
code_list
# Out:
# [['Albania', 'AL'],
#  ['Greece', 'GR'],
#  ['Macedonia', 'MK'],
#  ['Serbia', 'SRB'],
#  ['Montenegro', 'MNE'],
#  ['Kosovo', 'KOS'],
#  ['Andorra', 'AND'],
#  ['France', 'F'],
#  ['Spain', 'E'],
#  ['Austria', 'A'],
#  ['Czech Republic', 'CZ'],
#  ['Germany', 'D'],
#  ['Hungary', 'H'],
#  ['Italy', 'I'],
#  ['Liechtenstein', 'FL'],
#  ['Slovakia', 'SK'],
#  ['Slovenia', 'SLO'],
#  ['Switzerland', 'CH'],
#  ['Belarus', 'BY'],
#  ['Latvia', 'LV'],
#  ['Lithuania', 'LT'],
#  ['Poland', 'PL'],
#  ['Ukraine', 'UA'],
#  ['Russia', 'R'],
#  ['Belgium', 'B'],
#  ['Luxembourg', 'L'],
#  ['Netherlands', 'NL'],
#  ['Bosnia and Herzegovina', 'BIH'],
#  ['Croatia', 'HR'],
#  ['Bulgaria', 'BG'],
#  ['Romania', 'RO'],
#  ['Turkey', 'TR'],
#  ['Denmark', 'DK'],
#  ['Estonia', 'EW'],
#  ['Faroe Islands', 'FARX'],
#  ['Finland', 'SF'],
#  ['Norway', 'N'],
#  ['Sweden', 'S'],
#  ['Monaco', 'MC'],
#  ['Gibraltar', 'GBZ'],
#  ['Guernsey', 'GBG'],
#  ['Holy See', 'V'],
#  ['Ceuta', 'CEU'],
#  ['Melilla', 'MEL'],
#  ['Iceland', 'IS'],
#  ['Ireland', 'IRL'],
#  ['San Marino', 'RSM'],
#  ['Jersey', 'GBJ'],
#  ['Malta', 'M'],
#  ['Isle of Man', 'GBM'],
#  ['Moldova', 'MD'],
#  ['Portugal', 'P'],
#  ['Svalbard', 'SVAX'],
#  ['United Kingdom', 'GB'],
#  ['Afghanistan', 'AFG'],
#  ['China', 'CN'],
#  ['Iran', 'IR'],
#  ['Pakistan', 'PK'],
#  ['Tajikistan', 'TAD'],
#  ['Turkmenistan', 'TM'],
#  ['Uzbekistan', 'UZB'],
#  ['Armenia', 'ARM'],
#  ['Georgia', 'GE'],
#  ['Azerbaijan', 'AZ'],
#  ['Bahrain', 'BRN'],
#  ['Bangladesh', 'BD'],
#  ['Myanmar', 'MYA'],
#  ['India', 'IND'],
#  ['Bhutan', 'BHT'],
#  ['Brunei', 'BRU'],
#  ['Malaysia', 'MAL'],
#  ['Laos', 'LAO'],
#  ['Thailand', 'THA'],
#  ['Cambodia', 'K'],
#  ['Vietnam', 'VN'],
#  ['Kazakhstan', 'KAZ'],
#  ['North Korea', 'NOK'],
#  ['Kyrgyzstan', 'KGZ'],
#  ['Hong Kong', 'HONX'],
#  ['Macao', 'MACX'],
#  ['Mongolia', 'MNG'],
#  ['Nepal', 'NEP'],
#  ['Christmas Island', 'XMAS'],
#  ['Cocos Islands', 'COCO'],
#  ['Cyprus', 'CY'],
#  ['Gaza Strip', 'GAZA'],
#  ['Israel', 'IL'],
#  ['Egypt', 'ET'],
#  ['Indonesia', 'RI'],
#  ['Timor-Leste', 'TL'],
#  ['Papua New Guinea', 'PNG'],
#  ['Iraq', 'IRQ'],
#  ['Jordan', 'JOR'],
#  ['Kuwait', 'KWT'],
#  ['Saudi Arabia', 'SA'],
#  ['Syria', 'SYR'],
#  ['Lebanon', 'RL'],
#  ['West Bank', 'WEST'],
#  ['Japan', 'J'],
#  ['South Korea', 'ROK'],
#  ['Maldives', 'MV'],
#  ['Oman', 'OM'],
#  ['United Arab Emirates', 'UAE'],
#  ['Yemen', 'YE'],
#  ['Philippines', 'RP'],
#  ['Qatar', 'Q'],
#  ['Singapore', 'SGP'],
#  ['Sri Lanka', 'CL'],
#  ['Taiwan', 'RC'],
#  ['Anguilla', 'AXA'],
#  ['Antigua and Barbuda', 'AG'],
#  ['Aruba', 'ARU'],
#  ['Bahamas', 'BS'],
#  ['Barbados', 'BDS'],
#  ['Belize', 'BZ'],
#  ['Guatemala', 'GCA'],
#  ['Mexico', 'MEX'],
#  ['Bermuda', 'BERM'],
#  ['British Virgin Islands', 'BVIR'],
#  ['Canada', 'CDN'],
#  ['United States', 'USA'],
#  ['Cayman Islands', 'CAYM'],
#  ['Costa Rica', 'CR'],
#  ['Nicaragua', 'NIC'],
#  ['Panama', 'PA'],
#  ['Cuba', 'C'],
#  ['Dominica', 'WD'],
#  ['Dominican Republic', 'DOM'],
#  ['Haiti', 'RH'],
#  ['El Salvador', 'ES'],
#  ['Honduras', 'HCA'],
#  ['Greenland', 'GROX'],
#  ['Grenada', 'WG'],
#  ['Guadeloupe', 'GUAD'],
#  ['Jamaica', 'JA'],
#  ['Martinique', 'MART'],
#  ['Montserrat', 'MNTS'],
#  ['Curacao', 'CUR'],
#  ['Sint Maarten', 'NLSM'],
#  ['Saint Martin', 'SMAR'],
#  ['Saint Barthelemy', 'SBAR'],
#  ['Colombia', 'CO'],
#  ['Puerto Rico', 'PR'],
#  ['Saint Kitts and Nevis', 'KN'],
#  ['Saint Lucia', 'WL'],
#  ['Saint Pierre and Miquelon', 'SPMI'],
#  ['Saint Vincent and the Grenadines', 'WV'],
#  ['Trinidad and Tobago', 'TT'],
#  ['Turks and Caicos Islands', 'TUCA'],
#  ['Virgin Islands', 'VIRG'],
#  ['American Samoa', 'AMSA'],
#  ['Australia', 'AUS'],
#  ['Cook Islands', 'COOK'],
#  ['Fiji', 'FJI'],
#  ['French Polynesia', 'FPOL'],
#  ['Guam', 'GUAM'],
#  ['Kiribati', 'KIR'],
#  ['Marshall Islands', 'MH'],
#  ['Micronesia', 'FSM'],
#  ['Nauru', 'NAU'],
#  ['New Caledonia', 'NCA'],
#  ['New Zealand', 'NZ'],
#  ['Niue', 'NIUE'],
#  ['Norfolk Island', 'NORF'],
#  ['Northern Mariana Islands', 'NMIS'],
#  ['Palau', 'PAL'],
#  ['Pitcairn', 'PITC'],
#  ['Solomon Islands', 'SLB'],
#  ['Tonga', 'TO'],
#  ['Tuvalu', 'TUV'],
#  ['Tokelau', 'TOK'],
#  ['Vanuatu', 'VU'],
#  ['Wallis and Futuna', 'WAFU'],
#  ['Samoa', 'WS'],
#  ['Argentina', 'RA'],
#  ['Bolivia', 'BOL'],
#  ['Brazil', 'BR'],
#  ['Chile', 'RCH'],
#  ['Paraguay', 'PY'],
#  ['Uruguay', 'ROU'],
#  ['Peru', 'PE'],
#  ['French Guiana', 'FGU'],
#  ['Guyana', 'GUY'],
#  ['Suriname', 'SME'],
#  ['Venezuela', 'YV'],
#  ['Ecuador', 'EC'],
#  ['Falkland Islands', 'FALK'],
#  ['Algeria', 'DZ'],
#  ['Libya', 'LAR'],
#  ['Mali', 'RMM'],
#  ['Mauritania', 'RIM'],
#  ['Morocco', 'MA'],
#  ['Niger', 'RN'],
#  ['Tunisia', 'TN'],
#  ['Western Sahara', 'WSA'],
#  ['Angola', 'ANG'],
#  ['Congo', 'RCB'],
#  ['Namibia', 'NAM'],
#  ['Zaire', 'ZRE'],
#  ['Zambia', 'Z'],
#  ['Benin', 'BEN'],
#  ['Burkina Faso', 'BF'],
#  ['Nigeria', 'WAN'],
#  ['Togo', 'RT'],
#  ['Botswana', 'RB'],
#  ['South Africa', 'RSA'],
#  ['Zimbabwe', 'ZW'],
#  ['Cote dIvoire', 'CI'],
#  ['Ghana', 'GH'],
#  ['Burundi', 'BI'],
#  ['Rwanda', 'RWA'],
#  ['Tanzania', 'EAT'],
#  ['Cameroon', 'CAM'],
#  ['Central African Republic', 'RCA'],
#  ['Chad', 'TCH'],
#  ['Equatorial Guinea', 'GQ'],
#  ['Gabon', 'G'],
#  ['Cape Verde', 'CV'],
#  ['Sudan', 'SUD'],
#  ['South Sudan', 'SSD'],
#  ['Comoros', 'COM'],
#  ['Guinea', 'RG'],
#  ['Liberia', 'LB'],
#  ['Djibouti', 'DJI'],
#  ['Eritrea', 'ER'],
#  ['Ethiopia', 'ETH'],
#  ['Somalia', 'SP'],
#  ['Kenya', 'EAK'],
#  ['Gambia', 'WAG'],
#  ['Senegal', 'SN'],
#  ['Guinea-Bissau', 'GNB'],
#  ['Sierra Leone', 'WAL'],
#  ['Uganda', 'EAU'],
#  ['Lesotho', 'LS'],
#  ['Madagascar', 'RM'],
#  ['Malawi', 'MW'],
#  ['Mozambique', 'MOC'],
#  ['Mauritius', 'MS'],
#  ['Mayotte', 'MAYO'],
#  ['Swaziland', 'SD'],
#  ['Reunion', 'REUN'],
#  ['Saint Helena', 'HELX'],
#  ['Sao Tome and Principe', 'STP'],
#  ['Seychelles', 'SY']]

# %%
code_df = pd.DataFrame(code_list,columns=['country','country_code'])
code_df.head()
# Out:
#       country country_code
# 0     Albania           AL
# 1      Greece           GR
# 2   Macedonia           MK
# 3      Serbia          SRB
# 4  Montenegro          MNE

# %%
# build a list of list elements to create dataframe
river_list = []

for element in root.iter('river'):
    d = element.attrib
    
    if element.find('length') is None:
        l = [element.find('name').text,d['country'],element.find('length')]
    else:
        l = [element.find('name').text,d['country'],float(element.find('length').text)]
    river_list.append(l)
    
river_list
# Out:
# [['Thjorsa', 'IS', 230.0],
#  ['Joekulsa a Fjoellum', 'IS', 206.0],
#  ['Glomma', 'N', 604.0],
#  ['Lagen', 'N', 322.0],
#  ['Goetaaelv', 'S', 93.0],
#  ['Klaraelv', 'N S', 460.0],
#  ['Umeaelv', 'S', 470.0],
#  ['Dalaelv', 'S', 520.0],
#  ['Vaesterdalaelv', 'S', 320.0],
#  ['Oesterdalaelv', 'S', 241.0],
#  ['Paatsjoki', 'SF N R', 145.0],
#  ['Ounasjoki', 'SF', 300.0],
#  ['Kemijoki', 'SF', 550.0],
#  ['Oulujoki', 'SF', 107.0],
#  ['Kymijoki', 'SF', 203.0],
#  ['Kokemaeenjoki', 'SF', 121.0],
#  ['Vuoksi', 'SF R', 162.0],
#  ['Thames', 'GB', 346.0],
#  ['Maas', 'NL B F', 925.0],
#  ['Loire', 'F', 1013.0],
#  ['Garonne', 'F E', 647.0],
#  ['Rhone', 'F CH', 812.0],
#  ['Saone', 'F', 480.0],
#  ['Doubs', 'F CH', 453.0],
#  ['Isere', 'F', 290.0],
#  ['Seine', 'F', 776.0],
#  ['Marne', 'F', 514.0],
#  ['Tajo', 'E P', 1007.0],
#  ['Douro', 'E P', 897.0],
#  ['Guadiana', 'E P', 742.0],
#  ['Guadalquivir', 'E', 657.0],
#  ['Ebro', 'E', 925.0],
#  ['Po', 'I', 652.0],
#  ['Ticino', 'CH I', 248.0],
#  ['Adda', 'I', 313.0],
#  ['Mincio', 'I', 75.0],
#  ['Etsch', 'I', 415.0],
#  ['Tiber', 'I', 405.0],
#  ['Arno', 'I', 240.0],
#  ['Donau', 'SRB A D H HR SK BG RO MD UA', 2845.0],
#  ['Breg', 'D', 45.9],
#  ['Brigach', 'D', 43.0],
#  ['Iller', 'D A', 147.0],
#  ['Lech', 'D A', 264.0],
#  ['Isar', 'D A', 295.0],
#  ['Ammer', 'D', 168.0],
#  ['Würm', 'D', 35.0],
#  ['Inn', 'CH A D', 517.0],
#  ['Alz', 'D', 150.0],
#  ['Salzach', 'A D', 225.0],
#  ['Enns', 'A', 254.0],
#  ['March', 'CZ SK A', 358.0],
#  ['Raab', 'A H', 250.0],
#  ['Waag', 'SK', 403.0],
#  ['Drau', 'I A SLO HR H', 749.0],
#  ['Mur', 'A H SLO HR', 453.0],
#  ['Theiss', 'H UA SRB', 1308.0],
#  ['Save', 'SLO HR BIH SRB', 945.0],
#  ['Drina', 'BIH SRB', 346.0],
#  ['Tara', 'MNE BIH', 140.0],
#  ['Piva', 'MNE BIH', 120.0],
#  ['Morava', 'SRB', 185.0],
#  ['Western Morava', 'SRB', 308.0],
#  ['Southern Morava', 'SRB KOS MK', 295.0],
#  ['Olt', 'RO', 615.0],
#  ['Pruth', 'RO MD UA', 953.0],
#  ['Dnjestr', 'UA MD', 1352.0],
#  ['Weser', 'D', 440.0],
#  ['Aller', 'D', 211.0],
#  ['Leine', 'D', 281.0],
#  ['Werra', 'D', 292.0],
#  ['Fulda', 'D', 221.0],
#  ['Elbe', 'D CZ', 1091.0],
#  ['Moldau', 'CZ', 440.0],
#  ['Rhein', 'D CH FL A F NL', 1324.0],
#  ['Main', 'D', 524.0],
#  ['Mosel', 'D L F', 544.0],
#  ['Saar', 'D F', 227.0],
#  ['Neckar', 'D', 367.0],
#  ['Aare', 'CH', 288.0],
#  ['Reuss', 'CH', 164.0],
#  ['Limmat', 'CH', 36.3],
#  ['Oder', 'D PL CZ', 866.0],
#  ['Weichsel', 'PL', 1047.0],
#  ['Narew', 'PL BY', 448.0],
#  ['Western Bug', 'PL BY UA', 772.0],
#  ['Moraca', 'MNE', 99.5],
#  ['Buna', 'AL MNE', 44.0],
#  ['Drin', 'AL', 152.0],
#  ['White Drin', 'AL KOS', 175.0],
#  ['Black Drin', 'AL MK', 133.0],
#  ['Jordan', 'IL WEST JOR SYR RL', 251.0],
#  ['Kura', 'TR GE AZ', 1364.0],
#  ['Schatt al Arab', 'IRQ IR', 193.0],
#  ['Tigris', 'TR SYR IRQ', 1900.0],
#  ['Euphrat', 'TR SYR IRQ', 2736.0],
#  ['Murat', 'TR', 720.0],
#  ['Karasu', 'TR', 720.0],
#  ['Karun', 'IR', 950.0],
#  ['Northern Dwina', 'R', 740.0],
#  ['Suchona', 'R', 558.0],
#  ['Petschora', 'R', 1809.0],
#  ['Newa', 'R', 74.0],
#  ['Swir', 'R', 224.0],
#  ['Narva', 'R EW', 78.0],
#  ['Western Dwina', 'BY LV R', 1020.0],
#  ['Dnister', 'UA MD', 1352.0],
#  ['Dnepr', 'BY UA R', 2201.0],
#  ['Prypjat', 'BY UA', 775.0],
#  ['Don', 'R', 1870.0],
#  ['Volga', 'R', 3531.0],
#  ['Oka', 'R', 1480.0],
#  ['Kama', 'R', 1805.0],
#  ['Ural', 'R KAZ', 2428.0],
#  ['Ob', 'R', 3650.0],
#  ['Irtysch', 'R KAZ CN', 4248.0],
#  ['Tobol', 'R KAZ', 1591.0],
#  ['Ischim', 'R KAZ', 2450.0],
#  ['Katun', 'R', 688.0],
#  ['Jenissej', 'R', 4092.0],
#  ['Angara', 'R', 1779.0],
#  ['Selenge', 'R MNG', 992.0],
#  ['Chatanga', 'R', 1636.0],
#  ['Lena', 'R', 4400.0],
#  ['Amur', 'R CN', 2824.0],
#  ['Schilka', 'R', 560.0],
#  ['Argun', 'R CN', 1620.0],
#  ['Kolyma', 'R', 2129.0],
#  ['Syrdarja', 'KAZ UZB TAD', 2129.0],
#  ['Naryn', 'UZB KGZ', 807.0],
#  ['Amudarja', 'TAD AFG TM UZB', 1415.0],
#  ['Pjandsh', 'AFG TAD', 1141.0],
#  ['Bartang', 'TAD', 133.0],
#  ['Murgab', 'TAD AFG', 395.0],
#  ['Ili', 'CN KAZ', 1001.0],
#  ['Tarim-Yarkend', 'CN', 3260.0],
#  ['Hwangho', 'CN', 4845.0],
#  ['Jangtse', 'CN', 6380.0],
#  ['Mekong', 'CN LAO THA K VN', 4350.0],
#  ['Saluen', 'MYA CN', 2980.0],
#  ['Irawaddy', 'MYA CN', 2170.0],
#  ['Ganges', 'IND BD', 2511.0],
#  ['Brahmaputra', 'CN IND BD', 2896.0],
#  ['Indus', 'PK IND CN', 3180.0],
#  ['Asahan', 'RI', 150.0],
#  ['Yukon River', 'CDN USA', 3185.0],
#  ['Mackenzie River', 'CDN', 1903.0],
#  ['Nelson River', 'CDN', 664.0],
#  ['Saskatchewan River', 'CDN', 1392.0],
#  ['Saint Lawrence River', 'CDN USA', 1197.0],
#  ['Niagara River', 'CDN USA', 58.0],
#  ['Detroit River', 'CDN USA', 200.0],
#  ['Saint Marys River', 'CDN USA', 120.0],
#  ['Straits of Mackinac', 'USA', 0.1],
#  ['Manicouagan', 'CDN', 560.0],
#  ['Riviere Richelieu', 'CDN', 124.0],
#  ['Merrimack River', 'USA', 177.0],
#  ['Connecticut River', 'USA', 655.0],
#  ['Hudson River', 'USA', 493.0],
#  ['Mississippi', 'USA', 3778.0],
#  ['Missouri', 'USA', 4130.0],
#  ['Arkansas', 'USA', 2334.0],
#  ['Ohio River', 'USA', 1579.0],
#  ['Allegheny River', 'USA', 523.0],
#  ['Tennessee', 'USA', 1049.0],
#  ['Columbia River', 'CDN USA', 1953.0],
#  ['Truckee River', 'USA', 225.0],
#  ['Colorado', 'MEX USA', 2330.0],
#  ['Rio Grande', 'MEX USA', 3034.0],
#  ['Rio Lerma', 'MEX', 965.0],
#  ['Rio San Juan', 'NIC CR', 199.0],
#  ['Rio Desaguadero', 'BOL', 383.0],
#  ['Rio Magdalena', 'CO', 1538.0],
#  ['Orinoco', 'YV CO', 2140.0],
#  ['Amazonas', 'CO BR PE', 6448.0],
#  ['Rio Negro', 'BR CO', 2253.0],
#  ['Rio Madeira', 'BR BOL', 1450.0],
#  ['Rio Mamore', 'BOL', 1931.0],
#  ['Tocantins', 'BR', 2640.0],
#  ['Rio Sao Francisco', 'BR', 2830.0],
#  ['Parana', 'RA BR PY', 3998.0],
#  ['Paraguay', 'RA BR PY', 2549.0],
#  ['Uruguay', 'BR ROU RA', 1790.0],
#  ['Gambia', 'RG WAG SN', 1120.0],
#  ['Senegal', 'RMM RIM SN RG', 1430.0],
#  ['Volta', 'GH BF', 1500.0],
#  ['Niger', 'RMM RN WAN RG', 4184.0],
#  ['Bani', 'RMM CI', 430.0],
#  ['Benue', 'WAN CAM', 1400.0],
#  ['Schari', 'TCH CAM RCA', 1400.0],
#  ['Nile', 'ET SUD', None],
#  ['Atbara', 'SUD ETH', 1120.0],
#  ['Blue Nile', 'SUD ETH', 1783.0],
#  ['White Nile', 'SUD SSD', None],
#  ['Sobat', 'SSD', 740.0],
#  ['Pibor', 'SSD ETH', 320.0],
#  ['Baro', 'SSD ETH', 306.0],
#  ['Bahr el-Ghasal', 'SSD', 716.0],
#  ['Bahr el-Djebel/Albert-Nil', 'SSD EAU', None],
#  ['Semliki', 'ZRE EAU', 230.0],
#  ['Victoria Nile', 'EAU', None],
#  ['Akagera', 'EAT RWA EAU', 275.0],
#  ['Jubba', 'ETH SP', 1658.0],
#  ['Shabelle', 'ETH SP', 1820.0],
#  ['Sanaga', 'CAM', 918.0],
#  ['Zaire', 'RCB ZRE', 4374.0],
#  ['Sanga', 'CAM RCA RCB', 530.0],
#  ['Ubangi', 'ZRE RCA RCB', 1120.0],
#  ['Bomu', 'ZRE RCA', 280.0],
#  ['Uelle', 'ZRE', 1130.0],
#  ['Kwa', 'ZRE', 100.0],
#  ['Fimi', 'ZRE', 200.0],
#  ['Lukenie', 'ZRE', 900.0],
#  ['Kasai', 'ANG ZRE', 1983.0],
#  ['Cuango', 'ANG ZRE', 1100.0],
#  ['Cuilo', 'ANG ZRE', 970.0],
#  ['Ruki', 'ZRE', 130.0],
#  ['Busira', 'ZRE', 830.0],
#  ['Tshuapa', 'ZRE', 1300.0],
#  ['Lulua', 'ZRE', 970.0],
#  ['Lomami', 'ZRE', 1450.0],
#  ['Aruwimi', 'ZRE', 1287.0],
#  ['Lualaba', 'ZRE', None],
#  ['Lukuga', 'ZRE', 350.0],
#  ['Ruzizi', 'ZRE RWA BI', 104.0],
#  ['Luvua', 'ZRE', 350.0],
#  ['Luapula', 'ZRE Z', 300.0],
#  ['Zambezi', 'ANG NAM RB Z ZW MOC', 2574.0],
#  ['Chire', 'MW MOC', 402.0],
#  ['Okavango', 'ANG NAM RB', 1700.0],
#  ['Limpopo', 'RSA MOC ZW RB', 1750.0],
#  ['Oranje', 'LS NAM RSA', 2160.0],
#  ['Vaal', 'RSA', 1251.0],
#  ['Murray River', 'AUS', 2589.0],
#  ['Darling River', 'AUS', 2739.0],
#  ['Murrumbidgee River', 'AUS', 1579.0],
#  ['Eucumbene River', 'AUS', 83.0],
#  ['Snowy River', 'AUS', 403.0]]

# %%
river_df = pd.DataFrame(river_list,columns=['river_name','country_code','length'])
river_df.head()
# Out:
#             river_name country_code  length
# 0              Thjorsa           IS   230.0
# 1  Joekulsa a Fjoellum           IS   206.0
# 2               Glomma            N   604.0
# 3                Lagen            N   322.0
# 4            Goetaaelv            S    93.0

# %%
rd = river_df.merge(code_df,how='left')
rd.head()
# Out:
#             river_name country_code  length  country
# 0              Thjorsa           IS   230.0  Iceland
# 1  Joekulsa a Fjoellum           IS   206.0  Iceland
# 2               Glomma            N   604.0   Norway
# 3                Lagen            N   322.0   Norway
# 4            Goetaaelv            S    93.0   Sweden

# %%
# 4. name and country of a) longest river
rd.sort_values('length',ascending=False).head()
# Out:
#     river_name country_code  length country
# 174   Amazonas     CO BR PE  6448.0     NaN
# 137    Jangtse           CN  6380.0   China
# 136    Hwangho           CN  4845.0   China
# 123       Lena            R  4400.0  Russia
# 205      Zaire      RCB ZRE  4374.0     NaN

# %%
# build a list of list elements to create dataframe
lake_list = []

for element in root.iter('lake'):
    d = element.attrib
    
    if element.find('area') is None:
        l = [element.find('name').text,d['country'],element.find('area')]
    else:
        l = [element.find('name').text,d['country'],float(element.find('area').text)]
    lake_list.append(l)
    
lake_list
# Out:
# [['Inari', 'SF', 1040.0],
#  ['Oulujaervi', 'SF', 928.0],
#  ['Kallavesi', 'SF', 472.0],
#  ['Saimaa', 'SF', 4370.0],
#  ['Paeijaenne', 'SF', 1118.0],
#  ['Mjoesa-See', 'N', 368.0],
#  ['Storuman', 'S', 173.0],
#  ['Siljan', 'S', 290.0],
#  ['Maelaren', 'S', 1140.0],
#  ['Vaenern', 'S', 5648.0],
#  ['Vaettern', 'S', 1900.0],
#  ['Arresoe', 'DK', 40.2],
#  ['Loch Ness', 'GB', 56.0],
#  ['Loch Lomond', 'GB', 71.0],
#  ['Bodensee', 'A D CH', 538.5],
#  ['Chiemsee', 'D', 80.0],
#  ['Starnberger See', 'D', 56.36],
#  ['Ammersee', 'D', 46.6],
#  ['Laacher Maar', 'D', 3.3],
#  ['Lac Leman', 'F CH', 581.0],
#  ['Zurichsee', 'CH', 88.0],
#  ['Thunersee', 'CH', 48.3],
#  ['Brienzersee', 'CH', 29.8],
#  ['Vierwaldstattersee', 'CH', 113.7],
#  ['Lago Maggiore', 'I CH', 216.0],
#  ['Lago di Como', 'I', 146.0],
#  ['Lago di Garda ', 'I', 370.0],
#  ['Lago Trasimeno', 'I', 128.0],
#  ['Lago di Bolsena', 'I', 114.0],
#  ['Lago di Bracciano', 'I', 57.0],
#  ['Laguna de Gallocanta', 'E', 14.4],
#  ['Neusiedlersee', 'A H', 320.0],
#  ['Balaton', 'H', 594.0],
#  ['Lake Skutari', 'AL MNE', 368.0],
#  ['Lake Prespa', 'AL MK GR', 273.0],
#  ['Lake Ohrid', 'AL MK', 367.0],
#  ['Kiev Reservoir', 'UA', 922.0],
#  ['Kakhovka Reservoir', 'UA', 2155.0],
#  ['Kremenchuk Reservoir', 'UA', 2252.0],
#  ['Kuybyshev Reservoir', 'R', 6450.0],
#  ['Ozero Ladoga', 'R', 18400.0],
#  ['Ozero Onega', 'R', 9.616],
#  ['Ozero Pskovskoje', 'R EW', 3555.0],
#  ['Ozero Baikal', 'R', 31492.0],
#  ['Ozero Taimyr', 'R', 4560.0],
#  ['Ozero Chanka', 'R CN', 4400.0],
#  ['Ozero Tschany', 'R', 2500.0],
#  ['Dead Sea', 'IL JOR WEST', 41650.0],
#  ['Lake Genezareth', 'IL SYR', 165.0],
#  ['Lake Van', 'TR', 3740.0],
#  ['Lake Keban', 'TR', 675.0],
#  ['Lake Urmia', 'IR', 5470.0],
#  ['Daryacheh ye Namak', 'IR', 1800.0],
#  ['Hamun e Jaz Murian', 'IR', 1600.0],
#  ['Caspian Sea', 'R AZ KAZ IR TM', 386400.0],
#  ['Ozero Aral', 'UZB KAZ', 17160.0],
#  ['Ozero Balchash', 'KAZ', 18428.0],
#  ['Issyk-Kul', 'KGZ', 6236.0],
#  ['Koli Sarez', 'TAD', 80.0],
#  ['Lop Nor', 'CN', 5000.0],
#  ['Laguna de Bay', 'RP', 911.0],
#  ['Lake Toba', 'RI', 1103.0],
#  ['Segara Anak', 'RI', 11.3],
#  ['Qinghai Lake', 'CN', 4583.0],
#  ['Nam Co', 'CN', 1855.0],
#  ['Lake Nasser', 'ET SUD', 5250.0],
#  ['Lake Volta', 'GH', 8502.0],
#  ['Lake Bosumtwi', 'GH', 49.0],
#  ['Lake Kainji', 'WAN', 1243.0],
#  ['Chad Lake', 'RN WAN TCH CAM', 23000.0],
#  ['Barrage de Mbakaou', 'CAM', None],
#  ['Lake Nyos', 'CAM', None],
#  ['Lac Assal', 'DJI', 54.0],
#  ['Lake Abbe', 'DJI ETH', 320.0],
#  ['Lake Abaya', 'ETH', 1285.0],
#  ['Chew Bahir', 'ETH EAK', 800.0],
#  ['Lake Turkana', 'ETH EAK', 6405.0],
#  ['Lake Tana', 'ETH', 3000.0],
#  ['Lake Sese Seko/Albertsee', 'EAU ZRE', 5347.0],
#  ['Rutanzige/Eduardsee', 'ZRE EAU', 2325.0],
#  ['Lake Kioga', 'EAU', 1720.0],
#  ['Lake Victoria', 'EAT EAK EAU', 68870.0],
#  ['Lake Kivu', 'ZRE RWA', 2650.0],
#  ['Lake Tanganjika', 'ZRE Z BI EAT', 32893.0],
#  ['Lake Mweru', 'ZRE Z', 5120.0],
#  ['Lake Bangweulu', 'Z', 10000.0],
#  ['Lake Rukwa', 'EAT', 5760.0],
#  ['Lake Eyasi', 'EAT', 1050.0],
#  ['Lake Natron', 'EAT', 1040.0],
#  ['Lake Malawi', 'MW MOC EAT', 29600.0],
#  ['Lake Chilwa', 'MW MOC', 687.0],
#  ['Lake Mai Ndombe', 'ZRE', 8200.0],
#  ['Malebo Pool', 'RCB ZRE', 500.0],
#  ['Lake Cabora-Bassa', 'MOC', 2800.0],
#  ['Lake Kariba', 'Z ZW', 5580.0],
#  ['Lake Ngami', 'RB', 770.0],
#  ['Etoscha Salt Pan', 'NAM', 6133.0],
#  ['Makarikari Salt Pan', 'RB', 12000.0],
#  ['Great Bear Lake', 'CDN', 31792.0],
#  ['Great Slave Lake', 'CDN', 28568.0],
#  ['Atlin Lake', 'CDN', 798.0],
#  ['Lake Winnipeg', 'CDN', 24420.0],
#  ['Lake Nipigon', 'CDN', 4848.0],
#  ['Lake Manicouagan', 'CDN', 1942.0],
#  ['Lake Ontario', 'CDN USA', 18960.0],
#  ['Lake Erie', 'CDN USA', 25745.0],
#  ['Lake Huron', 'CDN USA', 59600.0],
#  ['Lake Manitou', 'CDN', 104.0],
#  ['Lake Michigan', 'USA', 57800.0],
#  ['Lake Superior', 'CDN USA', 82103.0],
#  ['Lake Champlain', 'USA CDN', 1130.0],
#  ['Lake Winnipesaukee', 'USA', 186.0],
#  ['Lake Okeechobee', 'USA', 1890.0],
#  ['Kentucky Lake', 'USA', 648.0],
#  ['Chickamauga Lake', 'USA', 147.0],
#  ['Franklin. D. Roosevelt Lake', 'USA', 337.0],
#  ['Crater Lake', 'USA', 53.2],
#  ['Great Salt Lake', 'USA', 4400.0],
#  ['Lake Tahoe', 'USA', 497.0],
#  ['Pyramid Lake', 'USA', 487.0],
#  ['Lake Powell', 'USA', 645.0],
#  ['Lake Mead', 'USA', 640.0],
#  ['Fort Peck Lake', 'USA', 981.0],
#  ['Lake Sakakawea', 'USA', 1578.0],
#  ['Lake Oahe', 'USA', 1453.0],
#  ['Lago de Chapala', 'MEX', 1685.0],
#  ['Lake Nicaragua', 'NIC CR', 8157.0],
#  ['Lake Managua', 'NIC', 1035.0],
#  ['Lake Irazu', 'CR', 1.0],
#  ['Lake Maracaibo', 'YV', 13000.0],
#  ['Lago de Sobradinho', 'BR', 4214.0],
#  ['Lake Titicaca', 'BOL PE', 8372.0],
#  ['Poopo', 'BOL', 1340.0],
#  ['Salar de Uyuni', 'BOL', 10582.0],
#  ['Licancabur Crater Lake', 'RCH BOL', 0.005],
#  ['Laguna Mar Chiquita', 'RA', 5770.0],
#  ['Lake Eyre', 'AUS', 9500.0],
#  ['Lake Burley Griffin', 'AUS', 6.64],
#  ['Lake Eucumbene', 'AUS', 145.0],
#  ['Lake Jindabyne', 'AUS', 30.0],
#  ['Lake Hume', 'AUS', 202.0]]

# %%
lake_df = pd.DataFrame(lake_list,columns=['lake_name','country_code','area'])
lake_df.head()
# Out:
#     lake_name country_code    area
# 0       Inari           SF  1040.0
# 1  Oulujaervi           SF   928.0
# 2   Kallavesi           SF   472.0
# 3      Saimaa           SF  4370.0
# 4  Paeijaenne           SF  1118.0

# %%
ld = lake_df.merge(code_df,how='left')
ld.head()
# Out:
#     lake_name country_code    area  country
# 0       Inari           SF  1040.0  Finland
# 1  Oulujaervi           SF   928.0  Finland
# 2   Kallavesi           SF   472.0  Finland
# 3      Saimaa           SF  4370.0  Finland
# 4  Paeijaenne           SF  1118.0  Finland

# %%
# 4. name and country of b) largest lake
ld.sort_values('area',ascending=False).head()
# Out:
#          lake_name    country_code      area        country
# 54     Caspian Sea  R AZ KAZ IR TM  386400.0            NaN
# 109  Lake Superior         CDN USA   82103.0            NaN
# 81   Lake Victoria     EAT EAK EAU   68870.0            NaN
# 106     Lake Huron         CDN USA   59600.0            NaN
# 108  Lake Michigan             USA   57800.0  United States

# %%
# build a list of list elements to create dataframe
air_list = []

for element in root.iter('airport'):
    d = element.attrib
    
    if element.find('elevation').text is None:
        l = [element.find('name').text,d['country'],element.find('elevation')]
    else:
        l = [element.find('name').text,d['country'],float(element.find('elevation').text)]
    air_list.append(l)
    
air_list
# Out:
# [['Herat', 'AFG', 977.0],
#  ['Kabul Intl', 'AFG', 1792.0],
#  ['Tirana Rinas', 'AL', 38.0],
#  ['Cheikh Larbi Tebessi', 'DZ', 811.0],
#  ['Batna Airport', 'DZ', 822.0],
#  ['Soummam', 'DZ', 6.0],
#  ['Tamanrasset', 'DZ', 1377.0],
#  ['Biskra', 'DZ', 88.0],
#  ['Mohamed Boudiaf Intl', 'DZ', 691.0],
#  ['Ain Arnat Airport', 'DZ', 1024.0],
#  ['Es Senia', 'DZ', 90.0],
#  ['Noumerat', 'DZ', 461.0],
#  ['Annaba', 'DZ', 5.0],
#  ['Houari Boumediene', 'DZ', 25.0],
#  ['Zenata', 'DZ', 248.0],
#  ['Pago Pago Intl', 'AMSA', 10.0],
#  ['Lubango', 'ANG', 1762.0],
#  ['Cabinda', 'ANG', 20.0],
#  ['Menongue', 'ANG', 1363.0],
#  ['Luanda 4 De Fevereiro', 'ANG', 74.0],
#  ['Huambo', 'ANG', 1703.0],
#  ['Wallblake', 'AXA', 39.0],
#  ['V C Bird Intl', 'AG', 19.0],
#  ['La Rioja', 'RA', 438.0],
#  ['Jujuy', 'RA', 920.0],
#  ['Comandante Espora', 'RA', 75.0],
#  ['Teniente Benjamin Matienzo', 'RA', 456.0],
#  ['San Luis', 'RA', 710.0],
#  ['Santiago del Estero', 'RA', 200.0],
#  ['Sauce Viejo', 'RA', 17.0],
#  ['Corrientes', 'RA', 62.0],
#  ['Presidente Peron', 'RA', 273.0],
#  ['Salta', 'RA', 1246.0],
#  ['Aeroparque Jorge Newbery', 'RA', 5.0],
#  ['Ministro Pistarini', 'RA', 20.0],
#  ['Ushuaia Malvinas Argentinas', 'RA', 22.0],
#  ['Formosa', 'RA', 59.0],
#  ['Posadas', 'RA', 131.0],
#  ['Rosario', 'RA', 26.0],
#  ['Resistencia', 'RA', 53.0],
#  ['Rio Gallegos', 'RA', 19.0],
#  ['Comodoro Rivadavia', 'RA', 58.0],
#  ['Mar Del Plata', 'RA', 22.0],
#  ['El Plumerillo', 'RA', 704.0],
#  ['Ambrosio L V Taravella', 'RA', 489.0],
#  ['Zvartnots', 'ARM', 865.0],
#  ['Reina Beatrix Intl', 'ARU', 18.0],
#  ['Melbourne Intl', 'AUS', 132.0],
#  ['Sydney Intl', 'AUS', 6.0],
#  ['Cairns Intl', 'AUS', 3.0],
#  ['Townsville', 'AUS', 5.0],
#  ['Brisbane Intl', 'AUS', 4.0],
#  ['Canberra', 'AUS', 575.0],
#  ['Adelaide Intl', 'AUS', 6.0],
#  ['Newcastle Airport', 'AUS', 9.0],
#  ['Darwin Intl', 'AUS', 31.0],
#  ['Perth Intl', 'AUS', 20.0],
#  ['Hobart', 'AUS', 4.0],
#  ['Salzburg', 'A', 430.0],
#  ['Linz', 'A', 298.0],
#  ['Innsbruck', 'A', 581.0],
#  ['Schwechat', 'A', 183.0],
#  ['Graz', 'A', 340.0],
#  ['Woerthersee International Airport', 'A', 138.0],
#  ['Heydar Aliyev', 'AZ', 3.0],
#  ['Lynden Pindling Intl', 'BS', 5.0],
#  ['Bahrain Intl', 'BRN', 2.0],
#  ['Zia Intl', 'BD', 9.0],
#  ['Shah Amanat Intl', 'BD', 4.0],
#  ['Grantley Adams Intl', 'BDS', 52.0],
#  ['Minsk 2', 'BY', 204.0],
#  ['Deurne', 'B', 12.0],
#  ['Brussels South', 'B', 187.0],
#  ['Aéroport de Liège', 'B', 201.0],
#  ['Brussels Natl', 'B', 56.0],
#  ['Philip S W Goldson Intl', 'BZ', 5.0],
#  ['Cadjehoun', 'BEN', 6.0],
#  ['Bermuda Intl', 'BERM', 4.0],
#  ['Paro', 'BHT', 2235.0],
#  ['Heroes Del Acre', 'BOL', 272.0],
#  ['El Alto Intl', 'BOL', 4063.0],
#  ['Viru Viru Intl', 'BOL', 373.0],
#  ['Juana Azurduy De Padilla', 'BOL', 2905.0],
#  ['Tte Av Jorge Henrich Arauz', 'BOL', 155.0],
#  ['Capitan Oriel Lea Plaza', 'BOL', 1855.0],
#  ['Jorge Wilsterman', 'BOL', 2549.0],
#  ['Sarajevo', 'BIH', 521.0],
#  ['Sir Seretse Khama Intl', 'RB', 1006.0],
#  ['Guararapes Gilberto Freyre Intl', 'BR', 10.0],
#  ['Presidente Juscelino Kubitschek', 'BR', 1061.0],
#  ['Boa Vista', 'BR', 84.0],
#  ['Ten Cel Av Cesar Bombonato', 'BR', 943.0],
#  ['Zumbi Dos Palmares', 'BR', 118.0],
#  ['Macapa', 'BR', 17.0],
#  ['Eduardo Gomes Intl', 'BR', 80.0],
#  ['Goiabeiras', 'BR', 3.0],
#  ['Afonso Pena', 'BR', 911.0],
#  ['Santarem', 'BR', 60.0],
#  ['Londrina', 'BR', 569.0],
#  ['Marechal Rondon', 'BR', 188.0],
#  ['Campo Grande', 'BR', 559.0],
#  ['Congonhas', 'BR', 802.0],
#  ['Santos Dumont', 'BR', 3.0],
#  ['Deputado Luis Eduardo Magalhaes', 'BR', 20.0],
#  ['Tancredo Neves Intl', 'BR', 828.0],
#  ['Marechal Cunha Machado Intl', 'BR', 54.0],
#  ['Amarais Airport', 'BR', 612.0],
#  ['Viracopos', 'BR', 662.0],
#  ['Santa Maria', 'BR', 7.0],
#  ['Uberaba', 'BR', 809.0],
#  ['Val De Cans Intl', 'BR', 16.0],
#  ['Senador Petronio Portella', 'BR', 67.0],
#  ['Augusto Severo', 'BR', 52.0],
#  ['Pelotas', 'BR', 18.0],
#  ['Leite Lopes', 'BR', 549.0],
#  ['General Leite de Castro Airport', 'BR', 684.0],
#  ['Governador Valadares Airport', 'BR', 171.0],
#  ['Usiminas', 'BR', 239.0],
#  ['Campo Dos Bugres', 'BR', 754.0],
#  ['Galeao Antonio Carlos Jobim', 'BR', 9.0],
#  ['Pinto Martins Intl', 'BR', 25.0],
#  ['Pampulha Carlos Drummond De Andrade', 'BR', 789.0],
#  ['Governador Jorge Teixeira De Oliveira', 'BR', 90.0],
#  ['Santa Genoveva', 'BR', 747.0],
#  ['Salgado Filho', 'BR', 3.0],
#  ['Guarulhos Gov Andre Franco Montouro', 'BR', 750.0],
#  ['Prefeito Renato Moreira', 'BR', 131.0],
#  ['Ilheus', 'BR', 5.0],
#  ['Terrance B Lettsome Intl', 'BVIR', 5.0],
#  ['Brunei Intl', 'BRU', 22.0],
#  ['Burgas', 'BG', 41.0],
#  ['Varna', 'BG', 70.0],
#  ['Plovdiv', 'BG', 182.0],
#  ['Sofia', 'BG', 531.0],
#  ['Bobo Dioulasso', 'BF', 461.0],
#  ['Ouagadougou', 'BF', 316.0],
#  ['Mandalay Intl', 'MYA', 91.0],
#  ['Yangon Intl', 'MYA', 33.0],
#  ['Bujumbura Intl', 'BI', 787.0],
#  ['Phnom Penh Intl', 'K', 12.0],
#  ['Douala', 'CAM', 10.0],
#  ['Yaounde Nsimalen', 'CAM', 695.0],
#  ['Gander Intl', 'CDN', 151.0],
#  ['Whitehorse Intl', 'CDN', 706.0],
#  ['Iqaluit', 'CDN', 34.0],
#  ['St Johns Intl', 'CDN', 141.0],
#  ['Lester B Pearson Intl', 'CDN', 173.0],
#  ['Calgary Intl', 'CDN', 1084.0],
#  ['Victoria Intl', 'CDN', 19.0],
#  ['London', 'CDN', 278.0],
#  ['Saskatoon J G Diefenbaker Intl', 'CDN', 504.0],
#  ['Yellowknife', 'CDN', 206.0],
#  ['Quebec Jean Lesage Intl', 'CDN', 74.0],
#  ['Thunder Bay', 'CDN', 199.0],
#  ['Regina Intl', 'CDN', 577.0],
#  ['Ottawa Macdonald Cartier Intl', 'CDN', 114.0],
#  ['Pierre Elliott Trudeau Intl', 'CDN', 36.0],
#  ['City Centre', 'CDN', 77.0],
#  ['Winnipeg Intl', 'CDN', 239.0],
#  ['Vancouver Intl', 'CDN', 4.0],
#  ['Hamilton', 'CDN', 238.0],
#  ['Halifax Intl', 'CDN', 145.0],
#  ['Edmonton Intl', 'CDN', 723.0],
#  ['Praia International Airport', 'CV', 70.0],
#  ['Edward Bodden Airfield', 'CAYM', 1.0],
#  ['Owen Roberts Intl', 'CAYM', 2.0],
#  ['Gerrard Smith Intl', 'CAYM', 2.0],
#  ['Bangui M Poko', 'RCA', 368.0],
#  ['Ndjamena Hassan Djamous', 'TCH', 295.0],
#  ['Cerro Moreno Intl', 'RCH', 139.0],
#  ['Pichoy', 'RCH', 18.0],
#  ['La Florida', 'RCH', 147.0],
#  ['Copiapo', 'RCH', 305.0],
#  ['Carriel Sur Intl', 'RCH', 8.0],
#  ['Maquehue', 'RCH', 93.0],
#  ['Arturo Merino Benitez Intl', 'RCH', 474.0],
#  ['Diego Aracena Intl', 'RCH', 47.0],
#  ['Chacalluta', 'RCH', 51.0],
#  ['El Tepual Intl', 'RCH', 90.0],
#  ['Carlos Ibanez Del Campo Intl', 'RCH', 42.0],
#  ['Xiaoshan', 'CN', 7.0],
#  ['Gaoqi', 'CN', 18.0],
#  ['Dongshan', 'CN', 661.0],
#  ['Xiangfan Airport', 'CN', <Element 'elevation' at 0x000001AF6E7BF598>],
#  ['Qingshan', 'CN', 1559.0],
#  ['Meilan', 'CN', 23.0],
#  ['Baita Airport', 'CN', 1084.0],
#  ['Capital Intl', 'CN', 35.0],
#  ['Pudong', 'CN', 4.0],
#  ['Wanzhou Wuqiao Airport', 'CN', 567.0],
#  ['Tianhe', 'CN', 34.0],
#  ['Wuxi Airport', 'CN', 5.0],
#  ['Wenzhou Longwan Airport',
#   'CN',
#   <Element 'elevation' at 0x000001AF6E7C4728>],
#  ['Yinchuan', 'CN', 1098.0],
#  ['Zhuhai Airport', 'CN', 7.0],
#  ['Taiping', 'CN', 139.0],
#  ['Jiamusi Airport', 'CN', 80.0],
#  ['Changchun', 'CN', 69.0],
#  ['Xinzheng', 'CN', 151.0],
#  ['Lanzhou Airport', 'CN', 1948.0],
#  ['Shijiazhuang Daguocun International Airport', 'CN', 71.0],
#  ['Jiangbei', 'CN', 416.0],
#  ['Huanghua', 'CN', 66.0],
#  ['Beihai Airport', 'CN', <Element 'elevation' at 0x000001AF6E7C7C28>],
#  ['Tongliao Airport', 'CN', 730.0],
#  ['Changbei Intl', 'CN', 44.0],
#  ['Wujiaba', 'CN', 1895.0],
#  ['Binhai', 'CN', 3.0],
#  ['Baotou Airport', 'CN', 1013.0],
#  ['Qiqihar Sanjiazi Airport', 'CN', 145.0],
#  ['Wuxu', 'CN', 128.0],
#  ['Lukou', 'CN', 15.0],
#  ['Diwopu', 'CN', 648.0],
#  ['Nantong Airport', 'CN', <Element 'elevation' at 0x000001AF6E7CDF98>],
#  ['Mianyang Airport', 'CN', <Element 'elevation' at 0x000001AF6E7D21D8>],
#  ['Wusu', 'CN', 785.0],
#  ['Baiyun Intl', 'CN', 15.0],
#  ['Luzhou Airport', 'CN', <Element 'elevation' at 0x000001AF6E7D2778>],
#  ['Shubuling Airport', 'CN', <Element 'elevation' at 0x000001AF6E7D2958>],
#  ['Lhasa-Gonggar', 'CN', 4005.0],
#  ['Weihai Airport', 'CN', 44.0],
#  ['Mudanjiang', 'CN', 269.0],
#  ['Zhoushuizi', 'CN', 33.0],
#  ['Jinan', 'CN', 23.0],
#  ['Phoenix International', 'CN', 28.0],
#  ['Longdongbao', 'CN', 1139.0],
#  ['Baoan Intl', 'CN', 4.0],
#  ['Shuangliu', 'CN', 495.0],
#  ['Yanji Airport', 'CN', 190.0],
#  ['Laishan', 'CN', 18.0],
#  ['Yancheng Airport', 'CN', <Element 'elevation' at 0x000001AF6E7DB0E8>],
#  ['Yichang Airport', 'CN', 205.0],
#  ['Yibin', 'CN', 305.0],
#  ['Xuzhou Guanyin Airport', 'CN', 43.0],
#  ['Changle', 'CN', 14.0],
#  ['Xining Caojiabao Airport', 'CN', 2170.0],
#  ['Xianyang', 'CN', 479.0],
#  ['Luogang', 'CN', 33.0],
#  ['Meixian Airport', 'CN', <Element 'elevation' at 0x000001AF6E7DE098>],
#  ['Nanyang Airport', 'CN', <Element 'elevation' at 0x000001AF6E7DE278>],
#  ['Manzhouli', 'CN', <Element 'elevation' at 0x000001AF6E7DE458>],
#  ['Yushu Batang', 'CN', 3963.0],
#  ['Anqing Airport', 'CN', <Element 'elevation' at 0x000001AF6E7DE818>],
#  ['Changde Airport', 'CN', <Element 'elevation' at 0x000001AF6E7DE9F8>],
#  ['Kashi', 'CN', 1381.0],
#  ['Ganzhou Airport', 'CN', <Element 'elevation' at 0x000001AF6E7DEDB8>],
#  ['Aksu Airport', 'CN', 1163.0],
#  ['Korla Airport', 'CN', 927.0],
#  ['Luoyang Airport', 'CN', 64.0],
#  ['Lianyungang Airport', 'CN', <Element 'elevation' at 0x000001AF6E7E3598>],
#  ['Bailian Airport', 'CN', 90.0],
#  ['Weifang Airport', 'CN', <Element 'elevation' at 0x000001AF6E7E3958>],
#  ['Chaoyang Airport', 'CN', 173.0],
#  ['Changzhi Airport', 'CN', <Element 'elevation' at 0x000001AF6E7E3D18>],
#  ['Chifeng Airport', 'CN', <Element 'elevation' at 0x000001AF6E7E3EF8>],
#  ['Dongying Airport', 'CN', 26.0],
#  ['Nanchong Airport', 'CN', <Element 'elevation' at 0x000001AF6E7E8318>],
#  ['Jiujiang Lushan Airport',
#   'CN',
#   <Element 'elevation' at 0x000001AF6E7E84F8>],
#  ['Jingdezhen Airport', 'CN', 34.0],
#  ['Zhanjiang Airport', 'CN', 38.0],
#  ['Wuhai', 'CN', <Element 'elevation' at 0x000001AF6E7E8A98>],
#  ['Guangyuan Airport', 'CN', <Element 'elevation' at 0x000001AF6E7E8C78>],
#  ['Zhoushan Airport', 'CN', 9.0],
#  ['Jinzhou Airport', 'CN', <Element 'elevation' at 0x000001AF6E7ED0E8>],
#  ['Jining Airport ', 'CN', 470.0],
#  ['Quzhou Airport', 'CN', <Element 'elevation' at 0x000001AF6E7ED4A8>],
#  ['Ulanhot Airport', 'CN', <Element 'elevation' at 0x000001AF6E7ED688>],
#  ['Hami Airport', 'CN', 824.0],
#  ['Yining Airport', 'CN', 666.0],
#  ['Liangjiang', 'CN', 174.0],
#  ['Changzhou', 'CN', 12.0],
#  ['Jieyang Chaoshan International Airport',
#   'CN',
#   <Element 'elevation' at 0x000001AF6E7F2048>],
#  ['Datong Airport', 'CN', 1049.0],
#  ['Liuting', 'CN', 10.0],
#  ['Dandong', 'CN', 9.0],
#  ['Shenyang Taoxian International Airport', 'CN', 60.0],
#  ['Hongqiao Intl', 'CN', 3.0],
#  ['Christmas Island', 'XMAS', 279.0],
#  ['Cocos Keeling Island Airport', 'COCO', 3.0],
#  ['Eldorado Intl', 'CO', 2549.0],
#  ['Perales', 'CO', 914.0],
#  ['Gustavo Artunduaga Paredes', 'CO', 245.0],
#  ['El Eden', 'CO', 1216.0],
#  ['La Nubia', 'CO', 2095.0],
#  ['Yariguies', 'CO', 126.0],
#  ['Alfonso Bonilla Aragon Intl', 'CO', 964.0],
#  ['Rafael Nunez', 'CO', 1.0],
#  ['Simon Bolivar', 'CO', 7.0],
#  ['Ernesto Cortissoz', 'CO', 30.0],
#  ['Matecana', 'CO', 1346.0],
#  ['Camilo Daza', 'CO', 334.0],
#  ['Palonegro', 'CO', 1188.0],
#  ['Gustavo Rojas Pinilla', 'CO', 6.0],
#  ['Olaya Herrera', 'CO', 1506.0],
#  ['Prince Said Ibrahim', 'COM', 28.0],
#  ['Pointe Noire', 'RCB', 17.0],
#  ['Maya Maya', 'RCB', 320.0],
#  ['Hato', 'CUR', 9.0],
#  ['Ndjili Intl', 'ZRE', 313.0],
#  ['Mbuji Mayi', 'ZRE', 677.0],
#  ['Lubumbashi Intl', 'ZRE', 1309.0],
#  ['Rarotonga Intl', 'COOK', 6.0],
#  ['Tobias Bolanos International Airport', 'CR', 1002.0],
#  ['Daniel Oduber Quiros Intl', 'CR', 82.0],
#  ['Juan Santamaria Intl', 'CR', 921.0],
#  ['Abidjan Felix Houphouet Boigny Intl', 'CI', 6.0],
#  ['Split', 'HR', 24.0],
#  ['Zagreb', 'HR', 108.0],
#  ['Rijeka', 'HR', 85.0],
#  ['Zadar', 'HR', 88.0],
#  ['Antonio Maceo Intl', 'C', 76.0],
#  ['Ignacio Agramonte Intl', 'C', 126.0],
#  ['Frank Pais Intl', 'C', 110.0],
#  ['Rafael Cabrera', 'C', 24.0],
#  ['Jose Marti Intl', 'C', 64.0],
#  ['Larnaca', 'CY', 2.0],
#  ['Ercan International Airport', 'CY', 123.0],
#  ['Karlovy Vary', 'CZ', 606.0],
#  ['Pardubice', 'CZ', 226.0],
#  ['Ruzyne', 'CZ', 380.0],
#  ['Mosnov', 'CZ', 257.0],
#  ['Brno-Tuřany', 'CZ', 235.0],
#  ['Kastrup', 'DK', 5.0],
#  ['Aalborg', 'DK', 3.0],
#  ['Aarhus', 'DK', 25.0],
#  ['Bornholm Ronne', 'DK', 16.0],
#  ['Esbjerg', 'DK', 30.0],
#  ['Ambouli International Airport', 'DJI', 15.0],
#  ['Melville Hall', 'WD', 22.0],
#  ['Las Americas Intl', 'DOM', 18.0],
#  ['Cibao Intl', 'DOM', 172.0],
#  ['Presidente Nicolau Lobato Intl', 'TL', 8.0],
#  ['Seymour', 'EC', 63.0],
#  ['Jose Joaquin De Olmedo Intl', 'EC', 6.0],
#  ['Mariscal Sucre Intl', 'EC', 2813.0],
#  ['Mariscal Lamar', 'EC', 2532.0],
#  ['Hurghada Intl', 'ET', 16.0],
#  ['Aswan Intl', 'ET', 202.0],
#  ['Asyut International Airport', 'ET', 235.0],
#  ['Borg El Arab Intl', 'ET', 54.0],
#  ['Cairo Intl', 'ET', 116.0],
#  ['Alexandria Intl', 'ET', -2.0],
#  ['El Salvador Intl', 'ES', 31.0],
#  ['Malabo', 'GQ', 23.0],
#  ['Bata', 'GQ', 11.0],
#  ['Asmara Intl', 'ER', 2336.0],
#  ['Tallinn-Ulemiste International', 'EW', 40.0],
#  ['Gondar', 'ETH', 1994.0],
#  ['Dire Dawa Intl', 'ETH', 1167.0],
#  ['Bole Intl', 'ETH', 2334.0],
#  ['Gambella', 'ETH', 540.0],
#  ['Port Stanley', 'FALK', 23.0],
#  ['Vagar', 'FARX', 85.0],
#  ['Nausori Intl', 'FJI', 5.0],
#  ['Mariehamn', 'SF', 5.0],
#  ['Oulu', 'SF', 14.0],
#  ['Helsinki Vantaa', 'SF', 55.0],
#  ['Pori', 'SF', 13.0],
#  ['Joensuu', 'SF', 121.0],
#  ['Rovaniemi', 'SF', 196.0],
#  ['Jyvaskyla', 'SF', 140.0],
#  ['Kuopio', 'SF', 98.0],
#  ['Lappeenranta', 'SF', 106.0],
#  ['Tampere Pirkkala', 'SF', 119.0],
#  ['Turku', 'SF', 49.0],
#  ['Vaasa', 'SF', 6.0],
#  ['Basel Mulhouse', 'F', 270.0],
#  ['Provence', 'F', 23.0],
#  ['Mediterranee', 'F', 5.0],
#  ['Carpiquet', 'F', 78.0],
#  ['Angers-Loire Airport', 'F', 59.0],
#  ['Metz Nancy Lorraine', 'F', 265.0],
#  ['Orly', 'F', 89.0],
#  ['Garons', 'F', 94.0],
#  ['Rivesaltes', 'F', 44.0],
#  ['Biard', 'F', 129.0],
#  ['St Jacques', 'F', 38.0],
#  ['Saint Exupery', 'F', 250.0],
#  ['Merignac', 'F', 49.0],
#  ['Entzheim', 'F', 154.0],
#  ['Auvergne', 'F', 332.0],
#  ['Bellegarde', 'F', 396.0],
#  ['Lesquin', 'F', 48.0],
#  ['Charles De Gaulle', 'F', 120.0],
#  ['Campo Dell Oro', 'F', 5.0],
#  ['Val De Loire', 'F', 109.0],
#  ['Blagnac', 'F', 152.0],
#  ['Guipavas', 'F', 99.0],
#  ["Cote d'Azur", 'F', 4.0],
#  ['Nantes Atlantique', 'F', 27.0],
#  ['Saint Barthelemy', 'SBAR', 15.0],
#  ['Rochambeau', 'FGU', 8.0],
#  ["Faa'a International", 'FPOL', 2.0],
#  ['Leon M Ba', 'G', 12.0],
#  ['Banjul Intl', 'WAG', 29.0],
#  ['Tbilisi', 'GE', 495.0],
#  ['Batumi', 'GE', 32.0],
#  ['Kopitnari', 'GE', 68.0],
#  ['Hannover', 'D', 56.0],
#  ['Hamburg', 'D', 16.0],
#  ['Paderborn Lippstadt', 'D', 213.0],
#  ['Westerland Sylt', 'D', 16.0],
#  ['Saarbrücken', 'D', 323.0],
#  ['Tegel', 'D', 37.0],
#  ['Neuenland', 'D', 4.0],
#  ['Schönefeld', 'D', 48.0],
#  ['Stuttgart', 'D', 389.0],
#  ['Lübeck', 'D', 16.0],
#  ['Leipzig Halle', 'D', 142.0],
#  ['Köln Bonn', 'D', 92.0],
#  ['Frankfurt Hahn', 'D', 503.0],
#  ['Frankfurt Main', 'D', 111.0],
#  ['Münster Osnabrück', 'D', 49.0],
#  ['Baden Airpark', 'D', 124.0],
#  ['Dusseldorf', 'D', 45.0],
#  ['Nürnberg', 'D', 319.0],
#  ['Dresden', 'D', 230.0],
#  ['Dortmund', 'D', 130.0],
#  ['Franz Josef Strauss', 'D', 453.0],
#  ['Kotoka Intl', 'GH', 63.0],
#  ['Gibraltar', 'GBZ', 5.0],
#  ['Nikos Kazantzakis', 'GR', 35.0],
#  ['Ioannina', 'GR', 475.0],
#  ['Mikonos', 'GR', 123.0],
#  ['Chios', 'GR', 5.0],
#  ['Rhodes Diagoras', 'GR', 5.0],
#  ['Eleftherios Venizelos Intl', 'GR', 94.0],
#  ['Kefallinia', 'GR', 18.0],
#  ['Megas Alexandros Intl', 'GR', 5.0],
#  ['Ioannis Kapodistrias Intl', 'GR', 2.0],
#  ['Makedonia', 'GR', 7.0],
#  ['Souda', 'GR', 149.0],
#  ['Samos', 'GR', 6.0],
#  ['Kos', 'GR', 126.0],
#  ['Mitilini', 'GR', 18.0],
#  ['Araxos', 'GR', 14.0],
#  ['Dionysios Solomos', 'GR', 5.0],
#  ['Ikaria', 'GR', 24.0],
#  ['Syros Airport', 'GR', 72.0],
#  ['Nuuk', 'GROX', 86.0],
#  ['Point Salines Intl', 'WG', 13.0],
#  ['Le Raizet', 'GUAD', 11.0],
#  ['Guam Intl', 'GUAM', 91.0],
#  ['La Aurora', 'GCA', 1510.0],
#  ['Guernsey', 'GBG', 102.0],
#  ['Conakry', 'RG', 22.0],
#  ['Osvaldo Vieira Intl', 'GNB', 39.0],
#  ['Cheddi Jagan Intl', 'GUY', 29.0],
#  ['Toussaint Louverture Intl', 'RH', 37.0],
#  ['Toncontin Intl', 'HCA', 1004.0],
#  ['Hong Kong Intl', 'HONX', 9.0],
#  ['Ferihegy', 'H', 151.0],
#  ['Keflavik International Airport', 'IS', 52.0],
#  ['Srinagar', 'IND', 1655.0],
#  ['Surat', 'IND', 5.0],
#  ['Dehradun', 'IND', 558.0],
#  ['Indira Gandhi Intl', 'IND', 237.0],
#  ['Lucknow', 'IND', 125.0],
#  ['Coimbatore', 'IND', 404.0],
#  ['Cochin', 'IND', 2.0],
#  ['Bhopal', 'IND', 524.0],
#  ['Bangalore', 'IND', 888.0],
#  ['Trichy', 'IND', 88.0],
#  ['Thiruvananthapuram Intl', 'IND', 5.0],
#  ['Aizawl', 'IND', 305.0],
#  ['Calicut', 'IND', 104.0],
#  ['Netaji Subhash Chandra Bose Intl', 'IND', 5.0],
#  ['Bhubaneshwar', 'IND', 42.0],
#  ['Vijayawada', 'IND', 25.0],
#  ['Varanasi', 'IND', 81.0],
#  ['Diu Airport', 'IND', 9.0],
#  ['Visakhapatnam', 'IND', 5.0],
#  ['Dr Ambedkar Intl', 'IND', 315.0],
#  ['Gorakhpur Airport', 'IND', 79.0],
#  ['Lokpriya Gopinath Bordoloi International Airport', 'IND', 49.0],
#  ['Pune', 'IND', 592.0],
#  ['Goa', 'IND', 56.0],
#  ['Imphal', 'IND', 774.0],
#  ['Devi Ahilyabai Holkar', 'IND', 564.0],
#  ['Rajkot', 'IND', 134.0],
#  ['Hyderabad', 'IND', 531.0],
#  ['Raipur', 'IND', 317.0],
#  ['Jabalpur', 'IND', 495.0],
#  ['Rajahmundry', 'IND', 46.0],
#  ['Jamnagar', 'IND', 21.0],
#  ['Jodhpur', 'IND', 219.0],
#  ['Jaipur', 'IND', 385.0],
#  ['Port Blair', 'IND', 4.0],
#  ['Birsa Munda', 'IND', 655.0],
#  ['Aurangabad', 'IND', 583.0],
#  ['Chandigarh', 'IND', 309.0],
#  ['Agartala', 'IND', 14.0],
#  ['Madurai', 'IND', 140.0],
#  ['Jammu', 'IND', 314.0],
#  ['Amritsar', 'IND', 230.0],
#  ['Chennai Intl', 'IND', 16.0],
#  ['Chhatrapati Shivaji Intl', 'IND', 11.0],
#  ['Ahmedabad', 'IND', 58.0],
#  ['Allahabad', 'IND', 98.0],
#  ['Syamsudin Noor', 'RI', 20.0],
#  ['Wolter Monginsidi', 'RI', 164.0],
#  ['Radin Inten II (Branti) Airport', 'RI', 86.0],
#  ['Hang Nadim', 'RI', 38.0],
#  ['El Tari', 'RI', 102.0],
#  ['Sultan Babullah', 'RI', 15.0],
#  ['Fatmawati Soekarno', 'RI', 15.0],
#  ['Pattimura', 'RI', 10.0],
#  ['Sepinggan', 'RI', 4.0],
#  ['Abdul Rachman Saleh', 'RI', 526.0],
#  ['Sam Ratulangi', 'RI', 80.0],
#  ['Sentani', 'RI', 88.0],
#  ['Lombok International Airport', 'RI', 16.0],
#  ['Achmad Yani', 'RI', 4.0],
#  ['Sultan Thaha', 'RI', 25.0],
#  ['Soekarno Hatta Intl', 'RI', 10.0],
#  ['Husein Sastranegara', 'RI', 743.0],
#  ['Hasanuddin', 'RI', 14.0],
#  ['Bali Ngurah Rai', 'RI', 4.0],
#  ['Mutiara', 'RI', 87.0],
#  ['Depati Amir', 'RI', 33.0],
#  ['Tjilik Riwut', 'RI', 25.0],
#  ['Sultan Mahmud Badaruddin Ii', 'RI', 15.0],
#  ['Jalaluddin', 'RI', 32.0],
#  ['Supadio', 'RI', 3.0],
#  ['Sultan Syarif Kasim Ii', 'RI', 31.0],
#  ['Tabing', 'RI', 3.0],
#  ['Adi Sutjipto', 'RI', 107.0],
#  ['Sultan Iskandarmuda', 'RI', 20.0],
#  ['Polonia', 'RI', 35.0],
#  ['Juanda', 'RI', 3.0],
#  ['Ahwaz', 'IR', 20.0],
#  ['Abadan', 'IR', 6.0],
#  ['Shiraz Shahid Dastghaib Intl', 'IR', 1500.0],
#  ['Esfahan Shahid Beheshti Intl', 'IR', 1542.0],
#  ['Imam Khomeini', 'IR', 1008.0],
#  ['Bushehr', 'IR', 21.0],
#  ['Mashhad', 'IR', 995.0],
#  ['Tabriz Intl', 'IR', 1359.0],
#  ['Bandar Abbas Intl', 'IR', 7.0],
#  ['Al Najaf International Airport', 'IRQ', 152.0],
#  ['Basrah Intl', 'IRQ', 3.0],
#  ['Erbil Intl', 'IRQ', 409.0],
#  ['Baghdad International Airport', 'IRQ', 35.0],
#  ['Sulaymaniyah International Airport', 'IRQ', 760.0],
#  ['Shannon', 'IRL', 14.0],
#  ['Cork', 'IRL', 153.0],
#  ['Dublin', 'IRL', 74.0],
#  ['Isle Of Man', 'GBM', 16.0],
#  ['Ben Gurion', 'IL', 41.0],
#  ['Malpensa', 'I', 234.0],
#  ['Firenze', 'I', 43.0],
#  ['Parma', 'I', 49.0],
#  ['Palermo', 'I', 20.0],
#  ['Perugia', 'I', 211.0],
#  ['Genova Sestri', 'I', 4.0],
#  ['Pisa', 'I', 2.0],
#  ['Pescara', 'I', 15.0],
#  ['Falconara', 'I', 3.0],
#  ['Bari', 'I', 54.0],
#  ['Elmas', 'I', 4.0],
#  ['Bolzano', 'I', 241.0],
#  ['Reggio Calabria', 'I', 29.0],
#  ['Rimini', 'I', 13.0],
#  ['Capodichino', 'I', 90.0],
#  ['Villafranca', 'I', 73.0],
#  ['Fiumicino', 'I', 5.0],
#  ['Venezia Tessera', 'I', 2.0],
#  ['Bergamo Orio Al Serio', 'I', 238.0],
#  ['Torino', 'I', 302.0],
#  ['Ronchi Dei Legionari', 'I', 11.0],
#  ['Bologna', 'I', 38.0],
#  ['Catania Fontanarossa', 'I', 12.0],
#  ['Lampedusa', 'I', 21.0],
#  ['Ciampino', 'I', 130.0],
#  ['Linate', 'I', 108.0],
#  ['Norman Manley Intl', 'JA', 3.0],
#  ['Okayama', 'J', 246.0],
#  ['Naha', 'J', 4.0],
#  ['Oita', 'J', 6.0],
#  ['Yamagata', 'J', 108.0],
#  ['Fukuoka', 'J', 10.0],
#  ['Fukushima Airport', 'J', 372.0],
#  ['Hiroshima', 'J', 332.0],
#  ['Tokyo Intl', 'J', 11.0],
#  ['Hakodate', 'J', 46.0],
#  ['Saga Airport', 'J', 2.0],
#  ['Osaka Intl', 'J', 15.0],
#  ['Akita', 'J', 95.0],
#  ['Toyama', 'J', 29.0],
#  ['Aomori', 'J', 202.0],
#  ['New Chitose', 'J', 25.0],
#  ['Takamatsu', 'J', 185.0],
#  ['Sendai', 'J', 5.0],
#  ['Kansai', 'J', 15.0],
#  ['Niigata', 'J', 2.0],
#  ['Kagoshima', 'J', 276.0],
#  ['Tottori', 'J', 20.0],
#  ['Miyazaki', 'J', 6.0],
#  ['Komatsu', 'J', 11.0],
#  ['Kumamoto', 'J', 196.0],
#  ['Tokushima', 'J', 8.0],
#  ['Kochi', 'J', 13.0],
#  ['New Kitakyushu', 'J', 6.0],
#  ['Chubu Centrair Intl', 'J', 5.0],
#  ['Nagasaki', 'J', 5.0],
#  ['Kobe', 'J', 7.0],
#  ['Narita Intl', 'J', 43.0],
#  ['Yamaguchi Ube', 'J', 7.0],
#  ['Matsuyama', 'J', 8.0],
#  ['Mt. Fuji Shizuoka Airport', 'J', 132.0],
#  ['Jersey', 'GBJ', 84.0],
#  ['Queen Alia Intl', 'JOR', 730.0],
#  ['Semipalatinsk', 'KAZ', 232.0],
#  ['Uralsk', 'KAZ', 38.0],
#  ['Atyrau', 'KAZ', -22.0],
#  ['Aktau', 'KAZ', 6.0],
#  ['Zhezkazgan Airport', 'KAZ', 381.0],
#  ['Kostanay West Airport', 'KAZ', 181.0],
#  ['Ust Kamenogorsk Airport', 'KAZ', 286.0],
#  ['Shymkent', 'KAZ', 422.0],
#  ['Aktyubinsk', 'KAZ', 225.0],
#  ['Almaty', 'KAZ', 681.0],
#  ['Astana Intl', 'KAZ', 355.0],
#  ['Sary-Arka', 'KAZ', 538.0],
#  ['Pavlodar', 'KAZ', 125.0],
#  ['Kzylorda', 'KAZ', 131.0],
#  ['Malindi Airport', 'EAK', 24.0],
#  ['Mombasa Moi Intl', 'EAK', 61.0],
#  ['Jomo Kenyatta International', 'EAK', 1624.0],
#  ['Nairobi Wilson', 'EAK', 1691.0],
#  ['Kisumu', 'EAK', 1157.0],
#  ['Eldoret Intl', 'EAK', 2116.0],
#  ['Bonriki Intl', 'KIR', 3.0],
#  ['Kuwait Intl', 'KWT', 63.0],
#  ['Manas', 'KGZ', 627.0],
#  ['Osh', 'KGZ', 892.0],
#  ['Wattay Intl', 'LAO', 172.0],
#  ['Riga Intl', 'LV', 10.0],
#  ['Rafic Hariri Intl', 'RL', 27.0],
#  ['Moshoeshoe I Intl', 'LS', 1630.0],
#  ['Monrovia Roberts Intl', 'LB', 9.0],
#  ['Benina', 'LAR', 132.0],
#  ['Misratah Airport', 'LAR', 18.0],
#  ['Tripoli Intl', 'LAR', 80.0],
#  ['Kaunas Intl', 'LT', 78.0],
#  ['Vilnius Intl', 'LT', 197.0],
#  ['Luxembourg', 'L', 376.0],
#  ['Macao Intl', 'MACX', 6.0],
#  ['Skopje', 'MK', 238.0],
#  ['Arrachart', 'RM', 114.0],
#  ['Toliara', 'RM', 9.0],
#  ['Ivato', 'RM', 1280.0],
#  ['Chileka Intl', 'MW', 779.0],
#  ['Kamuzu Intl', 'MW', 1230.0],
#  ['Penang Intl', 'MAL', 3.0],
#  ['Sultan Mahmud', 'MAL', 6.0],
#  ['Sandakan', 'MAL', 14.0],
#  ['Kota Kinabalu Intl', 'MAL', 3.0],
#  ['Sultan Ismail', 'MAL', 41.0],
#  ['Kuching Intl', 'MAL', 27.0],
#  ['Sultan Azlan Shah', 'MAL', 40.0],
#  ['Sultan Ismail Petra', 'MAL', 5.0],
#  ['Sultan Abdul Aziz Shah Intl', 'MAL', 27.0],
#  ['Kuantan', 'MAL', 18.0],
#  ['Kuala Lumpur Intl', 'MAL', 21.0],
#  ['Labuan', 'MAL', 31.0],
#  ['Male Intl', 'MV', 2.0],
#  ['Senou', 'RMM', 380.0],
#  ['Luqa', 'M', 91.0],
#  ['Marshall Islands Intl', 'MH', 2.0],
#  ['Le Lamentin', 'MART', 5.0],
#  ['Nouakchott', 'RIM', 2.0],
#  ['Nouadhibou', 'RIM', 5.0],
#  ['Sir Seewoosagur Ramgoolam Intl', 'MS', 57.0],
#  ['Dzaoudzi Pamandzi', 'MAYO', 7.0],
#  ['General Servando Canales Intl', 'MEX', 8.0],
#  ['Ingeniero Alberto Acuna Ongay Intl', 'MEX', 10.0],
#  ['Colima', 'MEX', 752.0],
#  ['Licenciado Y Gen Ignacio Lopez Rayon', 'MEX', 1603.0],
#  ['Angel Albino Corzo', 'MEX', 455.0],
#  ['General Abelardo L Rodriguez Intl', 'MEX', 149.0],
#  ['General Heriberto Jara Intl', 'MEX', 27.0],
#  ['Quetzalcoatl Intl', 'MEX', 148.0],
#  ['Licenciado Manuel Crescencio Rejon Int', 'MEX', 12.0],
#  ['General Mariano Escobedo Intl', 'MEX', 390.0],
#  ['Minatitlan', 'MEX', 11.0],
#  ['C P A Carlos Rovirosa Intl', 'MEX', 14.0],
#  ['General Rodolfo Sanchez Taboada Intl', 'MEX', 23.0],
#  ['Hermanos Serdan Intl', 'MEX', 2244.0],
#  ['General Leobardo C Ruiz Intl', 'MEX', 2177.0],
#  ['Lencero Airport', 'MEX', 953.0],
#  ['Queretaro Intercontinental', 'MEX', 1920.0],
#  ['Licenciado Adolfo Lopez Mateos Intl', 'MEX', 2581.0],
#  ['Tepic', 'MEX', 921.0],
#  ['General Pedro Jose Mendez Intl', 'MEX', 232.0],
#  ['Ponciano Arriaga Intl', 'MEX', 1840.0],
#  ['Chetumal Intl', 'MEX', 12.0],
#  ['General Francisco J Mujica Intl', 'MEX', 1839.0],
#  ['Durango Intl', 'MEX', 1861.0],
#  ['Don Miguel Hidalgo Y Costilla Intl', 'MEX', 1529.0],
#  ['Xoxocotlan Intl', 'MEX', 1521.0],
#  ['General Ignacio P Garcia Intl', 'MEX', 191.0],
#  ['General Lucio Blanco Intl', 'MEX', 42.0],
#  ['Licenciado Benito Juarez Intl', 'MEX', 2230.0],
#  ['General Rafael Buelna Intl', 'MEX', 12.0],
#  ['General R Fierro Villalobos Intl', 'MEX', 1360.0],
#  ['Cancun Intl', 'MEX', 6.0],
#  ['Culiacan Intl', 'MEX', 33.0],
#  ['Tapachula Intl', 'MEX', 30.0],
#  ['General Francisco Javier Mina Intl', 'MEX', 24.0],
#  ['General Manuel Marquez De Leon Intl', 'MEX', 21.0],
#  ['Ciudad Obregon Intl', 'MEX', 63.0],
#  ['Abraham Gonzalez Intl', 'MEX', 1190.0],
#  ['Valle Del Fuerte Intl', 'MEX', 5.0],
#  ['Plan De Guadalupe Intl', 'MEX', 1457.0],
#  ['Jesus Teran Intl', 'MEX', 1863.0],
#  ['Torreon Intl', 'MEX', 1124.0],
#  ['General Juan N Alvarez Intl', 'MEX', 5.0],
#  ['Pohnpei Intl', 'FSM', 3.0],
#  ['Chisinau Intl', 'MD', 122.0],
#  ['Chinggis Khaan Intl', 'MNG', 1330.0],
#  ['Podgorica', 'MNE', 43.0],
#  ['John A. Osborne', 'MNTS', 168.0],
#  ['Angads', 'MA', 468.0],
#  ['Inezgane', 'MA', 27.0],
#  ['Ibn Batouta', 'MA', 19.0],
#  ['Menara', 'MA', 471.0],
#  ['Mohammed V Intl', 'MA', 200.0],
#  ['Cherif El Idrissi', 'MA', 29.0],
#  ['Sale', 'MA', 84.0],
#  ['Saiss', 'MA', 579.0],
#  ['Chimoio Airport', 'MOC', 697.0],
#  ['Nampula', 'MOC', 440.0],
#  ['Tete Chingodzi', 'MOC', 160.0],
#  ['Beira', 'MOC', 10.0],
#  ['Quelimane', 'MOC', 11.0],
#  ['Inhambane', 'MOC', 9.0],
#  ['Pemba', 'MOC', 101.0],
#  ['Maputo', 'MOC', 44.0],
#  ['Lichinga', 'MOC', 1373.0],
#  ['Windhoek Hosea Kutako International Airport ', 'NAM', 1720.0],
#  ['Tribhuvan Intl', 'NEP', 1338.0],
#  ['Rotterdam', 'NL', -5.0],
#  ['Eindhoven', 'NL', 23.0],
#  ['Maastricht', 'NL', 114.0],
#  ['Schiphol', 'NL', -3.0],
#  ['Nauru Intl', 'NAU', 7.0],
#  ['La Tontouta', 'NCA', 16.0],
#  ['Hamilton', 'NZ', 52.0],
#  ['Wellington Intl', 'NZ', 13.0],
#  ['Christchurch Intl', 'NZ', 38.0],
#  ['Auckland Intl', 'NZ', 7.0],
#  ['Dunedin', 'NZ', 1.0],
#  ['Managua Intl', 'NIC', 59.0],
#  ['Diori Hamani', 'RN', 223.0],
#  ['Maiduguri', 'WAN', 335.0],
#  ['Port Harcourt Intl', 'WAN', 27.0],
#  ['Yakubu Gowon', 'WAN', 1290.0],
#  ['Sadiq Abubakar Iii Intl', 'WAN', 308.0],
#  ['Murtala Muhammed', 'WAN', 41.0],
#  ['Benin', 'WAN', 79.0],
#  ['Kaduna', 'WAN', 632.0],
#  ['Mallam Aminu Intl', 'WAN', 476.0],
#  ['Calabar', 'WAN', 64.0],
#  ['Nnamdi Azikiwe Intl', 'WAN', 342.0],
#  ['Enugu', 'WAN', 142.0],
#  ['Yola', 'WAN', 183.0],
#  ['Ilorin', 'WAN', 343.0],
#  ['Niue Intl', 'NIUE', 64.0],
#  ['Norfolk Island Intl', 'NORF', 113.0],
#  ['Francisco C Ada Saipan Intl', 'NMIS', 66.0],
#  ['Pyongyang Sunan Int', 'NOK', 36.0],
#  ['Geiteryggen', 'N', 141.0],
#  ['Svolvaer Helle Airport', 'N', 8.0],
#  ['Airport', 'N', 39.0],
#  ['Framnes', 'N', 30.0],
#  ['Gardermoen', 'N', 208.0],
#  ['Moss', 'N', 53.0],
#  ['Longyear', 'SVAX', 27.0],
#  ['Aro', 'N', 3.0],
#  ['Kjevik', 'N', 17.0],
#  ['Langnes', 'N', 9.0],
#  ['Sola', 'N', 9.0],
#  ['Vaernes', 'N', 17.0],
#  ['Flesland', 'N', 52.0],
#  ['Hammerfest Airport', 'N', 244.0],
#  ['Seeb Intl', 'OM', 15.0],
#  ['Chaklala', 'PK', 509.0],
#  ['Jinnah Intl', 'PK', 30.0],
#  ['Allama Iqbal Intl', 'PK', 217.0],
#  ['Faisalabad Intl', 'PK', 180.0],
#  ['Sukkur', 'PK', 60.0],
#  ['Sialkot Airport', 'PK', 247.0],
#  ['Quetta', 'PK', 1606.0],
#  ['Peshawar Intl', 'PK', 353.0],
#  ['Multan Intl', 'PK', 123.0],
#  ['Babelthuap', 'PAL', 54.0],
#  ['Bocas del Toro Intl', 'PA', 3.0],
#  ['Tocumen Intl', 'PA', 41.0],
#  ['Port Moresby Jacksons Intl', 'PNG', 45.0],
#  ['Ciudad del Este', 'PY', 258.0],
#  ['Silvio Pettirossi Intl', 'PY', 89.0],
#  ['Capt Jose A Quinones Gonzales Intl', 'PE', 30.0],
#  ['Capitan Carlos Martinez De Pinillos', 'PE', 32.0],
#  ['Alferez Fap David Figueroa Fernandini Airport', 'PE', 1851.0],
#  ['Coronel Fap Alfredo Mendivil Duarte', 'PE', 2719.0],
#  ['Pedro Canga', 'PE', 35.0],
#  ['Mayor General FAP Armando Revoredo Iglesias Airport', 'PE', 2677.0],
#  ['Capitan Fap Guillermo Concha Iberico', 'PE', 37.0],
#  ['Cap Fap David Abenzur Rengifo Intl', 'PE', 156.0],
#  ['Padre Aldamiz', 'PE', 201.0],
#  ['Coronel Francisco Secada Vignetta Intl', 'PE', 93.0],
#  ['Rodriguez Ballon', 'PE', 2563.0],
#  ['Juliaca', 'PE', 3827.0],
#  ['Cadete Guillermo Del Castillo Paredes', 'PE', 265.0],
#  ['Teniente Alejandro Velasco Astete Intl', 'PE', 3311.0],
#  ['Coronel Carlos Ciriani Santa Rosa Intl', 'PE', 469.0],
#  ['Jorge Chavez Intl', 'PE', 34.0],
#  ['Mactan Cebu Intl', 'RP', 9.0],
#  ['Legazpi', 'RP', 20.0],
#  ['Daniel Z Romualdez', 'RP', 3.0],
#  ['Ninoy Aquino Intl', 'RP', 23.0],
#  ['Butuan', 'RP', 43.0],
#  ['Zamboanga Intl', 'RP', 10.0],
#  ['Iloilo', 'RP', 8.0],
#  ['Pagadian', 'RP', 2.0],
#  ['General Santos International Airport', 'RP', 9.0],
#  ['Francisco Bangoy International', 'RP', 18.0],
#  ['Bacolod', 'RP', 8.0],
#  ['Cotabato', 'RP', 58.0],
#  ['Balice', 'PL', 241.0],
#  ['Pyrzowice', 'PL', 303.0],
#  ['Bydgoszcz Ignacy Jan Paderewski Airport', 'PL', 72.0],
#  ['Goleniow', 'PL', 47.0],
#  ['Lech Walesa', 'PL', 149.0],
#  ['Jasionka', 'PL', 206.0],
#  ['Lawica', 'PL', 94.0],
#  ['Strachowice', 'PL', 123.0],
#  ['Lodz Wladyslaw Reymont Airport', 'PL', 184.0],
#  ['Okecie', 'PL', 110.0],
#  ['Faro', 'P', 7.0],
#  ['Flores', 'P', 34.0],
#  ['Portela', 'P', 114.0],
#  ['Porto Santo', 'P', 104.0],
#  ['Graciosa', 'P', 26.0],
#  ['Sao Jorge', 'P', 95.0],
#  ['Corvo Airport', 'P', 19.0],
#  ['Santa Maria', 'P', 94.0],
#  ['Madeira', 'P', 59.0],
#  ['Pico', 'P', 33.0],
#  ['Lajes', 'P', 55.0],
#  ['Porto', 'P', 70.0],
#  ['Ponta Delgada', 'P', 79.0],
#  ['Luis Munoz Marin Intl', 'PR', 3.0],
#  ['Doha Intl', 'Q', 11.0],
#  ['St Denis Gillot', 'REUN', 20.0],
#  ['Iasi', 'RO', 121.0],
#  ['Sibiu', 'RO', 456.0],
#  ['Tautii Magheraus', 'RO', 184.0],
#  ['Stefan Cel Mare', 'RO', 419.0],
#  ['Cluj Napoca', 'RO', 316.0],
#  ['Traian Vuia', 'RO', 106.0],
#  ['Bacau', 'RO', 185.0],
#  ['Oradea', 'RO', 142.0],
#  ['Henri Coanda', 'RO', 96.0],
#  ['Satu Mare', 'RO', 123.0],
#  ['Arad', 'RO', 107.0],
#  ['Tomsk Bogashevo Airport', 'R', 182.0],
#  ['Ignatyevo', 'R', 195.0],
#  ['Pobedilovo Airport', 'R', 146.0],
#  ['Shpakovskoye', 'R', 453.0],
#  ['Tambow', 'R', 38.0],
#  ['Salekhard Airport', 'R', 66.0],
#  ['Cheboksary Airport', 'R', 170.0],
#  ['Vorkuta Airport', 'R', 184.0],
#  ['Chertovitskoye', 'R', 157.0],
#  ['Belgorod International Airport', 'R', 224.0],
#  ['Uytash', 'R', 4.0],
#  ['Syktyvkar', 'R', 104.0],
#  ['Surgut', 'R', 61.0],
#  ['Magnitogorsk', 'R', 436.0],
#  ['Knevichi', 'R', 14.0],
#  ['Nalchik Airport', 'R', 445.0],
#  ['Spichenkovo Airport', 'R', 312.0],
#  ['Nizhnevartovsk', 'R', 54.0],
#  ['Ulyanovsk East Airport', 'R', 77.0],
#  ['Elista Airport', 'R', 153.0],
#  ['Alykel', 'R', 181.0],
#  ['Mukhino', 'R', 515.0],
#  ['Novyi Urengoy', 'R', 6.0],
#  ['Bolshoye Savino', 'R', 123.0],
#  ['Rostov Na Donu', 'R', 85.0],
#  ['Ufa', 'R', 137.0],
#  ['Murmansk', 'R', 81.0],
#  ['Domododevo', 'R', 179.0],
#  ['Kurumoch', 'R', 145.0],
#  ['Kazan', 'R', 125.0],
#  ['Koltsovo', 'R', 233.0],
#  ['Sheremetyevo', 'R', 190.0],
#  ['Pulkovo', 'R', 24.0],
#  ['Balandino', 'R', 234.0],
#  ['Novy', 'R', 74.0],
#  ['Khrabrovo', 'R', 13.0],
#  ['Roschino', 'R', 115.0],
#  ['Sochi', 'R', 27.0],
#  ['Khomutovo', 'R', 18.0],
#  ['Vnukovo', 'R', 209.0],
#  ['Gumrak', 'R', 147.0],
#  ['Tolmachevo', 'R', 111.0],
#  ['Omsk', 'R', 95.0],
#  ['Petrozavodsk Airport', 'R', 46.0],
#  ['Orsk Airport', 'R', 277.0],
#  ['Yelizovo', 'R', 40.0],
#  ['Khanty Mansiysk Airport', 'R', 23.0],
#  ['Sokol', 'R', 175.0],
#  ['Yakutsk', 'R', 99.0],
#  ['Orenburg', 'R', 118.0],
#  ['Grozny Airport', 'R', 167.0],
#  ['Izhevsk Airport', 'R', 162.0],
#  ['Irkutsk', 'R', 511.0],
#  ['Kadala', 'R', 693.0],
#  ['Astrakhan', 'R', -20.0],
#  ['Abakan', 'R', 253.0],
#  ['Emelyanovo', 'R', 287.0],
#  ['Barnaul', 'R', 255.0],
#  ['Kemerovo', 'R', 263.0],
#  ['Bratsk', 'R', 491.0],
#  ['Talagi', 'R', 6.0],
#  ['Leshukonskoye Airport', 'R', 67.0],
#  ['Cherepovets Airport', 'R', 115.0],
#  ['Pashkovskiy', 'R', 36.0],
#  ['Kigali Intl', 'RWA', 1481.0],
#  ['Robert L Bradshaw', 'KN', 52.0],
#  ['Hewanorra Intl', 'WL', 4.0],
#  ['George F L Charles', 'WL', 7.0],
#  ['Saint-Pierre', 'SPMI', 8.0],
#  ['E T Joshua', 'WV', 20.0],
#  ['Faleolo Intl', 'WS', 18.0],
#  ['Sao Tome Intl', 'STP', 10.0],
#  ['Taif', 'SA', 1478.0],
#  ['King Fahd Intl', 'SA', 22.0],
#  ['Hail', 'SA', 1016.0],
#  ['King Abdulaziz Intl', 'SA', 15.0],
#  ['King Khaled Intl', 'SA', 625.0],
#  ['Prince Mohammad Bin Abdulaziz', 'SA', 656.0],
#  ['Ziguinchor', 'SN', 23.0],
#  ['Leopold Sedar Senghor Intl', 'SN', 26.0],
#  ['Pristina', 'KOS', 545.0],
#  ['Beograd', 'SRB', 102.0],
#  ['Nis', 'SRB', 198.0],
#  ['Seychelles Intl', 'SY', 3.0],
#  ['Freetown Lungi', 'WAL', 26.0],
#  ['Changi Intl', 'SGP', 7.0],
#  ['Princess Juliana Intl', 'NLSM', 4.0],
#  ['M R Stefanik', 'SK', 133.0],
#  ['Kosice', 'SK', 230.0],
#  ['Ljubljana', 'SLO', 388.0],
#  ['Honiara International', 'SLB', 9.0],
#  ['Aden Adde International Airport', 'SP', 9.0],
#  ['Lanseria', 'RSA', 1377.0],
#  ['Pietermaritzburg', 'RSA', 739.0],
#  ['Durban Intl', 'RSA', 10.0],
#  ['East London', 'RSA', 133.0],
#  ['Bloemfontein Intl', 'RSA', 1359.0],
#  ['Kimberley', 'RSA', 1204.0],
#  ['Port Elizabeth Intl', 'RSA', 69.0],
#  ['Pietersburg', 'RSA', 1327.0],
#  ['Cape Town Intl', 'RSA', 46.0],
#  ['Johannesburg Intl', 'RSA', 1695.0],
#  ['Yeosu', 'ROK', 16.0],
#  ['Incheon Intl', 'ROK', 7.0],
#  ['Gimhae Intl', 'ROK', 2.0],
#  ['Gimpo', 'ROK', 18.0],
#  ['Ulsan', 'ROK', 14.0],
#  ['Gwangju', 'ROK', 12.0],
#  ['Daegu Ab', 'ROK', 35.0],
#  ['Jeju Intl', 'ROK', 36.0],
#  ['Juba', 'SSD', 461.0],
#  ['Hierro', 'E', 31.0],
#  ['Santander', 'E', 5.0],
#  ['La Palma', 'E', 33.0],
#  ['Gran Canaria', 'E', 24.0],
#  ['Salamanca', 'E', 791.0],
#  ['Tenerife Norte', 'E', 632.0],
#  ['Malaga', 'E', 16.0],
#  ['Bilbao', 'E', 42.0],
#  ['Tenerife Sur', 'E', 64.0],
#  ['Talavera La Real', 'E', 186.0],
#  ['Alicante', 'E', 43.0],
#  ['Barcelona', 'E', 4.0],
#  ['Lanzarote', 'E', 14.0],
#  ['Vigo', 'E', 261.0],
#  ['Melilla', 'MEL', 48.0],
#  ['Murcia San Javier', 'E', 3.0],
#  ['La Gomera Airport', 'E', 219.0],
#  ['Fuerteventura', 'E', 25.0],
#  ['Jerez', 'E', 28.0],
#  ['Son Sant Joan', 'E', 7.0],
#  ['Pamplona', 'E', 459.0],
#  ['Granada', 'E', 567.0],
#  ...]

# %%
air_df = pd.DataFrame(air_list,columns=['airport_name','country_code','elevation'])
air_df.head()
# Out:
#            airport_name country_code elevation
# 0                 Herat          AFG       977
# 1            Kabul Intl          AFG      1792
# 2          Tirana Rinas           AL        38
# 3  Cheikh Larbi Tebessi           DZ       811
# 4         Batna Airport           DZ       822

# %%
ad = air_df.merge(code_df,how='left')
ad['elevation'] = pd.to_numeric(ad.elevation,errors='coerce')

# %%
# 4. name and country of c) airport at highest elevation
ad.sort_values('elevation',ascending=False).head()
# Out:
#                                airport_name country_code  elevation  country
# 80                             El Alto Intl          BOL     4063.0  Bolivia
# 219                           Lhasa-Gonggar           CN     4005.0    China
# 241                            Yushu Batang           CN     3963.0    China
# 813                                 Juliaca           PE     3827.0     Peru
# 815  Teniente Alejandro Velasco Astete Intl           PE     3311.0     Peru
